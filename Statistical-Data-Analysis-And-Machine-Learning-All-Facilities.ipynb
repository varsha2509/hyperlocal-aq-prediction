# %% [markdown]
# <b> <font size = 5> Statistical Inference and Feature Engineering with All Facilities </b> </font>

# %% [markdown]
# This iPython Notebook performs statistical analysis of different datasets used in this analysis. The first section of the notebook focuses on the issue of multicollinearity and different methods are tested to resolve this issue in the dataset. This includes a simple Ordinary Least Square fit to drop highly collinear features, step forward approach with R2 and Variance Inflation Factor estimation, and Lasso regularization. Next, a Random Forest approach is used for feature selection.
#
# In the second section of this notebook, machine learning models are built to predict air concentration using the input features. Different models are tested with and without a Principal Component Analysis approach including Linear, Ridge and Elastic Net Regression, Random Forest and XGBoost.

# %%
#Import basic python packages for data analysis and plotting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.lines as mlines
import pylab as plot
import matplotlib
import geopandas as gpd
from shapely.geometry import Point, Polygon
from shapely.ops import nearest_points
import random
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
import math
import time

import pickle

### Import Sklearn packages
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.model_selection import GridSearchCV, cross_validate, cross_val_score
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn import linear_model
from sklearn.model_selection import KFold
from sklearn.metrics import make_scorer
from sklearn.metrics import r2_score
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import ElasticNet




### Import Scipy stats packages
from scipy.stats import pearsonr
from scipy.stats import boxcox


# Import statsmodel packages
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices


#Sequential Feature Selector
from mlxtend.feature_selection import SequentialFeatureSelector as SFS



import re


import warnings
warnings.filterwarnings("ignore")

sns.set(style = 'whitegrid')
sns.set_palette('bright')
# %matplotlib inline

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #  <b> <font size = 5>  Statistical Data Analysis <b> </font>

# %% [markdown]
# ## <b> <font size = 4>  Load the DataFrames   </b> </font>

# %%
BC_All= pd.read_csv("Data/BC_All_Facilities_input.csv")
NO2_All = pd.read_csv("Data/NO2_All_Facilities_input.csv")

# %%
#Drop the first column and rename 'BC Value' and 'NO2 Value'
BC_All.drop(columns = ['Unnamed: 0'], inplace=True)
NO2_All.drop(columns = ['Unnamed: 0'], inplace=True)

BC_All.rename(columns = {'BC Value': 'BC_Value'}, inplace = True)
NO2_All.rename(columns = {'NO2 Value': 'NO2_Value'}, inplace = True)

# %% [markdown]
# <b> <font size = 3> Create feature list</b> </font>

# %%
# Create a feature list by dropping BC_value and NO2_value
BC_features = BC_All.drop(columns = ['BC_Value'])
NO2_features = NO2_All.drop(columns = ['NO2_Value'])

X_BC_scaled = pd.DataFrame(StandardScaler().fit_transform(BC_features), index = BC_features.index, columns = BC_features.columns)

BC_df_scaled = pd.concat([BC_All['BC_Value'], X_BC_scaled], axis = 1)


X_NO2_scaled = pd.DataFrame(StandardScaler().fit_transform(NO2_features), index = NO2_features.index, columns = NO2_features.columns)


NO2_df_scaled = pd.concat([NO2_All['NO2_Value'], X_NO2_scaled], axis = 1)

# %% [markdown]
# ## <b> <font size = 4>  Simple OLS fit on individual features </b> </font>

# %% [markdown]
# ### <b> <font size = 3> BC Dataset </b> </font>

# %%
r2_BC = []
for column in BC_features.columns[0:]:
        r2 = sm.OLS(BC_All['BC_Value'], BC_features[column]).fit().rsquared
        r2_BC.append(r2)
BC_r2_score_df = pd.DataFrame({'Feature': BC_features.columns, 'Individual_R2':r2_BC})

# %%
BC_r2_score_df.sort_values('Individual_R2', ascending = False)
# Out:
#                                  Feature  Individual_R2
# 349                            Radiation       0.590165
# 350                              Maxtemp       0.589760
# 351                              Mintemp       0.589044
# 352                             Pressure       0.588588
# 84         127811-Retail-Res-medium_dist       0.576016
# 277      18544711-Manufacturing-low_dist       0.575559
# 158         14318611-FoodPlant-high_dist       0.575417
# 92         13750711-Retail-Res-high_dist       0.574395
# 207         17247811-Retail-Res-low_dist       0.572499
# 131        14122011-Retail-Res-high_dist       0.570582
# 61    10505411-Manufacturing-medium_dist       0.569561
# 276         18543911-Retail-Res-low_dist       0.568621
# 14          10462111-Retail-Res-low_dist       0.567678
# 142      14251611-Retail-Res-medium_dist       0.566651
# 252      18489911-Retail-Res-medium_dist       0.566420
# 53          10501911-Retail-Res-low_dist       0.564550
# 223         18127811-Retail-Res-low_dist       0.560984
# 1          10452911-Retail-Res-high_dist       0.560107
# 38   10490111-Transportation-medium_dist       0.559192
# 96   13761511-Transportation-medium_dist       0.556853
# 348                               Precip       0.556658
# 317                382911-Misc-high_dist       0.554294
# 54          10502011-Retail-Res-low_dist       0.551853
# 342       773811-Manufacturing-high_dist       0.551069
# 173      15742311-Retail-Res-medium_dist       0.550125
# 330          448011-Retail-Res-high_dist       0.549553
# 60          10504811-Retail-Res-low_dist       0.547730
# 210         17248611-Retail-Res-low_dist       0.547698
# 105      13787311-Retail-Res-medium_dist       0.545223
# 315       380611-Manufacturing-high_dist       0.545156
# 2              10453011-WWTP-medium_dist       0.544847
# 287           18705211-Waste-medium_dist       0.544728
# 86         130511-Retail-Res-medium_dist       0.544686
# 202      17245411-Retail-Res-medium_dist       0.544431
# 153      14300311-Retail-Res-medium_dist       0.544336
# 292             18782611-Waste-high_dist       0.544306
# 124       140211-Manufacturing-high_dist       0.544283
# 299        196511-Retail-Res-medium_dist       0.543881
# 334    4955911-Manufacturing-medium_dist       0.543670
# 318     383211-Manufacturing-medium_dist       0.543612
# 167         15723511-Retail-Res-low_dist       0.543367
# 339            771711-Eateries-high_dist       0.543367
# 297           194911-Retail-Res-low_dist       0.542904
# 293     18787011-Manufacturing-high_dist       0.542885
# 64       10510811-AsphaltPlant-high_dist       0.542784
# 237         18132611-Retail-Res-low_dist       0.542585
# 198           17243911-Waste-medium_dist       0.542389
# 72        1088911-Retail-Res-medium_dist       0.541830
# 20       10472311-Retail-Res-medium_dist       0.541550
# 8     10457911-ConcretePlant-medium_dist       0.541544
# 250      18160711-Retail-Res-medium_dist       0.541026
# 240         18133411-Retail-Res-low_dist       0.541015
# 55       10502111-Retail-Res-medium_dist       0.539879
# 208      17247911-Retail-Res-medium_dist       0.538755
# 333         479511-FoodPlant-medium_dist       0.537384
# 25       10476211-Retail-Res-medium_dist       0.536912
# 266            18496311-Misc-medium_dist       0.535209
# 140   14247611-Manufacturing-medium_dist       0.534437
# 19          10472111-Retail-Res-low_dist       0.533305
# 192      16022011-Retail-Res-medium_dist       0.533280
# 244              18134411-Misc-high_dist       0.533272
# 126         14059511-Retail-Res-low_dist       0.533253
# 222      18127711-Retail-Res-medium_dist       0.533236
# 69               10707511-EGen-high_dist       0.533143
# 115      13825511-Retail-Res-medium_dist       0.532852
# 224        18128911-Retail-Res-high_dist       0.532803
# 227         18130011-Retail-Res-low_dist       0.532192
# 300      200311-AsphaltPlant-medium_dist       0.531820
# 259            18491811-WWTP-medium_dist       0.531755
# 65         10517111-Retail-Res-high_dist       0.531298
# 235      18132011-Retail-Res-medium_dist       0.531191
# 306          310411-Retail-Res-high_dist       0.531181
# 46       10496511-Retail-Res-medium_dist       0.530336
# 308           338411-AutoRepair-low_dist       0.529677
# 261      18492911-Manufacturing-low_dist       0.529536
# 206      17246911-Retail-Res-medium_dist       0.529428
# 243      18134211-Retail-Res-medium_dist       0.529309
# 28      10477111-Transportation-low_dist       0.529230
# 119          138911-AutoRepair-high_dist       0.528921
# 152      14295811-Retail-Res-medium_dist       0.528906
# 120        139211-Retail-Res-medium_dist       0.528343
# 302          203711-Retail-Res-high_dist       0.528209
# 264   18495311-Manufacturing-medium_dist       0.527906
# 295     193011-Manufacturing-medium_dist       0.527735
# 332       477811-ConcretePlant-high_dist       0.527593
# 272         18539711-Retail-Res-low_dist       0.527225
# 107         13799411-Retail-Res-low_dist       0.527126
# 161         15713811-FoodPlant-high_dist       0.526383
# 82         127611-Retail-Res-medium_dist       0.526175
# 343         7845611-Retail-Res-high_dist       0.526168
# 205         17246811-Retail-Res-low_dist       0.525548
# 326      444911-Transportation-high_dist       0.525455
# 325          405311-Foundaries-high_dist       0.525433
# 257      18491211-Retail-Res-medium_dist       0.525395
# 52       10501811-Retail-Res-medium_dist       0.525028
# 316          382111-Foundaries-high_dist       0.524864
# 204      17246611-Retail-Res-medium_dist       0.524726
# 191      16021911-Retail-Res-medium_dist       0.524374
# 258      18491311-Retail-Res-medium_dist       0.524331
# 218      17252511-Retail-Res-medium_dist       0.524169
# 320         3963311-Foundaries-high_dist       0.523493
# 80         127111-Retail-Res-medium_dist       0.523055
# 134      14179311-Retail-Res-medium_dist       0.522777
# 296       193511-ConcretePlant-high_dist       0.522445
# 262         18493611-Retail-Res-low_dist       0.522071
# 99          13777911-Retail-Res-low_dist       0.521929
# 144     14267411-Manufacturing-high_dist       0.520057
# 241      18133511-Retail-Res-medium_dist       0.519712
# 196        172211-Retail-Res-medium_dist       0.519556
# 79         126911-Retail-Res-medium_dist       0.519452
# 73       1105111-ConcretePlant-high_dist       0.519366
# 285      18697911-Retail-Res-medium_dist       0.518830
# 225      18129211-Retail-Res-medium_dist       0.518674
# 93       13760711-Retail-Res-medium_dist       0.518223
# 103      13785311-Retail-Res-medium_dist       0.518148
# 13            10461911-Waste-medium_dist       0.517092
# 346        808611-AsphaltPlant-high_dist       0.516740
# 194        168111-Retail-Res-medium_dist       0.516725
# 26      10476711-Manufacturing-high_dist       0.515343
# 303              203811-WWTP-medium_dist       0.514837
# 165         15715211-Retail-Res-low_dist       0.514813
# 70              10708011-Waste-high_dist       0.514032
# 171      15734911-Retail-Res-medium_dist       0.513007
# 321      3963411-Manufacturing-high_dist       0.512462
# 128   14071611-Manufacturing-medium_dist       0.512370
# 290        18778911-Retail-Res-high_dist       0.512301
# 43    10494711-Manufacturing-medium_dist       0.512127
# 335           512911-FoodPlant-high_dist       0.512098
# 97   13777411-Transportation-medium_dist       0.511722
# 271      18539511-Retail-Res-medium_dist       0.510699
# 312            375111-Eateries-high_dist       0.510477
# 256      18490811-Retail-Res-medium_dist       0.510267
# 291      18779811-Manufacturing-low_dist       0.509810
# 180     15755511-Manufacturing-high_dist       0.509756
# 116      13833111-Retail-Res-medium_dist       0.509041
# 269      18539211-Retail-Res-medium_dist       0.508777
# 309          338911-Retail-Res-high_dist       0.507126
# 122   13983311-Manufacturing-medium_dist       0.506821
# 239         18132911-Retail-Res-low_dist       0.506452
# 7          10457711-Foundaries-high_dist       0.506012
# 34          10478811-Retail-Res-low_dist       0.505714
# 4       10457411-Manufacturing-high_dist       0.504939
# 132          141411-Retail-Res-high_dist       0.504559
# 137      14191911-Retail-Res-medium_dist       0.503685
# 130         14115411-Retail-Res-low_dist       0.503638
# 36       10487211-Retail-Res-medium_dist       0.503483
# 114      13818911-Retail-Res-medium_dist       0.503399
# 286   18698311-Manufacturing-medium_dist       0.503317
# 3     10457011-Manufacturing-medium_dist       0.502953
# 160      15713511-Retail-Res-medium_dist       0.502779
# 9        10460411-Retail-Res-medium_dist       0.502486
# 44    10495311-Manufacturing-medium_dist       0.502453
# 288     18776211-Manufacturing-high_dist       0.501958
# 159            14334311-Misc-medium_dist       0.500780
# 305          310211-Retail-Res-high_dist       0.500737
# 284         18697311-Retail-Res-low_dist       0.500575
# 249        18135811-Retail-Res-high_dist       0.500517
# 345         804911-FoodPlant-medium_dist       0.499392
# 327       445511-Manufacturing-high_dist       0.498710
# 112         13818411-Retail-Res-low_dist       0.498601
# 113         13818811-Retail-Res-low_dist       0.498142
# 33       10478711-Retail-Res-medium_dist       0.498063
# 58       10502711-Retail-Res-medium_dist       0.497490
# 66           10518411-FoodPlant-low_dist       0.497162
# 94         13760911-Retail-Res-high_dist       0.496581
# 68      10523411-Manufacturing-high_dist       0.496030
# 341     772611-Manufacturing-medium_dist       0.495827
# 211      17249111-Retail-Res-medium_dist       0.495819
# 238            18132711-Misc-medium_dist       0.494611
# 213      17249911-Retail-Res-medium_dist       0.494539
# 298        195711-AutoRepair-medium_dist       0.493053
# 76        1106511-Retail-Res-medium_dist       0.492804
# 166        15721111-Retail-Res-high_dist       0.492373
# 181         15756011-FoodPlant-high_dist       0.492206
# 24    10473611-Manufacturing-medium_dist       0.491873
# 338           608411-Retail-Res-low_dist       0.491851
# 102         13783011-Retail-Res-low_dist       0.491656
# 90          13747911-Retail-Res-low_dist       0.490982
# 234   18131411-Manufacturing-medium_dist       0.490915
# 319        383511-AutoRepair-medium_dist       0.490832
# 17       10470711-Retail-Res-medium_dist       0.490460
# 307        337111-Manufacturing-low_dist       0.490434
# 41    10492711-Manufacturing-medium_dist       0.490077
# 63    10507111-Manufacturing-medium_dist       0.489863
# 136     14182811-Manufacturing-high_dist       0.489504
# 329     447711-Manufacturing-medium_dist       0.489325
# 51          10500811-Retail-Res-low_dist       0.489303
# 199        17244511-Retail-Res-high_dist       0.489197
# 162        15714511-AutoRepair-high_dist       0.488858
# 278         18544811-Retail-Res-low_dist       0.488598
# 246         18134711-Retail-Res-low_dist       0.488368
# 331          450311-Retail-Res-high_dist       0.488347
# 273      18541311-Retail-Res-medium_dist       0.487936
# 217   17252111-Manufacturing-medium_dist       0.487405
# 109         13812811-Retail-Res-low_dist       0.486352
# 289   18776511-Manufacturing-medium_dist       0.486224
# 230         18130411-Retail-Res-low_dist       0.486147
# 32          10478611-Retail-Res-low_dist       0.486023
# 310           340611-FoodPlant-high_dist       0.485944
# 71      10708111-Manufacturing-high_dist       0.485788
# 31       10478111-Retail-Res-medium_dist       0.485617
# 133         14167411-Retail-Res-low_dist       0.483461
# 39          10490611-Retail-Res-low_dist       0.483301
# 77        1107511-Retail-Res-medium_dist       0.483203
# 57          10502611-Retail-Res-low_dist       0.482676
# 127         14071311-Retail-Res-low_dist       0.482556
# 37       10488111-Retail-Res-medium_dist       0.482306
# 275      18542211-Retail-Res-medium_dist       0.482251
# 104  13787211-Transportation-medium_dist       0.482152
# 91       13748111-Retail-Res-medium_dist       0.482098
# 304              309711-Misc-medium_dist       0.482047
# 59       10503011-Retail-Res-medium_dist       0.481849
# 23          10473411-Retail-Res-low_dist       0.481652
# 85         128211-Retail-Res-medium_dist       0.481480
# 15          10466511-FoodPlant-high_dist       0.481434
# 179         15755411-Retail-Res-low_dist       0.480893
# 344             7845711-Misc-medium_dist       0.480500
# 247      18135111-Retail-Res-medium_dist       0.480039
# 226      18129911-Retail-Res-medium_dist       0.479468
# 233         18131111-Retail-Res-low_dist       0.477955
# 214     17250011-Transportation-low_dist       0.477858
# 172         15737911-Retail-Res-low_dist       0.477515
# 169      15732311-Retail-Res-medium_dist       0.477425
# 145  14270911-Transportation-medium_dist       0.477386
# 45       10496311-Retail-Res-medium_dist       0.477316
# 251         18344711-Retail-Res-low_dist       0.473121
# 242      18134111-Manufacturing-low_dist       0.467405
# 101      13782611-Retail-Res-medium_dist       0.463940
# 231      18130611-Retail-Res-medium_dist       0.462454
# 232         18131011-Retail-Res-low_dist       0.461512
# 78   11650611-Transportation-medium_dist       0.457643
# 328        446611-Manufacturing-low_dist       0.456541
# 245     18134511-Transportation-low_dist       0.456528
# 149      14286511-Retail-Res-medium_dist       0.456514
# 164         15714911-Retail-Res-low_dist       0.454701
# 10         10460511-Retail-Res-high_dist       0.454001
# 83         127711-Retail-Res-medium_dist       0.453917
# 163  15714811-Transportation-medium_dist       0.450803
# 201  17245111-Transportation-medium_dist       0.445081
# 168  15723611-Transportation-medium_dist       0.444867
# 228         18130211-Retail-Res-low_dist       0.444584
# 18          10471211-Retail-Res-low_dist       0.444562
# 87                 136511-EGen-high_dist       0.443838
# 123            13985611-Misc-medium_dist       0.442628
# 336       515411-Manufacturing-high_dist       0.442086
# 89   13747011-Transportation-medium_dist       0.441894
# 135      14182211-Retail-Res-medium_dist       0.441751
# 197  17243011-Transportation-medium_dist       0.440512
# 138      14235311-Retail-Res-medium_dist       0.440457
# 129      14115111-Retail-Res-medium_dist       0.440345
# 88           137211-Retail-Res-high_dist       0.439944
# 248    18135311-Transportation-high_dist       0.439428
# 100         13779311-Retail-Res-low_dist       0.438989
# 229  18130311-Transportation-medium_dist       0.438438
# 27   10476911-Transportation-medium_dist       0.436085
# 212         17249711-Retail-Res-low_dist       0.434467
# 147      14271411-Retail-Res-medium_dist       0.434201
# 154         14309511-Retail-Res-low_dist       0.434076
# 35      10481011-Transportation-low_dist       0.433068
# 177         15754311-Retail-Res-low_dist       0.432406
# 174        15745711-Retail-Res-high_dist       0.431574
# 219  17252611-Transportation-medium_dist       0.430433
# 182         15925211-Retail-Res-low_dist       0.428943
# 110     13815311-Transportation-low_dist       0.428870
# 220      17252711-Retail-Res-medium_dist       0.428850
# 314                379511-WWTP-high_dist       0.427486
# 347           808811-FoodPlant-high_dist       0.424840
# 221  17252811-Transportation-medium_dist       0.424236
# 323          400311-Retail-Res-high_dist       0.424214
# 260        18492711-Retail-Res-high_dist       0.423145
# 95         13761011-Retail-Res-high_dist       0.422086
# 216      17251211-Retail-Res-medium_dist       0.421221
# 117         13833411-Retail-Res-low_dist       0.420952
# 188         15943911-Retail-Res-low_dist       0.420691
# 322          400211-Retail-Res-high_dist       0.419974
# 157     14314811-Transportation-low_dist       0.419762
# 50   10498611-Transportation-medium_dist       0.419422
# 209      17248111-Retail-Res-medium_dist       0.419365
# 56          10502511-Retail-Res-low_dist       0.419343
# 29       10477311-Retail-Res-medium_dist       0.418780
# 155         14314511-Retail-Res-low_dist       0.418120
# 118     13837411-Transportation-low_dist       0.417826
# 141         14249611-Retail-Res-low_dist       0.417762
# 30              10477411-Waste-high_dist       0.417721
# 6       10457611-Manufacturing-high_dist       0.417542
# 108     13801611-Manufacturing-high_dist       0.417343
# 282        18697111-Retail-Res-high_dist       0.417065
# 301          200611-Retail-Res-high_dist       0.417025
# 189         15950611-Retail-Res-low_dist       0.416179
# 193      16080611-Retail-Res-medium_dist       0.415853
# 111  13818011-Transportation-medium_dist       0.415842
# 106      13799311-Retail-Res-medium_dist       0.414971
# 283      18697211-Retail-Res-medium_dist       0.414893
# 254         18490411-Retail-Res-low_dist       0.414595
# 183      15940511-Retail-Res-medium_dist       0.414269
# 75           1106311-Retail-Res-low_dist       0.413765
# 236   18132311-Manufacturing-medium_dist       0.413520
# 263      18493911-Retail-Res-medium_dist       0.412714
# 185        15941111-Retail-Res-high_dist       0.412606
# 170      15734511-Retail-Res-medium_dist       0.412057
# 311           343011-FoodPlant-high_dist       0.411691
# 270         18539311-Retail-Res-low_dist       0.411664
# 143      14258711-Retail-Res-medium_dist       0.411489
# 184      15941011-Retail-Res-medium_dist       0.411453
# 340                772011-EGen-high_dist       0.411400
# 175         15746511-Retail-Res-low_dist       0.411242
# 281      18545611-Retail-Res-medium_dist       0.411205
# 48       10497111-Retail-Res-medium_dist       0.410852
# 187      15942711-Retail-Res-medium_dist       0.410641
# 0        10452611-Manufacturing-low_dist       0.409502
# 98       13777611-Retail-Res-medium_dist       0.409484
# 294     192811-Manufacturing-medium_dist       0.409387
# 49       10497711-Retail-Res-medium_dist       0.408691
# 74          1106211-Retail-Res-high_dist       0.408671
# 156      14314611-Retail-Res-medium_dist       0.408562
# 215        17250611-Retail-Res-high_dist       0.408263
# 146      14271111-Retail-Res-medium_dist       0.408249
# 21          10472411-Retail-Res-low_dist       0.408244
# 5       10457511-Manufacturing-high_dist       0.408233
# 255      18490711-Retail-Res-medium_dist       0.407983
# 40          10492211-Retail-Res-low_dist       0.407938
# 280         18545511-Retail-Res-low_dist       0.407613
# 190            15974511-Misc-medium_dist       0.407474
# 12       10461711-Retail-Res-medium_dist       0.407378
# 62       10506911-Retail-Res-medium_dist       0.407378
# 139        14241511-Retail-Res-high_dist       0.406593
# 337     571611-Manufacturing-medium_dist       0.406209
# 195               168411-Waste-high_dist       0.406076
# 47       10496711-Retail-Res-medium_dist       0.405999
# 121      13980511-Retail-Res-medium_dist       0.405867
# 81         127511-Retail-Res-medium_dist       0.405692
# 313        375611-AutoRepair-medium_dist       0.405314
# 274      18542011-Retail-Res-medium_dist       0.404708
# 186      15941211-Retail-Res-medium_dist       0.404588
# 148  14280211-Transportation-medium_dist       0.404517
# 178         15755311-Retail-Res-low_dist       0.404467
# 11          10461011-Retail-Res-low_dist       0.404124
# 265      18495611-Retail-Res-medium_dist       0.404113
# 67      10518911-ConcretePlant-high_dist       0.403963
# 150      14287111-Retail-Res-medium_dist       0.403893
# 42       10493211-Retail-Res-medium_dist       0.403079
# 200      17245011-Retail-Res-medium_dist       0.402671
# 268      18496811-Retail-Res-medium_dist       0.402403
# 125      14059411-Retail-Res-medium_dist       0.401969
# 176        15750711-Retail-Res-high_dist       0.401907
# 253         18490311-Retail-Res-low_dist       0.401812
# 267      18496511-Retail-Res-medium_dist       0.401747
# 353                                 Dist       0.401477
# 16         10469511-Retail-Res-high_dist       0.401449
# 279      18545211-Retail-Res-medium_dist       0.401440
# 151        14292411-Retail-Res-high_dist       0.401436
# 324        403111-Retail-Res-medium_dist       0.401352
# 22               10472611-EGen-high_dist       0.401319
# 203         17245711-Retail-Res-low_dist       0.401155
# 354                 number_intersections       0.275175

# %% [markdown]
# <div class="alert alert-block alert-success"> <b> The above cells shows that the top few features having the largest correlation with BC concentration are Radiation, max temperature, min temperature, pressure, Retail-Res-medium-127811, Manufacturing-low-18544711.  </b> </div>

# %% [markdown]
# ### <b> <font size = 4>  NO2 Dataset </b> </font>

# %%
r2_NO2 = []
for column in NO2_features.columns[0:]:
        r2 = sm.OLS(NO2_All['NO2_Value'], NO2_features[column]).fit().rsquared
        r2_NO2.append(r2)
NO2_r2_score_df = pd.DataFrame({'Feature': NO2_features.columns, 'Individual_R2':r2_NO2})

# %%
NO2_r2_score_df.sort_values('Individual_R2', ascending = False)
# Out:
#                                  Feature  Individual_R2
# 318                            Radiation       0.758557
# 320                              Mintemp       0.757694
# 319                              Maxtemp       0.757622
# 321                             Pressure       0.757288
# 317                               Precip       0.734353
# 30   10490111-Transportation-medium_dist       0.729996
# 79         13750711-Retail-Res-high_dist       0.729319
# 51    10505411-Manufacturing-medium_dist       0.727134
# 141         14318611-FoodPlant-high_dist       0.726710
# 259      18544711-Manufacturing-low_dist       0.725161
# 83   13761511-Transportation-medium_dist       0.720460
# 234         18489911-Retail-Res-low_dist       0.715634
# 206         18127811-Retail-Res-low_dist       0.709528
# 191         17247911-Retail-Res-low_dist       0.706346
# 124   14247611-Manufacturing-medium_dist       0.704377
# 43          10501911-Retail-Res-low_dist       0.703507
# 258         18543911-Retail-Res-low_dist       0.702397
# 311       773811-Manufacturing-high_dist       0.701930
# 0          10452911-Retail-Res-high_dist       0.696770
# 115        14122011-Retail-Res-high_dist       0.694962
# 110      14059511-Retail-Res-medium_dist       0.694091
# 288       380611-Manufacturing-high_dist       0.693903
# 298      444911-Transportation-high_dist       0.690082
# 208      18129211-Retail-Res-medium_dist       0.688658
# 290                382911-Misc-high_dist       0.688545
# 218      18132011-Retail-Res-medium_dist       0.688483
# 175        168111-Retail-Res-medium_dist       0.686709
# 251      18539211-Retail-Res-medium_dist       0.686632
# 60        1088911-Retail-Res-medium_dist       0.685808
# 278                203811-WWTP-high_dist       0.685729
# 112     14071611-Manufacturing-high_dist       0.685439
# 187         17246811-Retail-Res-low_dist       0.685000
# 50          10504811-Retail-Res-low_dist       0.684116
# 58              10708011-Waste-high_dist       0.683692
# 270      18779811-Manufacturing-low_dist       0.683285
# 161     15755511-Manufacturing-high_dist       0.683276
# 241            18491811-WWTP-medium_dist       0.680079
# 26          10478811-Retail-Res-low_dist       0.679286
# 248            18496311-Misc-medium_dist       0.678784
# 97          13818411-Retail-Res-low_dist       0.678148
# 293      3963411-Manufacturing-high_dist       0.678049
# 25       10478711-Retail-Res-medium_dist       0.677808
# 226      18134211-Retail-Res-medium_dist       0.677463
# 308            771711-Eateries-high_dist       0.677396
# 314           804911-FoodPlant-high_dist       0.677350
# 71         127811-Retail-Res-medium_dist       0.677257
# 8                10461911-Waste-low_dist       0.676924
# 273           194911-Retail-Res-low_dist       0.676808
# 108       140211-Manufacturing-high_dist       0.676332
# 305           512911-FoodPlant-high_dist       0.675807
# 44       10502011-Retail-Res-medium_dist       0.675505
# 1              10453011-WWTP-medium_dist       0.675487
# 246   18495311-Manufacturing-medium_dist       0.675261
# 126         14251611-Retail-Res-low_dist       0.674935
# 73         130511-Retail-Res-medium_dist       0.674718
# 231        18135811-Retail-Res-high_dist       0.674426
# 14          10472111-Retail-Res-low_dist       0.674279
# 77       13747911-Retail-Res-medium_dist       0.674259
# 36       10496511-Retail-Res-medium_dist       0.673781
# 299       445511-Manufacturing-high_dist       0.673668
# 81         13760911-Retail-Res-high_dist       0.673460
# 276      200311-AsphaltPlant-medium_dist       0.673132
# 154         15742311-Retail-Res-low_dist       0.672960
# 55        10518411-FoodPlant-medium_dist       0.672556
# 268   18698311-Manufacturing-medium_dist       0.671469
# 99       13818911-Retail-Res-medium_dist       0.671459
# 19    10473611-Manufacturing-medium_dist       0.670803
# 184      17245411-Retail-Res-medium_dist       0.670620
# 162         15756011-FoodPlant-high_dist       0.670494
# 266         18697311-Retail-Res-low_dist       0.670389
# 63        1106511-Retail-Res-medium_dist       0.669774
# 307           608411-Retail-Res-low_dist       0.669247
# 289          382111-Foundaries-high_dist       0.669193
# 136      14300311-Retail-Res-medium_dist       0.669053
# 222         18132911-Retail-Res-low_dist       0.669052
# 310     772611-Manufacturing-medium_dist       0.668493
# 275        196511-Retail-Res-medium_dist       0.668431
# 143          15713811-FoodPlant-low_dist       0.668280
# 189         17247311-Retail-Res-low_dist       0.667483
# 213      18130411-Retail-Res-medium_dist       0.667301
# 201         17252511-Retail-Res-low_dist       0.667282
# 304      4955911-Manufacturing-high_dist       0.667148
# 217     18131411-Manufacturing-high_dist       0.666776
# 147        15721111-Retail-Res-high_dist       0.666483
# 302          450311-Retail-Res-high_dist       0.666235
# 190      17247811-Retail-Res-medium_dist       0.666116
# 41          10500811-Retail-Res-low_dist       0.666106
# 267        18697911-Retail-Res-high_dist       0.666031
# 128     14267411-Manufacturing-high_dist       0.665160
# 53       10510811-AsphaltPlant-high_dist       0.664567
# 177        172211-Retail-Res-medium_dist       0.664465
# 84   13777411-Transportation-medium_dist       0.664308
# 181        17244511-Retail-Res-high_dist       0.664291
# 89          13783011-Retail-Res-low_dist       0.662841
# 18          10473411-Retail-Res-low_dist       0.662679
# 98       13818811-Retail-Res-medium_dist       0.662453
# 48       10502711-Retail-Res-medium_dist       0.662219
# 221              18132711-Misc-high_dist       0.662117
# 255      18541311-Retail-Res-medium_dist       0.662060
# 33    10492711-Manufacturing-medium_dist       0.661869
# 152         15734911-Retail-Res-low_dist       0.661823
# 291        383511-AutoRepair-medium_dist       0.661817
# 142         15713511-Retail-Res-low_dist       0.661631
# 194      17249111-Retail-Res-medium_dist       0.661480
# 28       10487211-Retail-Res-medium_dist       0.661350
# 64        1107511-Retail-Res-medium_dist       0.661170
# 31       10490611-Retail-Res-medium_dist       0.661142
# 24          10478611-Retail-Res-low_dist       0.661135
# 200   17252111-Manufacturing-medium_dist       0.660998
# 59    10708111-Manufacturing-medium_dist       0.660986
# 116        141411-Retail-Res-medium_dist       0.660960
# 283           340611-FoodPlant-high_dist       0.660919
# 111         14071311-Retail-Res-low_dist       0.660716
# 15       10472311-Retail-Res-medium_dist       0.660575
# 72         128211-Retail-Res-medium_dist       0.659795
# 2     10457011-Manufacturing-medium_dist       0.659723
# 47          10502611-Retail-Res-low_dist       0.659639
# 9           10462111-Retail-Res-low_dist       0.659594
# 106     13983311-Manufacturing-high_dist       0.659536
# 10          10466511-FoodPlant-high_dist       0.659200
# 153         15737911-Retail-Res-low_dist       0.658342
# 129  14270911-Transportation-medium_dist       0.658242
# 197     17250011-Transportation-low_dist       0.658198
# 150      15732311-Retail-Res-medium_dist       0.657986
# 45       10502111-Retail-Res-medium_dist       0.657425
# 148         15723511-Retail-Res-low_dist       0.656233
# 232         18160711-Retail-Res-low_dist       0.652811
# 20          10476211-Retail-Res-low_dist       0.651151
# 205         18127711-Retail-Res-low_dist       0.641262
# 173      16022011-Retail-Res-medium_dist       0.641120
# 193      17248611-Retail-Res-medium_dist       0.636764
# 301          448011-Retail-Res-high_dist       0.635966
# 281          310411-Retail-Res-high_dist       0.635670
# 22      10477111-Transportation-low_dist       0.633626
# 254         18539711-Retail-Res-low_dist       0.627643
# 91       13787311-Retail-Res-medium_dist       0.626555
# 172      16021911-Retail-Res-medium_dist       0.626000
# 223      18133411-Retail-Res-medium_dist       0.625555
# 220         18132611-Retail-Res-low_dist       0.625481
# 86          13777911-Retail-Res-low_dist       0.623247
# 303            479511-FoodPlant-low_dist       0.621622
# 69         127611-Retail-Res-medium_dist       0.621125
# 227               18134411-Misc-low_dist       0.618541
# 66         126911-Retail-Res-medium_dist       0.616828
# 207      18128911-Retail-Res-medium_dist       0.616790
# 210         18130011-Retail-Res-low_dist       0.615795
# 243      18492911-Manufacturing-low_dist       0.612963
# 57               10707511-EGen-high_dist       0.611855
# 104        139211-Retail-Res-medium_dist       0.611617
# 54         10517111-Retail-Res-high_dist       0.610230
# 272     193011-Manufacturing-medium_dist       0.610210
# 100        13825511-Retail-Res-high_dist       0.609867
# 188      17246911-Retail-Res-medium_dist       0.607817
# 312         7845611-Retail-Res-high_dist       0.607792
# 297          405311-Foundaries-high_dist       0.606742
# 42       10501811-Retail-Res-medium_dist       0.606107
# 93          13799411-Retail-Res-low_dist       0.604980
# 240      18491311-Retail-Res-medium_dist       0.603980
# 292         3963311-Foundaries-high_dist       0.603755
# 239      18491211-Retail-Res-medium_dist       0.602009
# 244         18493611-Retail-Res-low_dist       0.601367
# 186      17246611-Retail-Res-medium_dist       0.601284
# 101      13833111-Retail-Res-medium_dist       0.601226
# 180      17244111-Retail-Res-medium_dist       0.600306
# 67         127111-Retail-Res-medium_dist       0.598046
# 80       13760711-Retail-Res-medium_dist       0.596064
# 315        808611-AsphaltPlant-high_dist       0.593525
# 118      14179311-Retail-Res-medium_dist       0.593473
# 146         15715211-Retail-Res-low_dist       0.592179
# 114      14115411-Retail-Res-medium_dist       0.591852
# 224        18133511-Retail-Res-high_dist       0.591310
# 121      14191911-Retail-Res-medium_dist       0.588828
# 285            375111-Eateries-high_dist       0.584253
# 238      18490811-Retail-Res-medium_dist       0.581718
# 253      18539511-Retail-Res-medium_dist       0.579754
# 280          310211-Retail-Res-high_dist       0.574519
# 282          338911-Retail-Res-high_dist       0.572972
# 4        10460411-Retail-Res-medium_dist       0.572427
# 12       10470711-Retail-Res-medium_dist       0.570027
# 260         18544811-Retail-Res-low_dist       0.565744
# 56      10523411-Manufacturing-high_dist       0.562937
# 196      17249911-Retail-Res-medium_dist       0.560193
# 117         14167411-Retail-Res-low_dist       0.558749
# 274          195711-AutoRepair-high_dist       0.558022
# 90   13787211-Transportation-medium_dist       0.556659
# 120     14182811-Manufacturing-high_dist       0.553735
# 322                                 Dist       0.551990
# 94       13812811-Retail-Res-medium_dist       0.548952
# 269     18776511-Manufacturing-high_dist       0.548591
# 23       10478111-Retail-Res-medium_dist       0.548325
# 229         18134711-Retail-Res-low_dist       0.548071
# 29       10488111-Retail-Res-medium_dist       0.543318
# 257      18542211-Retail-Res-medium_dist       0.543252
# 78       13748111-Retail-Res-medium_dist       0.542590
# 49       10503011-Retail-Res-medium_dist       0.542330
# 160         15755411-Retail-Res-low_dist       0.540386
# 230      18135111-Retail-Res-medium_dist       0.539188
# 209      18129911-Retail-Res-medium_dist       0.537773
# 233         18344711-Retail-Res-low_dist       0.537334
# 279              309711-Misc-medium_dist       0.536605
# 313             7845711-Misc-medium_dist       0.534496
# 225      18134111-Manufacturing-low_dist       0.533731
# 35       10496311-Retail-Res-medium_dist       0.532491
# 216         18131111-Retail-Res-low_dist       0.530917
# 133      14286511-Retail-Res-medium_dist       0.518368
# 228     18134511-Transportation-low_dist       0.514281
# 145         15714911-Retail-Res-low_dist       0.513404
# 88       13782611-Retail-Res-medium_dist       0.512580
# 215         18131011-Retail-Res-low_dist       0.510683
# 214         18130611-Retail-Res-low_dist       0.510094
# 144     15714811-Transportation-low_dist       0.510072
# 65   11650611-Transportation-medium_dist       0.504237
# 300        446611-Manufacturing-low_dist       0.504091
# 13          10471211-Retail-Res-low_dist       0.500008
# 211         18130211-Retail-Res-low_dist       0.499904
# 74                 136511-EGen-high_dist       0.499389
# 5          10460511-Retail-Res-high_dist       0.499360
# 70         127711-Retail-Res-medium_dist       0.498710
# 149     15723611-Transportation-low_dist       0.498040
# 183  17245111-Transportation-medium_dist       0.497984
# 107              13985611-Misc-high_dist       0.497682
# 76   13747011-Transportation-medium_dist       0.496283
# 119        14182211-Retail-Res-high_dist       0.494273
# 113      14115111-Retail-Res-medium_dist       0.491846
# 122      14235311-Retail-Res-medium_dist       0.491831
# 179         17243711-Retail-Res-low_dist       0.491246
# 178  17243011-Transportation-medium_dist       0.490492
# 212  18130311-Transportation-medium_dist       0.488286
# 21   10476911-Transportation-medium_dist       0.488213
# 87          13779311-Retail-Res-low_dist       0.485795
# 137      14309511-Retail-Res-medium_dist       0.485308
# 195         17249711-Retail-Res-low_dist       0.484939
# 27   10481011-Transportation-medium_dist       0.483003
# 131      14271411-Retail-Res-medium_dist       0.482439
# 75           137211-Retail-Res-high_dist       0.479955
# 158         15754311-Retail-Res-low_dist       0.476903
# 203      17252711-Retail-Res-medium_dist       0.475884
# 155        15745711-Retail-Res-high_dist       0.472492
# 287                379511-WWTP-high_dist       0.470220
# 163         15925211-Retail-Res-low_dist       0.469819
# 316           808811-FoodPlant-high_dist       0.469574
# 204  17252811-Transportation-medium_dist       0.469039
# 202  17252611-Transportation-medium_dist       0.467297
# 242        18492711-Retail-Res-high_dist       0.465584
# 95   13815311-Transportation-medium_dist       0.465152
# 140  14314811-Transportation-medium_dist       0.463207
# 103     13837411-Transportation-low_dist       0.462149
# 82         13761011-Retail-Res-high_dist       0.460848
# 40   10498611-Transportation-medium_dist       0.460460
# 174      16080611-Retail-Res-medium_dist       0.459244
# 96   13818011-Transportation-medium_dist       0.459221
# 295          400311-Retail-Res-high_dist       0.459171
# 264      18697111-Retail-Res-medium_dist       0.458750
# 125      14249611-Retail-Res-medium_dist       0.456663
# 138      14314511-Retail-Res-medium_dist       0.456321
# 102         13833411-Retail-Res-low_dist       0.456196
# 199      17251211-Retail-Res-medium_dist       0.455636
# 265        18697211-Retail-Res-high_dist       0.455314
# 169         15943911-Retail-Res-low_dist       0.454996
# 170         15950611-Retail-Res-low_dist       0.454805
# 192      17248111-Retail-Res-medium_dist       0.454241
# 46       10502511-Retail-Res-medium_dist       0.454238
# 62        1106311-Retail-Res-medium_dist       0.453854
# 294          400211-Retail-Res-high_dist       0.453724
# 284         343011-FoodPlant-medium_dist       0.452953
# 236      18490411-Retail-Res-medium_dist       0.452541
# 309                772011-EGen-high_dist       0.451313
# 252      18539311-Retail-Res-medium_dist       0.450827
# 277          200611-Retail-Res-high_dist       0.449836
# 271     192811-Manufacturing-medium_dist       0.449022
# 92       13799311-Retail-Res-medium_dist       0.448490
# 164      15940511-Retail-Res-medium_dist       0.447664
# 156         15746511-Retail-Res-low_dist       0.447238
# 3       10457511-Manufacturing-high_dist       0.447205
# 130      14271111-Retail-Res-medium_dist       0.446845
# 16       10472411-Retail-Res-medium_dist       0.446836
# 139      14314611-Retail-Res-medium_dist       0.446260
# 32          10492211-Retail-Res-low_dist       0.446175
# 61        1106211-Retail-Res-medium_dist       0.446148
# 198      17250611-Retail-Res-medium_dist       0.446055
# 219      18132311-Manufacturing-low_dist       0.445969
# 166        15941111-Retail-Res-high_dist       0.445903
# 151        15734511-Retail-Res-high_dist       0.445879
# 171              15974511-Misc-high_dist       0.445573
# 165      15941011-Retail-Res-medium_dist       0.445547
# 52       10506911-Retail-Res-medium_dist       0.445428
# 7        10461711-Retail-Res-medium_dist       0.445428
# 245         18493911-Retail-Res-low_dist       0.445243
# 127      14258711-Retail-Res-medium_dist       0.444831
# 263      18545611-Retail-Res-medium_dist       0.443870
# 237      18490711-Retail-Res-medium_dist       0.443780
# 168        15942711-Retail-Res-high_dist       0.443234
# 38         10497111-Retail-Res-high_dist       0.443030
# 262      18545511-Retail-Res-medium_dist       0.442507
# 85       13777611-Retail-Res-medium_dist       0.441979
# 37       10496711-Retail-Res-medium_dist       0.441881
# 39       10497711-Retail-Res-medium_dist       0.441426
# 123        14241511-Retail-Res-high_dist       0.441340
# 306     571611-Manufacturing-medium_dist       0.439992
# 176             168411-Waste-medium_dist       0.438852
# 132  14280211-Transportation-medium_dist       0.438765
# 105      13980511-Retail-Res-medium_dist       0.438451
# 182      17245011-Retail-Res-medium_dist       0.438409
# 256      18542011-Retail-Res-medium_dist       0.438318
# 68           127511-Retail-Res-high_dist       0.438260
# 247        18495611-Retail-Res-high_dist       0.437871
# 167        15941211-Retail-Res-high_dist       0.437869
# 6           10461011-Retail-Res-low_dist       0.437849
# 134      14287111-Retail-Res-medium_dist       0.436829
# 286        375611-AutoRepair-medium_dist       0.436223
# 11       10469511-Retail-Res-medium_dist       0.435739
# 34       10493211-Retail-Res-medium_dist       0.435508
# 159         15755311-Retail-Res-low_dist       0.435173
# 249        18496511-Retail-Res-high_dist       0.434758
# 235      18490311-Retail-Res-medium_dist       0.434591
# 250      18496811-Retail-Res-medium_dist       0.434578
# 109      14059411-Retail-Res-medium_dist       0.433766
# 135        14292411-Retail-Res-high_dist       0.433672
# 157        15750711-Retail-Res-high_dist       0.433668
# 261      18545211-Retail-Res-medium_dist       0.433660
# 296        403111-Retail-Res-medium_dist       0.433524
# 185         17245711-Retail-Res-low_dist       0.433042
# 17             10472611-EGen-medium_dist       0.432787
# 323                 number_intersections       0.423860

# %% [markdown]
# <div class="alert alert-block alert-success"> <b> The above cells shows that the top few features having the largest correlation with BC concentration are Radiation, min temperature, max temperature, pressure, precipitation, Transportation-10490111.  </b> </div>

# %% [markdown]
# ## <b> <font size = 4> Simple OLS fit on un-correlated features alone </b> </font>

# %% [markdown]
# The goal is to identify and drop the features that are highly positively correlated or negatively correlated and fit an OLS on the remaining features

# %%
# Next, identify all the features that have a correlation higher than 0.90 or lower than -0.90 indicating a strong positive or negative correlation
threshold_1 = 0.90
threshold_2 = -0.90

def features_high_corr(df_features_corr):
    columns = np.full((df_features_corr.shape[0],), True, dtype=bool)
    for i in range(df_features_corr.shape[0]):
        for j in range(i+1, df_features_corr.shape[0]):
            if (df_features_corr.iloc[i,j] >= threshold_1) | (df_features_corr.iloc[i,j] <= threshold_2) :
                if columns[j]:
                    columns[j] = False
    selected_columns = df_features_corr.columns[columns]
    return selected_columns

# %% [markdown]
# ### <b> <font size = 3> BC Dataset </b> </font>

# %%
BC_features_corr = BC_features.corr()
BC_features_OLS = features_high_corr(BC_features_corr)
print("Features in BC dataset that are not highly correlated: ")
print(BC_features_OLS)
# Out:
# Features in BC dataset that are not highly correlated:
# Index(['10452611-Manufacturing-low_dist', '10452911-Retail-Res-high_dist',
#        '10457011-Manufacturing-medium_dist', 'Precip', 'Radiation', 'Maxtemp',
#        'Mintemp', 'Pressure', 'number_intersections'],
#       dtype='object')

# %%
#Create a dataframe with BC value and selected columns from Lasso
OLS_BC_df = BC_All[['BC_Value']].join(BC_All[['10452611-Manufacturing-low_dist', '10452911-Retail-Res-high_dist',
       '10457011-Manufacturing-medium_dist', 'Precip', 'Radiation', 'Maxtemp',
       'Mintemp', 'Pressure', 'number_intersections']])

# %%
## Plot Correlation matrix
OLS_BC_df_corr = OLS_BC_df.corr()
BC_features_corr_mat = OLS_BC_df_corr.as_matrix()

# %%
print(plt.get_backend())

# close any existing plots
plt.close("all")

# mask out the top triangle
BC_features_corr_mat[np.triu_indices_from(BC_features_corr_mat)] = np.nan

fig, ax = plt.subplots(figsize=(15, 15))

hm = sns.heatmap(BC_features_corr_mat, cbar=True, vmin = -1, vmax = 1, center = 0,
                 fmt='.2f', annot_kws={'size': 8}, annot=True, 
                 square=False, cmap = 'coolwarm')
#cmap=plt.cm.Blues

ticks = np.arange(OLS_BC_df_corr.shape[0]) + 0.5
ax.set_xticks(ticks)
ax.set_xticklabels(OLS_BC_df_corr.columns, rotation=90, fontsize=20)
ax.set_yticks(ticks)
ax.set_yticklabels(OLS_BC_df_corr.index, rotation=360, fontsize=20)

ax.set_title('Correlation Matrix - Black Carbon  - Simple OLS', fontsize  = 30)
plt.tight_layout()
#plt.savefig("corr_matrix_incl_anno_double.png", dpi=300)
# Out:
# module://ipykernel.pylab.backend_inline

# %%
## Fit an OLS on the remaining features
BC_OLS_corr_model = sm.OLS(BC_All['BC_Value'], BC_features[BC_features_OLS])
BC_OLS_corr_results = BC_OLS_corr_model.fit() 
BC_OLS_corr_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               BC_Value   R-squared (uncentered):                   0.712
# Model:                            OLS   Adj. R-squared (uncentered):              0.712
# Method:                 Least Squares   F-statistic:                              5893.
# Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        19:20:22   Log-Likelihood:                         -15924.
# No. Observations:               21488   AIC:                                  3.187e+04
# Df Residuals:                   21479   BIC:                                  3.194e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# 10452611-Manufacturing-low_dist        0.1494      0.005     30.191      0.000       0.140       0.159
# 10452911-Retail-Res-high_dist         -0.3986      0.010    -40.459      0.000      -0.418      -0.379
# 10457011-Manufacturing-medium_dist     0.2950      0.006     49.908      0.000       0.283       0.307
# Precip                                -1.3444      0.079    -16.993      0.000      -1.500      -1.189
# Radiation                              0.0692      0.002     30.649      0.000       0.065       0.074
# Maxtemp                               -0.9051      0.042    -21.691      0.000      -0.987      -0.823
# Mintemp                                0.4854      0.139      3.501      0.000       0.214       0.757
# Pressure                              -0.0084      0.002     -4.405      0.000      -0.012      -0.005
# number_intersections                  -0.0107      0.001    -15.376      0.000      -0.012      -0.009
# ==============================================================================
# Omnibus:                     5268.254   Durbin-Watson:                   0.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17298.516
# Skew:                           1.237   Prob(JB):                         0.00
# Kurtosis:                       6.634   Cond. No.                     4.33e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
## R2, Coefficient and Intercept
print("The R2 is {}".format(BC_OLS_corr_results.rsquared), "The R2 tells us that there is a correlation between the features identified and concentration. ")
# Out:
# The R2 is 0.7117513520847643 The R2 tells us that there is a correlation between the features identified and concentration.

# %%
# Creating a plot of BC concentration vs predicted concentration using OLS
sns.set_style("darkgrid")
sns.set(font_scale = 1.2)
plt.figure(figsize = (8,6))
ax = sns.regplot(x = BC_All.BC_Value, y = BC_OLS_corr_results.fittedvalues, fit_reg=True)
ax.set(xlabel = 'Actual BC Concentrations (ug/m3)', ylabel = 'Predicted BC Concetrations (ug/m3)')
plt.title('Actual vs. Predicted BC Concentration')
plt.text(5 , 2.5 ,"R2 = 0.712", fontsize = 18)
# Out:
# Text(5, 2.5, 'R2 = 0.712')

# %% [markdown]
# <div class="alert alert-block alert-success"> <b> The above plot shows that the simple linear model does a decent job of predicting concentrations below 2 ug/m3, but does not perform well at high concentrations. Features that had a correlation coefficient below 0.9 or above -0.9, include 10452611-Manufacturing, 10452911-Retail-Res,
#        10457011-Manufacturing, Precip, Radiation, Maxtemp,
#        Mintemp, Pressure, number_intersections  </b> </div>

# %% [markdown]
# ### <b> <font size = 4>  NO2 Dataset </b> </font>

# %%
NO2_features_corr = NO2_features.corr()
NO2_features_OLS = features_high_corr(NO2_features_corr)
print("Features in NO2 dataset that are not highly correlated: ")
print(NO2_features_OLS)
# Out:
# Features in NO2 dataset that are not highly correlated:
# Index(['10452911-Retail-Res-high_dist', '10457011-Manufacturing-medium_dist',
#        '10457511-Manufacturing-high_dist', '10466511-FoodPlant-high_dist',
#        'Precip', 'Radiation', 'Maxtemp', 'Mintemp', 'Pressure',
#        'number_intersections'],
#       dtype='object')

# %%
#Create a dataframe with NO2 value and selected columns from Lasso
OLS_NO2_df = NO2_All[['NO2_Value']].join(NO2_All[['10452911-Retail-Res-high_dist', '10457011-Manufacturing-medium_dist',
       '10457511-Manufacturing-high_dist', '10466511-FoodPlant-high_dist' ,'Precip', 'Radiation', 'Maxtemp',
       'Mintemp', 'Pressure', 'number_intersections']])

# %%
## Plot Correlation matrix
OLS_NO2_df_corr = OLS_NO2_df.corr()
NO2_features_corr_mat = OLS_NO2_df_corr.as_matrix()

# %%
print(plt.get_backend())

# close any existing plots
plt.close("all")

# mask out the top triangle
NO2_features_corr_mat[np.triu_indices_from(NO2_features_corr_mat)] = np.nan

fig, ax = plt.subplots(figsize=(15, 15))

hm = sns.heatmap(NO2_features_corr_mat, cbar=True, vmin = -1, vmax = 1, center = 0,
                 fmt='.2f', annot_kws={'size': 8}, annot=True, 
                 square=False, cmap = 'coolwarm')
#cmap=plt.cm.Blues

ticks = np.arange(OLS_NO2_df_corr.shape[0]) + 0.5
ax.set_xticks(ticks)
ax.set_xticklabels(OLS_NO2_df_corr.columns, rotation=90, fontsize=20)
ax.set_yticks(ticks)
ax.set_yticklabels(OLS_NO2_df_corr.index, rotation=360, fontsize=20)

ax.set_title('Correlation Matrix - Nitrogen Dioxide  - Simple OLS', fontsize  = 30)
plt.tight_layout()
#plt.savefig("corr_matrix_incl_anno_double.png", dpi=300)
# Out:
# module://ipykernel.pylab.backend_inline

# %%
## Fit an OLS on the remaining features
NO2_OLS_corr_model = sm.OLS(NO2_All['NO2_Value'], NO2_features[NO2_features_OLS])
NO2_OLS_corr_results = NO2_OLS_corr_model.fit() 
NO2_OLS_corr_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              NO2_Value   R-squared (uncentered):                   0.866
# Model:                            OLS   Adj. R-squared (uncentered):              0.866
# Method:                 Least Squares   F-statistic:                          1.384e+04
# Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        19:20:30   Log-Likelihood:                         -73015.
# No. Observations:               21488   AIC:                                  1.461e+05
# Df Residuals:                   21478   BIC:                                  1.461e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# 10452911-Retail-Res-high_dist         -9.4084      0.144    -65.234      0.000      -9.691      -9.126
# 10457011-Manufacturing-medium_dist    10.8755      0.126     86.457      0.000      10.629      11.122
# 10457511-Manufacturing-high_dist       2.2774      0.095     23.884      0.000       2.091       2.464
# 10466511-FoodPlant-high_dist          -4.6254      0.075    -61.579      0.000      -4.773      -4.478
# Precip                               -11.9176      1.173    -10.160      0.000     -14.217      -9.619
# Radiation                              0.6287      0.034     18.509      0.000       0.562       0.695
# Maxtemp                              -14.6234      0.748    -19.561      0.000     -16.089     -13.158
# Mintemp                                1.7198      2.252      0.764      0.445      -2.694       6.134
# Pressure                               0.1329      0.026      5.088      0.000       0.082       0.184
# number_intersections                  -0.0788      0.010     -7.855      0.000      -0.098      -0.059
# ==============================================================================
# Omnibus:                     2739.437   Durbin-Watson:                   0.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4497.707
# Skew:                           0.882   Prob(JB):                         0.00
# Kurtosis:                       4.382   Cond. No.                     4.96e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.96e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
## R2, Coefficient and Intercept
print("The R2 is {}".format(NO2_OLS_corr_results.rsquared), "The R2 tells us that there is a correlation between the features identified and concentration. ")
# Out:
# The R2 is 0.8656264875177946 The R2 tells us that there is a correlation between the features identified and concentration.

# %%
# Creating a plot of NO2 concentration vs predicted concentration using OLS
sns.set_style("darkgrid")
sns.set(font_scale = 1.2)
plt.figure(figsize = (8,6))
ax = sns.regplot(x = NO2_All.NO2_Value, y = NO2_OLS_corr_results.fittedvalues, fit_reg=True)
ax.set(xlabel = 'Actual NO2 Concentrations (ppb)', ylabel = 'Predicted NO2 Concetrations (ppb)')
plt.title('Actual vs. Predicted NO2 Concentration')
plt.text(46 , 29 ,"R2 = 0.866", fontsize = 18)
# Out:
# Text(46, 29, 'R2 = 0.866')

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Once again, the above plot shows that the simple linear model does a decent job of predicting concentrations below 30 ppb, but does not perform well at high concentrations. Features that had a correlation coefficient below 0.9 or above -0.9 include 10452911-Retail-Res, 10457011-Manufacturing,10457511-Manufacturing, 10466511-FoodPlant ,Precip, Radiation, Maxtemp, Mintemp, Pressure, number_intersections</b></div>

# %% [markdown]
# ##  <b> <font size = 4>  Performing a box-cox transformation </b> </font>

# %%
# First make a copy of each dataframe and apply transformation on copy
BC_df_transform = BC_All.copy()
NO2_df_transform = NO2_All.copy()

# %%
lambdas_BC = pd.DataFrame(columns = ['Column_name', "Lambda"])
lambdas_NO2 = pd.DataFrame(columns = ['Column_name', "Lambda"])
def boxcox_transform(df):
    lambdas_df = pd.DataFrame(columns = ['Column_name', "Lambda"])
    for column in df.columns:
        if df[column].min() <=0 :
            df[column] = df[column] - df[column].min() + 0.01
        df[column], boxcox_lambda = boxcox(df[column])
        lambdas_df = lambdas_df.append({'Column_name': column, 'Lambda':boxcox_lambda}, ignore_index = True)
    return lambdas_df

# %% [markdown]
# <b> <font size = 3>  Store transformed data and corresponding Lambdas in a dataframe </b> </font>

# %%
lambdas_BC = boxcox_transform(BC_df_transform)
lambbas_NO2 = boxcox_transform(NO2_df_transform)

# %% [markdown]
# <b> <font size = 3>  Recreate the dataframes with normalized X and Y, and standardize the data </b> </font>

# %%
#BC Dataset
y_BC_transformed = BC_df_transform[['BC_Value']]
X_BC_transformed = BC_df_transform.drop(columns = ['BC_Value'])
X_BC_transformed_scaled = pd.DataFrame(StandardScaler().fit_transform(X_BC_transformed), index = X_BC_transformed.index, columns = X_BC_transformed.columns)
BC_df_transformed_scaled = y_BC_transformed.join(X_BC_transformed_scaled)

# %%
#NO2 Dataset
y_NO2_transformed = NO2_df_transform[['NO2_Value']]
X_NO2_transformed = NO2_df_transform.drop(columns = ['NO2_Value'])
X_NO2_transformed_scaled = pd.DataFrame(StandardScaler().fit_transform(X_NO2_transformed), index = X_NO2_transformed.index, columns = X_NO2_transformed.columns)
NO2_df_transformed_scaled = y_NO2_transformed.join(X_NO2_transformed_scaled)

# %% [markdown]
# ##  <b> <font size = 4> Function to create inputs to R2-VIF function for BC </b> </font>

# %%
def create_inputs_R2_vif_func_BC(X, y):
    #Calculate R2_VIF scores for training set and identify features
    input_df = pd.concat([y, X], axis = 1)
    #Update column name for X_train_BC to be of format Q('Column Name')
    output_featurelist_BC = []

    for feature_name in X.columns:
        output_featurelist_BC.append("Q('" + feature_name + "')")
    output_features_BC = ' + '.join(output_featurelist_BC)

    #  get y and X dataframes based on this regression:
    y_df, X_df = dmatrices('BC_Value ~' + output_features_BC, input_df, return_type='dataframe')
    X_df.drop(X_df.columns[0], axis = 1, inplace = True)
    return X_df, input_df

# %% [markdown]
# ##  <b> <font size = 4> Function to create inputs to R2_VIF function for NO2 </b> </font>

# %%
def create_inputs_R2_vif_func_NO2(X, y):
    #Calculate R2_VIF scores for training set and identify features
    input_df = pd.concat([y, X], axis = 1)
    #Update column name for X_train_NO2 to be of format Q('Column Name')
    output_featurelist_NO2 = []

    for feature_name in X.columns:
        output_featurelist_NO2.append("Q('" + feature_name + "')")
    output_features_NO2 = ' + '.join(output_featurelist_NO2)

    #  get y and X dataframes based on this regression:
    y_df, X_df = dmatrices('NO2_Value ~' + output_features_NO2, input_df, return_type='dataframe')
    X_df.drop(X_df.columns[0], axis = 1, inplace = True)
    return X_df, input_df

# %% [markdown]
# ## <b> <font size = 4> R2_VIF: Function to identify set of features with max R2 and low VIF scores</b> </font> </span>

# %%
## In this function, you pass the features, feature_df in the format Q(' ') and the entire dataframe with scaled values
## Input parameters are as follows
## feature_df = dataframe of all features i.e. X variables
## target_str = 'string' either 'BC_Value' or 'NO2_Value'
## df = dataframe of X and y

def calculate_R2_vif(feature_df, target_str, df):
    vif_score = []
    vif_df = pd.DataFrame()

    thresh = 10
    output = pd.DataFrame()
    output_featurelist = []
    max_R2 = 0
    k = feature_df.shape[1]
    first_feature = None
    for column in df.columns[1:]:
        r2 = sm.OLS(df[target_str], df[column]).fit().rsquared
        if r2 > max_R2:
            max_R2 = r2
            first_feature = column
    output_featurelist.append("Q('" + first_feature + "')")
    print(output_featurelist)
    
    for i in range(1,k):
        if (df.columns[i] == first_feature):
            continue
        
        output_featurelist.append(feature_df.columns[i]) # Start with the first column we identified before, and append the next column with every iteration
        
        output_features = ' + '.join(output_featurelist)
        y, X = dmatrices(target_str + '~' + output_features, df, return_type='dataframe') #Create matrix each time a column is appended

       
        #Set should drop feature as False initially
        shouldDropFeature = False

        #Check if R2 for the new model is greater than the max_R2

        if (sm.OLS(y,X).fit().rsquared) > max_R2:
            max_R2 = sm.OLS(y,X).fit().rsquared
            # For each X, calculate VIF and save in dataframe
            vif = [variance_inflation_factor(X.values, j) for j in range(X.shape[1])] #Calculate VIF score for each model
            if np.amax(vif) > thresh:    
                shouldDropFeature = True
        else:
            shouldDropFeature = True

        #print(output_featurelist)
        if shouldDropFeature:
            # Drop latest feature if VIF is > 10 OR r^2 < max r^2 for any feature after adding latest feature
            output_featurelist = output_featurelist[:-1]
            #print(output_featurelist)
            
    # Create final feature list    
    final_output_featurelist = output_featurelist
    final_output_features = ' + '.join(final_output_featurelist)

    
    #Recalculate X and Y for final feature list
    y, X = dmatrices(target_str +  '~' + final_output_features, df, return_type='dataframe')
    #Estimate VIF score for final feature list
    vif_df["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])] 
    
    vif_df["features"] = X.columns
    X.drop(columns = ['Intercept'], inplace=True)

    #Fit an OLS model for the final features that are selected and return summary statistics, VIF scores (This has to happen prior to VIF check)
    vif_ols_model = sm.OLS(y, X)
    vif_ols_results = vif_ols_model.fit()
    return vif_df, vif_ols_results.summary()

# %% [markdown]
# ##  <b> <font size = 4> Lasso Regularization with Gridsearch </b> </font>

# %%
# First define a function to calculate scores for a model

def get_cv_scores(model, X_train, y_train):
    scores = cross_val_score(model,
                             X_train,
                             y_train,
                             cv=10,
                             scoring='r2')
    
    return('CV Mean: ', np.mean(scores), 'STD: ', np.std(scores))

# %% [markdown]
# ### <b> <font size = 3>  BC dataset
# </b> </font>

# %%
# First set up the test-train split
X_train_BC, X_test_BC, y_train_BC, y_test_BC = train_test_split(X_BC_transformed_scaled, y_BC_transformed, test_size=0.30, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a75092111b16> in <module>
#       1 # First set up the test-train split
# ----> 2 X_train_BC, X_test_BC, y_train_BC, y_test_BC = train_test_split(X_BC_transformed_scaled, y_BC_transformed, test_size=0.30, random_state=0)
#
# NameError: name 'X_BC_transformed_scaled' is not defined

# %%
# Train model with default alpha=1
lasso_BC = Lasso(alpha=1).fit(X_train_BC, y_train_BC)

# get cross val scores
get_cv_scores(lasso_BC, X_train_BC, y_train_BC)
# Out:
# ('CV Mean: ', -0.0006961926159118059, 'STD: ', 0.0011057797886150414)

# %%
##Instantiate a Lasso Regularization model. Performe a LassoCV using 5-fold cross validation
lassoCV_BC = LassoCV(cv=5, alphas= None)

#Fit the model to BC X and y
lassoCV_BC.fit(X_train_BC, y_train_BC)

### Set the parameters
lasso_BC.set_params(alpha=lassoCV_BC.alpha_)

#Print the optimal valu for alpha that gives the best fit for training data
print("Best Alpha using LassoCV = ", lassoCV_BC.alpha_)


#Using this value of alpha to refit the model
lasso_BC.fit(X_train_BC, y_train_BC)


## Computing mean squared error on the test data
print("MSE on test data = ", mean_squared_error(y_test_BC, lasso_BC.predict(X_test_BC)))

## Best score using Lasso CV 
print("Best score using LassoCV: ", lasso_BC.score(X_test_BC, y_test_BC))

#Estimate model coefficients. Coefficient of zero indicates that feature can be dropped
coef_BC = pd.Series(lasso_BC.coef_, index = BC_features.columns)
# Out:
# Best Alpha using LassoCV =  0.00015531175113795207
# MSE on test data =  0.07005938189036442
# Best score using LassoCV:  0.5819077053856463

# %%
#Estimate model coefficients. Coefficient of zero indicates that feature can be dropped
coef_BC = pd.Series(lasso_BC.coef_, index = X_BC_transformed.columns)

# %%
#Display feature importance using Lasso model

#Sort the features
imp_coef = coef_BC[coef_BC !=0].sort_values()

# Plot feature importance in  bar graph
plt.figure(figsize = (10,30))
imp_coef.plot(kind = "barh", color='orange')
plt.title("Feature importance using Lasso Model for BC Dataset")
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# #### <b> <font size = 3> Calculate VIF scores for the features that were selected by Lasso </b> </font>

# %%
coef_BC[coef_BC !=0].index
# Out:
# Index(['10452611-Manufacturing-low_dist', '10453011-WWTP-medium_dist',
#        '10457011-Manufacturing-medium_dist',
#        '10457411-Manufacturing-high_dist', '10457511-Manufacturing-high_dist',
#        '10457911-ConcretePlant-medium_dist', '10460511-Retail-Res-high_dist',
#        '10461911-Waste-medium_dist', '10462111-Retail-Res-low_dist',
#        '10469511-Retail-Res-high_dist',
#        ...
#        '4955911-Manufacturing-medium_dist', '512911-FoodPlant-high_dist',
#        '771711-Eateries-high_dist', '772011-EGen-high_dist',
#        '808611-AsphaltPlant-high_dist', 'Precip', 'Mintemp', 'Pressure',
#        'Dist', 'number_intersections'],
#       dtype='object', length=171)

# %%
output_featurelist = []
i=0
for feature_name in coef_BC.index:
    score = coef_BC[i]
    if score!=0:
        output_featurelist.append("Q('" + feature_name + "')")
    i += 1
output_features_BC_Lasso = ' + '.join(output_featurelist)

# %%
vif_BC_score_Lasso = []
#  get y and X dataframes based on this regression:
y_BC_vif_lasso, X_BC_vif_lasso = dmatrices('BC_Value ~' + output_features_BC_Lasso, BC_df_transformed_scaled, return_type='dataframe')

# For each X, calculate VIF and save in dataframe
vif_BC_Lasso = pd.DataFrame()
vif_BC_Lasso["VIF Factor"] = [variance_inflation_factor(X_BC_vif_lasso.values, i) for i in range(X_BC_vif_lasso.shape[1])]
vif_BC_Lasso["features"] = X_BC_vif_lasso.columns
vif_BC_score_Lasso.append(vif_BC_Lasso.round(1))

# %%
vif_BC_score_Lasso
# Out:
# [       VIF Factor                                  features
#  0    1.000000e+00                                 Intercept
#  1    1.291200e+03      Q('10452611-Manufacturing-low_dist')
#  2    5.148320e+04            Q('10453011-WWTP-medium_dist')
#  3    4.631800e+03   Q('10457011-Manufacturing-medium_dist')
#  4    1.508744e+13     Q('10457411-Manufacturing-high_dist')
#  5    1.943800e+04     Q('10457511-Manufacturing-high_dist')
#  6    7.096800e+03   Q('10457911-ConcretePlant-medium_dist')
#  7    1.716484e+09        Q('10460511-Retail-Res-high_dist')
#  8    2.163440e+04           Q('10461911-Waste-medium_dist')
#  9    1.708945e+10         Q('10462111-Retail-Res-low_dist')
#  10   7.465000e+02        Q('10469511-Retail-Res-high_dist')
#  11   2.684330e+04      Q('10470711-Retail-Res-medium_dist')
#  12   2.738748e+05         Q('10472111-Retail-Res-low_dist')
#  13   2.526400e+03         Q('10472411-Retail-Res-low_dist')
#  14   3.059700e+03              Q('10472611-EGen-high_dist')
#  15   4.384100e+03         Q('10473411-Retail-Res-low_dist')
#  16   8.577400e+03  Q('10476911-Transportation-medium_dist')
#  17   4.255800e+03     Q('10477111-Transportation-low_dist')
#  18   9.579000e+02             Q('10477411-Waste-high_dist')
#  19   1.778743e+11      Q('10478111-Retail-Res-medium_dist')
#  20   2.648588e+06         Q('10478611-Retail-Res-low_dist')
#  21   4.055207e+09         Q('10478811-Retail-Res-low_dist')
#  22   8.665300e+03     Q('10481011-Transportation-low_dist')
#  23   7.581754e+10      Q('10496311-Retail-Res-medium_dist')
#  24   2.834800e+03      Q('10496711-Retail-Res-medium_dist')
#  25   1.724100e+03      Q('10497711-Retail-Res-medium_dist')
#  26   2.271548e+05         Q('10502611-Retail-Res-low_dist')
#  27   4.826100e+03         Q('10504811-Retail-Res-low_dist')
#  28   3.967878e+07   Q('10507111-Manufacturing-medium_dist')
#  29   1.174329e+05      Q('10510811-AsphaltPlant-high_dist')
#  30   8.373141e+07          Q('10518411-FoodPlant-low_dist')
#  31   6.398000e+02     Q('10518911-ConcretePlant-high_dist')
#  32   6.285698e+07             Q('10708011-Waste-high_dist')
#  33   3.751660e+05     Q('10708111-Manufacturing-high_dist')
#  34   1.843139e+05       Q('1088911-Retail-Res-medium_dist')
#  35   2.793700e+03         Q('1106211-Retail-Res-high_dist')
#  36   4.503000e+03          Q('1106311-Retail-Res-low_dist')
#  37   1.897990e+04       Q('1106511-Retail-Res-medium_dist')
#  38   6.324645e+09  Q('11650611-Transportation-medium_dist')
#  39   2.005840e+04        Q('127611-Retail-Res-medium_dist')
#  40   5.283100e+04        Q('127811-Retail-Res-medium_dist')
#  41   2.060297e+05        Q('130511-Retail-Res-medium_dist')
#  42   5.895100e+03  Q('13747011-Transportation-medium_dist')
#  43   2.936237e+11      Q('13748111-Retail-Res-medium_dist')
#  44   8.478306e+09        Q('13750711-Retail-Res-high_dist')
#  45   1.813200e+03        Q('13761011-Retail-Res-high_dist')
#  46   2.487488e+07  Q('13761511-Transportation-medium_dist')
#  47   2.611600e+03  Q('13777411-Transportation-medium_dist')
#  48   6.912000e+02         Q('13777911-Retail-Res-low_dist')
#  49   1.967864e+09      Q('13782611-Retail-Res-medium_dist')
#  50   1.428490e+05         Q('13783011-Retail-Res-low_dist')
#  51   7.683440e+04  Q('13787211-Transportation-medium_dist')
#  52   1.423400e+03     Q('13801611-Manufacturing-high_dist')
#  53   5.629500e+03     Q('13815311-Transportation-low_dist')
#  54   7.028000e+02  Q('13818011-Transportation-medium_dist')
#  55   5.104784e+06         Q('13818411-Retail-Res-low_dist')
#  56   5.703554e+08      Q('13818911-Retail-Res-medium_dist')
#  57   4.497200e+03      Q('13833111-Retail-Res-medium_dist')
#  58   9.260000e+02         Q('13833411-Retail-Res-low_dist')
#  59   5.216100e+03     Q('13837411-Transportation-low_dist')
#  60   2.037200e+03   Q('13983311-Manufacturing-medium_dist')
#  61   1.787513e+06       Q('140211-Manufacturing-high_dist')
#  62   2.140016e+06         Q('14059511-Retail-Res-low_dist')
#  63   3.975181e+05      Q('14115111-Retail-Res-medium_dist')
#  64   7.940000e+02        Q('14122011-Retail-Res-high_dist')
#  65   1.806411e+07      Q('14191911-Retail-Res-medium_dist')
#  66   9.695659e+05      Q('14235311-Retail-Res-medium_dist')
#  67   2.193800e+03        Q('14241511-Retail-Res-high_dist')
#  68   2.393552e+07   Q('14247611-Manufacturing-medium_dist')
#  69   2.447800e+03         Q('14249611-Retail-Res-low_dist')
#  70   9.782000e+02      Q('14251611-Retail-Res-medium_dist')
#  71   3.701520e+04  Q('14270911-Transportation-medium_dist')
#  72   1.363910e+04      Q('14271411-Retail-Res-medium_dist')
#  73   9.760100e+03  Q('14280211-Transportation-medium_dist')
#  74   8.915600e+03      Q('14295811-Retail-Res-medium_dist')
#  75   8.123300e+03         Q('14309511-Retail-Res-low_dist')
#  76   1.607400e+03         Q('14314511-Retail-Res-low_dist')
#  77   6.414700e+03      Q('14314611-Retail-Res-medium_dist')
#  78   3.161550e+04     Q('14314811-Transportation-low_dist')
#  79   6.468830e+10         Q('14318611-FoodPlant-high_dist')
#  80   7.139505e+11            Q('14334311-Misc-medium_dist')
#  81   3.612000e+03      Q('15713511-Retail-Res-medium_dist')
#  82   1.666500e+03         Q('15713811-FoodPlant-high_dist')
#  83   3.502913e+05  Q('15714811-Transportation-medium_dist')
#  84   1.321600e+03         Q('15714911-Retail-Res-low_dist')
#  85   9.982488e+11         Q('15715211-Retail-Res-low_dist')
#  86   8.389770e+04        Q('15721111-Retail-Res-high_dist')
#  87   2.190598e+07         Q('15723511-Retail-Res-low_dist')
#  88   8.932950e+04  Q('15723611-Transportation-medium_dist')
#  89   1.613000e+03      Q('15734511-Retail-Res-medium_dist')
#  90   1.890700e+03      Q('15734911-Retail-Res-medium_dist')
#  91   2.658700e+04      Q('15742311-Retail-Res-medium_dist')
#  92   1.317400e+03         Q('15746511-Retail-Res-low_dist')
#  93   7.626000e+02         Q('15755311-Retail-Res-low_dist')
#  94   3.326960e+09     Q('15755511-Manufacturing-high_dist')
#  95   3.423300e+03         Q('15925211-Retail-Res-low_dist')
#  96   1.741200e+03      Q('15941011-Retail-Res-medium_dist')
#  97   3.465520e+04         Q('15943911-Retail-Res-low_dist')
#  98   3.634507e+08      Q('16022011-Retail-Res-medium_dist')
#  99   7.118000e+02               Q('168411-Waste-high_dist')
#  100  5.254634e+05  Q('17243011-Transportation-medium_dist')
#  101  1.057100e+03      Q('17245011-Retail-Res-medium_dist')
#  102  5.613016e+06  Q('17245111-Transportation-medium_dist')
#  103  2.460400e+03      Q('17245411-Retail-Res-medium_dist')
#  104  5.575100e+03         Q('17245711-Retail-Res-low_dist')
#  105  2.268816e+13      Q('17246611-Retail-Res-medium_dist')
#  106  2.445800e+03         Q('17246811-Retail-Res-low_dist')
#  107  1.524061e+13      Q('17246911-Retail-Res-medium_dist')
#  108  3.596336e+09         Q('17247811-Retail-Res-low_dist')
#  109  1.315100e+03      Q('17248111-Retail-Res-medium_dist')
#  110  9.057388e+05         Q('17249711-Retail-Res-low_dist')
#  111  4.633333e+12      Q('17249911-Retail-Res-medium_dist')
#  112  3.995580e+04     Q('17250011-Transportation-low_dist')
#  113  4.171000e+03        Q('17250611-Retail-Res-high_dist')
#  114  4.589880e+04      Q('17251211-Retail-Res-medium_dist')
#  115  1.018170e+04  Q('17252611-Transportation-medium_dist')
#  116  1.423260e+04      Q('17252711-Retail-Res-medium_dist')
#  117  2.650608e+08      Q('18127711-Retail-Res-medium_dist')
#  118  1.047349e+14        Q('18128911-Retail-Res-high_dist')
#  119  1.125900e+14         Q('18130011-Retail-Res-low_dist')
#  120  1.232251e+06  Q('18130311-Transportation-medium_dist')
#  121  1.405900e+04         Q('18131011-Retail-Res-low_dist')
#  122  5.473574e+07         Q('18131111-Retail-Res-low_dist')
#  123  1.102536e+08   Q('18131411-Manufacturing-medium_dist')
#  124  4.604880e+04         Q('18132911-Retail-Res-low_dist')
#  125  2.456154e+05      Q('18133511-Retail-Res-medium_dist')
#  126  1.870909e+06      Q('18134111-Manufacturing-low_dist')
#  127  2.093059e+07     Q('18134511-Transportation-low_dist')
#  128  3.963041e+11         Q('18134711-Retail-Res-low_dist')
#  129  4.842559e+08        Q('18135811-Retail-Res-high_dist')
#  130  3.653270e+04         Q('18344711-Retail-Res-low_dist')
#  131  1.362690e+04         Q('18490311-Retail-Res-low_dist')
#  132  2.122400e+03         Q('18490411-Retail-Res-low_dist')
#  133  7.976000e+02            Q('18491811-WWTP-medium_dist')
#  134  1.267800e+03      Q('18493911-Retail-Res-medium_dist')
#  135  4.989500e+03   Q('18495311-Manufacturing-medium_dist')
#  136  1.135950e+04      Q('18495611-Retail-Res-medium_dist')
#  137  3.026890e+04            Q('18496311-Misc-medium_dist')
#  138  9.131700e+03      Q('18496511-Retail-Res-medium_dist')
#  139  3.301488e+06      Q('18541311-Retail-Res-medium_dist')
#  140  2.802114e+10      Q('18544711-Manufacturing-low_dist')
#  141  3.180611e+07         Q('18544811-Retail-Res-low_dist')
#  142  2.755700e+03      Q('18697211-Retail-Res-medium_dist')
#  143  8.900144e+06         Q('18697311-Retail-Res-low_dist')
#  144  2.521400e+03      Q('18697911-Retail-Res-medium_dist')
#  145  6.290879e+08   Q('18698311-Manufacturing-medium_dist')
#  146  4.980080e+04     Q('18787011-Manufacturing-high_dist')
#  147  2.467730e+04     Q('192811-Manufacturing-medium_dist')
#  148  1.064772e+06           Q('194911-Retail-Res-low_dist')
#  149  1.377337e+05      Q('200311-AsphaltPlant-medium_dist')
#  150  2.437500e+03          Q('200611-Retail-Res-high_dist')
#  151  7.401480e+06              Q('309711-Misc-medium_dist')
#  152  1.225300e+03          Q('310211-Retail-Res-high_dist')
#  153  3.305164e+10          Q('338911-Retail-Res-high_dist')
#  154  2.548100e+03           Q('343011-FoodPlant-high_dist')
#  155  2.325040e+04                Q('379511-WWTP-high_dist')
#  156  8.800100e+03                Q('382911-Misc-high_dist')
#  157  6.583300e+03          Q('400211-Retail-Res-high_dist')
#  158  2.418700e+03          Q('400311-Retail-Res-high_dist')
#  159  1.398633e+13          Q('405311-Foundaries-high_dist')
#  160  1.555077e+06      Q('444911-Transportation-high_dist')
#  161  3.969895e+08        Q('446611-Manufacturing-low_dist')
#  162  3.917900e+03    Q('4955911-Manufacturing-medium_dist')
#  163  3.163170e+04           Q('512911-FoodPlant-high_dist')
#  164  1.084060e+04            Q('771711-Eateries-high_dist')
#  165  4.791200e+03                Q('772011-EGen-high_dist')
#  166  2.401920e+13        Q('808611-AsphaltPlant-high_dist')
#  167  6.770000e+01                               Q('Precip')
#  168  3.780000e+01                              Q('Mintemp')
#  169  2.180000e+01                             Q('Pressure')
#  170  3.122000e+02                                 Q('Dist')
#  171  3.500000e+00                 Q('number_intersections')]

# %% [markdown]
# ####  <b> <font size = 3> Apply the R2_VIF function to training and test data based on features selected by Lasso </b> </font>

# %%
cols_in_BC_lasso = list(coef_BC[coef_BC !=0].index)

# %%
#Drop the intercept column from X_BC_vif_lasso
X_BC_vif_lasso.drop(columns = ['Intercept'], inplace = True)

# %%
# Create a dataframe with the feature subset
BC_lasso_subset_vif  = pd.concat([BC_All['BC_Value'], BC_All[cols_in_BC_lasso]], axis = 1)

# %%
# Split dataframe into test and train data for R2/vif estimation
X_train_lasso_BC_vif, X_test_lasso_BC_vif, y_train_lasso_BC_vif, y_test_lasso_BC_vif = train_test_split(BC_lasso_subset_vif[cols_in_BC_lasso], BC_lasso_subset_vif['BC_Value'], test_size  = 0.30, random_state=0)

# %% [markdown]
# **Training data**

# %%
X_BC_vif_lasso_train, train_df = create_inputs_R2_vif_func_BC(X_train_lasso_BC_vif, y_train_lasso_BC_vif)

# %%
#R2 and VIF scores for Training data
calculate_R2_vif(X_BC_vif_lasso_train, 'BC_Value', train_df)
# Out:
# ["Q('Mintemp')"]
# (     VIF Factor      features
#  0  13263.146002     Intercept
#  1      1.000000  Q('Mintemp'), <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:               BC_Value   R-squared (uncentered):                   0.592
#  Model:                            OLS   Adj. R-squared (uncentered):              0.592
#  Method:                 Least Squares   F-statistic:                          2.180e+04
#  Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
#  Time:                        12:09:46   Log-Likelihood:                         -13675.
#  No. Observations:               15041   AIC:                                  2.735e+04
#  Df Residuals:                   15040   BIC:                                  2.736e+04
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
#  --------------------------------------------------------------------------------
#  Q('Mintemp')     0.0627      0.000    147.637      0.000       0.062       0.064
#  ==============================================================================
#  Omnibus:                     3875.366   Durbin-Watson:                   2.018
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8540.606
#  Skew:                           1.491   Prob(JB):                         0.00
#  Kurtosis:                       5.177   Cond. No.                         1.00
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """)

# %% [markdown]
# **Test data**

# %%
X_BC_vif_lasso_test, test_df = create_inputs_R2_vif_func_BC(X_test_lasso_BC_vif, y_test_lasso_BC_vif)

# %%
#R2 and VIF scores for Training data
calculate_R2_vif(X_BC_vif_lasso_test, 'BC_Value', test_df)
# Out:
# ["Q('Mintemp')"]
# (     VIF Factor      features
#  0  13191.377213     Intercept
#  1      1.000000  Q('Mintemp'), <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:               BC_Value   R-squared (uncentered):                   0.583
#  Model:                            OLS   Adj. R-squared (uncentered):              0.583
#  Method:                 Least Squares   F-statistic:                              9017.
#  Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
#  Time:                        12:09:54   Log-Likelihood:                         -6054.4
#  No. Observations:                6447   AIC:                                  1.211e+04
#  Df Residuals:                    6446   BIC:                                  1.212e+04
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
#  --------------------------------------------------------------------------------
#  Q('Mintemp')     0.0635      0.001     94.956      0.000       0.062       0.065
#  ==============================================================================
#  Omnibus:                     2478.241   Durbin-Watson:                   1.994
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12527.370
#  Skew:                           1.794   Prob(JB):                         0.00
#  Kurtosis:                       8.810   Cond. No.                         1.00
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """)

# %% [markdown]
# <div class="alert alert-block alert-success"> <b> Based on Lasso regularization and feature selection using stepfoward VIF approach and R2 estimation, minimum temperature seems to be the feature having the highest impact of BC concentration </b> </div>

# %% [markdown]
# #### <b> <font size = 3> Fit an OLS on all the features that were selected from Lasso </b> </font>

# %%
## Fit an OLS on the remaining features
BC_OLS_Lasso = sm.OLS(BC_All['BC_Value'], BC_All[coef_BC[coef_BC !=0].index])
BC_OLS_Lasso_results = BC_OLS_Lasso.fit() 
BC_OLS_Lasso_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               BC_Value   R-squared (uncentered):                   0.860
# Model:                            OLS   Adj. R-squared (uncentered):              0.859
# Method:                 Least Squares   F-statistic:                              765.1
# Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        12:10:05   Log-Likelihood:                         -8173.4
# No. Observations:               21488   AIC:                                  1.669e+04
# Df Residuals:                   21317   BIC:                                  1.805e+04
# Df Model:                         171
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# 10452611-Manufacturing-low_dist         0.2869      0.483      0.594      0.552      -0.660       1.233
# 10453011-WWTP-medium_dist               8.1068      5.044      1.607      0.108      -1.780      17.993
# 10457011-Manufacturing-medium_dist      0.8692      0.265      3.282      0.001       0.350       1.388
# 10457411-Manufacturing-high_dist     2090.3900   4214.881      0.496      0.620   -6171.093    1.04e+04
# 10457511-Manufacturing-high_dist       12.3609      2.083      5.934      0.000       8.278      16.444
# 10457911-ConcretePlant-medium_dist    -11.2953      3.635     -3.108      0.002     -18.420      -4.171
# 10460511-Retail-Res-high_dist         896.4750    271.646      3.300      0.001     364.027    1428.923
# 10461911-Waste-medium_dist             -0.1332      0.616     -0.216      0.829      -1.340       1.074
# 10462111-Retail-Res-low_dist         1510.0920    367.764      4.106      0.000     789.247    2230.937
# 10469511-Retail-Res-high_dist           0.0614      0.265      0.232      0.817      -0.458       0.580
# 10470711-Retail-Res-medium_dist        -2.6404      3.141     -0.841      0.401      -8.797       3.516
# 10472111-Retail-Res-low_dist           22.6409      4.928      4.594      0.000      12.982      32.300
# 10472411-Retail-Res-low_dist           -0.5407      0.752     -0.719      0.472      -2.015       0.933
# 10472611-EGen-high_dist                 2.2312      0.999      2.234      0.026       0.273       4.189
# 10473411-Retail-Res-low_dist            0.1521      0.066      2.303      0.021       0.023       0.282
# 10476911-Transportation-medium_dist    20.1861      1.600     12.617      0.000      17.050      23.322
# 10477111-Transportation-low_dist        2.8894      1.159      2.493      0.013       0.618       5.161
# 10477411-Waste-high_dist                2.1998      0.254      8.659      0.000       1.702       2.698
# 10478111-Retail-Res-medium_dist     -1114.0427    798.888     -1.394      0.163   -2679.923     451.838
# 10478611-Retail-Res-low_dist            0.0814      3.491      0.023      0.981      -6.762       6.925
# 10478811-Retail-Res-low_dist          545.6098    166.879      3.269      0.001     218.515     872.705
# 10481011-Transportation-low_dist      -10.7445      1.098     -9.784      0.000     -12.897      -8.592
# 10496311-Retail-Res-medium_dist      2198.1395    979.285      2.245      0.025     278.668    4117.611
# 10496711-Retail-Res-medium_dist         2.3444      0.889      2.638      0.008       0.603       4.086
# 10497711-Retail-Res-medium_dist         2.6203      0.595      4.401      0.000       1.453       3.787
# 10502611-Retail-Res-low_dist           -3.6408      0.947     -3.845      0.000      -5.497      -1.785
# 10504811-Retail-Res-low_dist           -1.2657      0.284     -4.450      0.000      -1.823      -0.708
# 10507111-Manufacturing-medium_dist     37.6679     17.426      2.162      0.031       3.512      71.824
# 10510811-AsphaltPlant-high_dist         7.5440      6.827      1.105      0.269      -5.838      20.926
# 10518411-FoodPlant-low_dist            65.7880     23.702      2.776      0.006      19.330     112.245
# 10518911-ConcretePlant-high_dist       -0.2557      0.230     -1.114      0.265      -0.706       0.194
# 14235311-Retail-Res-medium_dist        78.6491     30.297      2.596      0.009      19.264     138.034
# 14241511-Retail-Res-high_dist           1.9048      0.836      2.278      0.023       0.266       3.543
# 14247611-Manufacturing-medium_dist    -32.5109     13.151     -2.472      0.013     -58.287      -6.734
# 14249611-Retail-Res-low_dist            1.2827      0.916      1.400      0.162      -0.513       3.078
# 14251611-Retail-Res-medium_dist        -2.4633      0.386     -6.389      0.000      -3.219      -1.708
# 14270911-Transportation-medium_dist     0.0781      0.252      0.310      0.756      -0.415       0.571
# 14271411-Retail-Res-medium_dist        -9.3474      2.678     -3.491      0.000     -14.596      -4.099
# 14280211-Transportation-medium_dist     6.2564      1.816      3.446      0.001       2.698       9.815
# 14295811-Retail-Res-medium_dist        -0.8722      0.648     -1.346      0.178      -2.142       0.398
# 14309511-Retail-Res-low_dist          -17.0912      1.430    -11.948      0.000     -19.895     -14.287
# 14314511-Retail-Res-low_dist           -1.4187      0.639     -2.222      0.026      -2.670      -0.167
# 14314611-Retail-Res-medium_dist         5.1568      1.514      3.407      0.001       2.190       8.124
# 14314811-Transportation-low_dist        8.2810      1.929      4.294      0.000       4.501      12.061
# 14318611-FoodPlant-high_dist        -5448.7042   3187.179     -1.710      0.087   -1.17e+04     798.407
# 14334311-Misc-medium_dist            1.633e+04   2456.958      6.646      0.000    1.15e+04    2.11e+04
# 15713511-Retail-Res-medium_dist        -0.4484      0.170     -2.638      0.008      -0.781      -0.115
# 15713811-FoodPlant-high_dist            0.5052      0.194      2.607      0.009       0.125       0.885
# 15714811-Transportation-medium_dist   -34.5353      2.444    -14.131      0.000     -39.326     -29.745
# 15714911-Retail-Res-low_dist            2.5258      1.788      1.413      0.158      -0.978       6.030
# 15715211-Retail-Res-low_dist        -3836.8331   1139.204     -3.368      0.001   -6069.760   -1603.907
# 15721111-Retail-Res-high_dist          -1.9367      0.858     -2.257      0.024      -3.618      -0.255
# 15723511-Retail-Res-low_dist         -296.7828    191.070     -1.553      0.120    -671.294      77.729
# 15723611-Transportation-medium_dist   -14.2763      9.987     -1.429      0.153     -33.852       5.299
# 15734511-Retail-Res-medium_dist        -2.0072      0.677     -2.965      0.003      -3.334      -0.680
# 15734911-Retail-Res-medium_dist        -0.1222      0.185     -0.660      0.509      -0.485       0.241
# 15742311-Retail-Res-medium_dist         3.1388      2.154      1.457      0.145      -1.084       7.362
# 15746511-Retail-Res-low_dist           -0.9513      0.640     -1.487      0.137      -2.205       0.303
# 15755311-Retail-Res-low_dist           -1.8785      0.349     -5.382      0.000      -2.563      -1.194
# 15755511-Manufacturing-high_dist     -553.8372    145.059     -3.818      0.000    -838.163    -269.511
# 15925211-Retail-Res-low_dist            2.6465      0.598      4.427      0.000       1.475       3.818
# 15941011-Retail-Res-medium_dist        -0.4329      0.776     -0.558      0.577      -1.955       1.089
# 15943911-Retail-Res-low_dist           15.5947      3.636      4.289      0.000       8.468      22.721
# 16022011-Retail-Res-medium_dist      1624.0335    739.688      2.196      0.028     174.189    3073.878
# 168411-Waste-high_dist                 -1.0949      0.239     -4.587      0.000      -1.563      -0.627
# Precip                                  0.5692      0.186      3.063      0.002       0.205       0.933
# Mintemp                                 1.7732      0.195      9.087      0.000       1.391       2.156
# Pressure                               -0.0287      0.003    -10.186      0.000      -0.034      -0.023
# Dist                                   -0.1286      0.034     -3.839      0.000      -0.194      -0.063
# number_intersections                    0.0001      0.001      0.142      0.887      -0.002       0.002
# ==============================================================================
# Omnibus:                     6708.731   Durbin-Watson:                   1.646
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            54003.354
# Skew:                           1.276   Prob(JB):                         0.00
# Kurtosis:                      10.335   Cond. No.                     2.76e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.76e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Creating a plot of BC concentration vs predicted concentration using OLS
sns.set_style("darkgrid")
sns.set(font_scale = 1.2)
plt.figure(figsize = (8,6))
ax = sns.regplot(x = BC_All.BC_Value, y = BC_OLS_Lasso_results.fittedvalues, fit_reg=True)
ax.set(xlabel = 'Actual BC Concentrations (ug/m3)', ylabel = 'Predicted BC Concetrations (ug/m3)')
plt.title('Actual vs. Predicted BC Concentration')
plt.text(5 , 5 ,"R2 = 0.860", fontsize = 18)
# Out:
# Text(5, 5, 'R2 = 0.860')

# %% [markdown]
# <div class="alert alert-block alert-success"> <b> This model does much better than the model that was developed just based on features that were not highly correlated. Predicted values for high concentration measurements are still pretty poor. The features selected by the Lasso model also have very high VIF scores.</b></div>

# %% [markdown]
# ### <b> <font size = 3>  NO2 dataset
# </b> </font>

# %%
# First set up the test-train split
X_train_NO2, X_test_NO2, y_train_NO2, y_test_NO2 = train_test_split(X_NO2_transformed_scaled, y_NO2_transformed, test_size=0.30, random_state=0)

# %%
# Train model with default alpha=1
lasso_NO2 = Lasso(alpha=1).fit(X_train_NO2, y_train_NO2)

# get cross val scores
get_cv_scores(lasso_NO2, X_train_NO2, y_train_NO2)
# Out:
# ('CV Mean: ', -0.0005128911866175035, 'STD: ', 0.0006258654727031758)

# %%
##Instantiate a Lasso Regularization model. Performe a LassoCV using 5-fold cross validation
lassoCV_NO2 = LassoCV(cv=5, alphas= None)

#Fit the model to BC X and y
lassoCV_NO2.fit(X_train_NO2, y_train_NO2)

### Set the parameters
lasso_NO2.set_params(alpha=lassoCV_NO2.alpha_)

#Print the optimal valu for alpha that gives the best fit for training data
print("Best Alpha using LassoCV = ", lassoCV_NO2.alpha_)


#Using this value of alpha to refit the model
lasso_NO2.fit(X_train_NO2, y_train_NO2)


## Computing mean squared error on the test data
print("MSE on test data = ", mean_squared_error(y_test_NO2, lasso_NO2.predict(X_test_NO2)))

## Best score using Lasso CV 
print("Best score using LassoCV: ", lasso_NO2.score(X_test_NO2, y_test_NO2))

#Estimate model coefficients. Coefficient of zero indicates that feature can be dropped
coef_NO2 = pd.Series(lasso_NO2.coef_, index = NO2_features.columns)
# Out:
# Best Alpha using LassoCV =  0.00041010339736882186
# MSE on test data =  0.1716660930783114
# Best score using LassoCV:  0.7033988784171415

# %%
#Estimate model coefficients. Coefficient of zero indicates that feature can be dropped
coef_NO2 = pd.Series(lasso_NO2.coef_, index = X_NO2_transformed.columns)
coef_NO2
# Out:
# 10452911-Retail-Res-high_dist         -0.000000
# 10453011-WWTP-medium_dist             -0.000636
# 10457011-Manufacturing-medium_dist     0.610643
# 10457511-Manufacturing-high_dist      -0.462947
# 10460411-Retail-Res-medium_dist       -0.043152
# 10460511-Retail-Res-high_dist          0.047153
# 10461011-Retail-Res-low_dist           0.000000
# 10461711-Retail-Res-medium_dist        0.000000
# 10461911-Waste-low_dist                0.598345
# 10462111-Retail-Res-low_dist          -0.000000
# 10466511-FoodPlant-high_dist           0.000000
# 10469511-Retail-Res-medium_dist        0.750513
# 10470711-Retail-Res-medium_dist       -0.159326
# 10471211-Retail-Res-low_dist           0.005425
# 10472111-Retail-Res-low_dist           0.046907
# 10472311-Retail-Res-medium_dist        0.000464
# 10472411-Retail-Res-medium_dist        0.000000
# 10472611-EGen-medium_dist              0.000000
# 10473411-Retail-Res-low_dist          -0.319624
# 10473611-Manufacturing-medium_dist    -0.000000
# 10476211-Retail-Res-low_dist           0.000000
# 10476911-Transportation-medium_dist   -0.386913
# 10477111-Transportation-low_dist      -0.008665
# 10478111-Retail-Res-medium_dist       -0.142849
# 10478611-Retail-Res-low_dist           0.097512
# 10478711-Retail-Res-medium_dist       -0.000000
# 10478811-Retail-Res-low_dist          -0.000000
# 10481011-Transportation-medium_dist   -0.013029
# 10487211-Retail-Res-medium_dist        0.000000
# 10488111-Retail-Res-medium_dist       -0.000000
# 10490111-Transportation-medium_dist    0.000000
# 10490611-Retail-Res-medium_dist        0.000000
# 10492211-Retail-Res-low_dist           0.000000
# 10492711-Manufacturing-medium_dist    -0.000000
# 10493211-Retail-Res-medium_dist        0.000000
# 10496311-Retail-Res-medium_dist        0.000000
# 10496511-Retail-Res-medium_dist        0.000000
# 10496711-Retail-Res-medium_dist       -0.184795
# 10497111-Retail-Res-high_dist         -0.013559
# 10497711-Retail-Res-medium_dist        0.000000
# 10498611-Transportation-medium_dist   -0.000000
# 10500811-Retail-Res-low_dist           0.000151
# 10501811-Retail-Res-medium_dist       -0.000000
# 10501911-Retail-Res-low_dist           0.000000
# 10502011-Retail-Res-medium_dist       -0.053453
# 10502111-Retail-Res-medium_dist       -0.000000
# 10502511-Retail-Res-medium_dist        0.000000
# 10502611-Retail-Res-low_dist          -0.000000
# 10502711-Retail-Res-medium_dist        0.000000
# 10503011-Retail-Res-medium_dist       -0.000000
# 10504811-Retail-Res-low_dist           0.300138
# 10505411-Manufacturing-medium_dist     0.000000
# 10506911-Retail-Res-medium_dist        0.000000
# 10510811-AsphaltPlant-high_dist       -0.083674
# 10517111-Retail-Res-high_dist         -0.000000
# 10518411-FoodPlant-medium_dist        -0.260133
# 10523411-Manufacturing-high_dist      -0.000000
# 10707511-EGen-high_dist               -0.000000
# 10708011-Waste-high_dist              -0.000000
# 10708111-Manufacturing-medium_dist    -0.014868
# 1088911-Retail-Res-medium_dist        -0.233450
# 1106211-Retail-Res-medium_dist        -0.547731
# 1106311-Retail-Res-medium_dist         0.087168
# 1106511-Retail-Res-medium_dist        -0.000000
# 1107511-Retail-Res-medium_dist        -0.000000
# 11650611-Transportation-medium_dist    0.384278
# 126911-Retail-Res-medium_dist         -0.000000
# 127111-Retail-Res-medium_dist         -0.000000
# 127511-Retail-Res-high_dist            0.000000
# 127611-Retail-Res-medium_dist          0.120568
# 127711-Retail-Res-medium_dist          0.030776
# 127811-Retail-Res-medium_dist         -0.213235
# 128211-Retail-Res-medium_dist          0.000000
# 130511-Retail-Res-medium_dist         -0.000000
# 136511-EGen-high_dist                  0.000000
# 137211-Retail-Res-high_dist           -0.000000
# 13747011-Transportation-medium_dist    0.032996
# 13747911-Retail-Res-medium_dist       -0.000000
# 13748111-Retail-Res-medium_dist       -0.000000
# 13750711-Retail-Res-high_dist          0.298884
# 13760711-Retail-Res-medium_dist       -0.000000
# 13760911-Retail-Res-high_dist          0.000000
# 13761011-Retail-Res-high_dist         -0.065527
# 13761511-Transportation-medium_dist    0.000000
# 13777411-Transportation-medium_dist    0.215658
# 13777611-Retail-Res-medium_dist        0.000000
# 13777911-Retail-Res-low_dist          -0.104419
# 13779311-Retail-Res-low_dist           0.056277
# 13782611-Retail-Res-medium_dist        0.102865
# 13783011-Retail-Res-low_dist           0.000000
# 13787211-Transportation-medium_dist   -0.000000
# 13787311-Retail-Res-medium_dist        0.000000
# 13799311-Retail-Res-medium_dist        0.000000
# 13799411-Retail-Res-low_dist           0.000000
# 13812811-Retail-Res-medium_dist        0.000000
# 13815311-Transportation-medium_dist   -0.277873
# 13818011-Transportation-medium_dist    0.368470
# 13818411-Retail-Res-low_dist          -0.099698
# 13818811-Retail-Res-medium_dist        0.000000
# 13818911-Retail-Res-medium_dist       -0.334906
# 13825511-Retail-Res-high_dist         -0.000000
# 13833111-Retail-Res-medium_dist        0.018700
# 13833411-Retail-Res-low_dist           0.010090
# 13837411-Transportation-low_dist      -0.375239
# 139211-Retail-Res-medium_dist         -0.000000
# 13980511-Retail-Res-medium_dist       -0.000000
# 13983311-Manufacturing-high_dist      -0.007279
# 13985611-Misc-high_dist                0.000000
# 140211-Manufacturing-high_dist         0.000000
# 14059411-Retail-Res-medium_dist       -0.000000
# 14059511-Retail-Res-medium_dist        0.155581
# 14071311-Retail-Res-low_dist           0.000000
# 14071611-Manufacturing-high_dist      -0.000000
# 14115111-Retail-Res-medium_dist       -0.000000
# 14115411-Retail-Res-medium_dist       -0.000000
# 14122011-Retail-Res-high_dist         -0.239645
# 141411-Retail-Res-medium_dist          0.000000
# 14167411-Retail-Res-low_dist          -0.000000
# 14179311-Retail-Res-medium_dist       -0.000000
# 14182211-Retail-Res-high_dist         -0.000000
# 14182811-Manufacturing-high_dist      -0.000000
# 14191911-Retail-Res-medium_dist        0.105054
# 14235311-Retail-Res-medium_dist       -0.000000
# 14241511-Retail-Res-high_dist          0.000000
# 14247611-Manufacturing-medium_dist     0.000000
# 14249611-Retail-Res-medium_dist        0.288077
# 14251611-Retail-Res-low_dist           0.090405
# 14258711-Retail-Res-medium_dist        0.000000
# 14267411-Manufacturing-high_dist       0.000000
# 14270911-Transportation-medium_dist    0.257375
# 14271111-Retail-Res-medium_dist        0.000000
# 14271411-Retail-Res-medium_dist       -0.117871
# 14280211-Transportation-medium_dist    0.000000
# 14286511-Retail-Res-medium_dist       -0.000000
# 14287111-Retail-Res-medium_dist       -0.000000
# 14292411-Retail-Res-high_dist          0.049803
# 14300311-Retail-Res-medium_dist       -0.000000
# 14309511-Retail-Res-medium_dist       -0.031260
# 14314511-Retail-Res-medium_dist        0.161645
# 14314611-Retail-Res-medium_dist       -0.006309
# 14314811-Transportation-medium_dist    0.497016
# 14318611-FoodPlant-high_dist           0.118399
# 15713511-Retail-Res-low_dist           0.264161
# 15713811-FoodPlant-low_dist            0.251729
# 15714811-Transportation-low_dist      -0.150793
# 15714911-Retail-Res-low_dist          -0.038182
# 15715211-Retail-Res-low_dist          -0.000000
# 15721111-Retail-Res-high_dist          0.212829
# 15723511-Retail-Res-low_dist          -0.069652
# 15723611-Transportation-low_dist      -0.000000
# 15732311-Retail-Res-medium_dist        0.000000
# 15734511-Retail-Res-high_dist          0.039983
# 15734911-Retail-Res-low_dist          -0.015681
# 15737911-Retail-Res-low_dist           0.000000
# 15742311-Retail-Res-low_dist           0.000000
# 15745711-Retail-Res-high_dist          0.022520
# 15746511-Retail-Res-low_dist           0.122479
# 15750711-Retail-Res-high_dist          0.000000
# 15754311-Retail-Res-low_dist           0.000000
# 15755311-Retail-Res-low_dist          -0.139715
# 15755411-Retail-Res-low_dist          -0.000000
# 15755511-Manufacturing-high_dist      -0.370053
# 15756011-FoodPlant-high_dist          -0.006804
# 15925211-Retail-Res-low_dist          -0.000000
# 15940511-Retail-Res-medium_dist       -0.018443
# 15941011-Retail-Res-medium_dist        0.000000
# 15941111-Retail-Res-high_dist         -0.000000
# 15941211-Retail-Res-high_dist         -0.000000
# 15942711-Retail-Res-high_dist         -0.000000
# 15943911-Retail-Res-low_dist           0.048480
# 15950611-Retail-Res-low_dist           0.000000
# 15974511-Misc-high_dist                0.000000
# 16021911-Retail-Res-medium_dist       -0.018834
# 16022011-Retail-Res-medium_dist       -0.060830
# 16080611-Retail-Res-medium_dist        0.000000
# 168111-Retail-Res-medium_dist         -0.000000
# 168411-Waste-medium_dist               0.151705
# 172211-Retail-Res-medium_dist         -0.440488
# 17243011-Transportation-medium_dist   -0.051613
# 17243711-Retail-Res-low_dist          -0.440597
# 17244111-Retail-Res-medium_dist       -0.000000
# 17244511-Retail-Res-high_dist         -0.000000
# 17245011-Retail-Res-medium_dist        0.034931
# 17245111-Transportation-medium_dist   -0.000000
# 17245411-Retail-Res-medium_dist       -0.030687
# 17245711-Retail-Res-low_dist           0.000000
# 17246611-Retail-Res-medium_dist       -0.000000
# 17246811-Retail-Res-low_dist           0.040943
# 17246911-Retail-Res-medium_dist       -0.000000
# 17247311-Retail-Res-low_dist           0.000000
# 17247811-Retail-Res-medium_dist       -0.057301
# 17247911-Retail-Res-low_dist          -0.148786
# 17248111-Retail-Res-medium_dist        0.159538
# 17248611-Retail-Res-medium_dist       -0.068214
# 17249111-Retail-Res-medium_dist       -0.000000
# 17249711-Retail-Res-low_dist           0.106708
# 17249911-Retail-Res-medium_dist       -0.084291
# 17250011-Transportation-low_dist       0.308918
# 17250611-Retail-Res-medium_dist       -0.000000
# 17251211-Retail-Res-medium_dist        0.273006
# 17252111-Manufacturing-medium_dist    -0.000000
# 17252511-Retail-Res-low_dist           0.227315
# 17252611-Transportation-medium_dist   -0.000000
# 17252711-Retail-Res-medium_dist        0.219454
# 17252811-Transportation-medium_dist    0.000000
# 18127711-Retail-Res-low_dist          -0.000000
# 18127811-Retail-Res-low_dist          -0.216442
# 18128911-Retail-Res-medium_dist       -0.160896
# 18129211-Retail-Res-medium_dist        0.000000
# 18129911-Retail-Res-medium_dist       -0.000592
# 18130011-Retail-Res-low_dist          -0.005660
# 18130211-Retail-Res-low_dist           0.000000
# 18130311-Transportation-medium_dist   -0.000000
# 18130411-Retail-Res-medium_dist        0.000000
# 18130611-Retail-Res-low_dist          -0.009835
# 18131011-Retail-Res-low_dist          -0.225996
# 18131111-Retail-Res-low_dist          -0.000000
# 18131411-Manufacturing-high_dist      -0.000000
# 18132011-Retail-Res-medium_dist        0.074781
# 18132311-Manufacturing-low_dist       -0.000000
# 18132611-Retail-Res-low_dist          -0.000000
# 18132711-Misc-high_dist                0.000000
# 18132911-Retail-Res-low_dist           0.000000
# 18133411-Retail-Res-medium_dist       -0.000000
# 18133511-Retail-Res-high_dist          0.000000
# 18134111-Manufacturing-low_dist        0.000000
# 18134211-Retail-Res-medium_dist        0.000000
# 18134411-Misc-low_dist                -0.000000
# 18134511-Transportation-low_dist      -0.000000
# 18134711-Retail-Res-low_dist          -0.000000
# 18135111-Retail-Res-medium_dist       -0.000000
# 18135811-Retail-Res-high_dist         -0.058658
# 18160711-Retail-Res-low_dist          -0.000000
# 18344711-Retail-Res-low_dist          -0.000000
# 18489911-Retail-Res-low_dist           0.000000
# 18490311-Retail-Res-medium_dist        0.000000
# 18490411-Retail-Res-medium_dist        0.011423
# 18490711-Retail-Res-medium_dist       -0.000000
# 18490811-Retail-Res-medium_dist       -0.000000
# 18491211-Retail-Res-medium_dist       -0.000000
# 18491311-Retail-Res-medium_dist       -0.000000
# 18491811-WWTP-medium_dist              0.975684
# 18492711-Retail-Res-high_dist          0.000000
# 18492911-Manufacturing-low_dist        0.000000
# 18493611-Retail-Res-low_dist           0.000000
# 18493911-Retail-Res-low_dist          -0.000000
# 18495311-Manufacturing-medium_dist    -0.869718
# 18495611-Retail-Res-high_dist          0.000000
# 18496311-Misc-medium_dist             -0.153919
# 18496511-Retail-Res-high_dist          0.148865
# 18496811-Retail-Res-medium_dist        0.000000
# 18539211-Retail-Res-medium_dist       -0.000000
# 18539311-Retail-Res-medium_dist        0.000000
# 18539511-Retail-Res-medium_dist       -0.000000
# 18539711-Retail-Res-low_dist           0.000000
# 18541311-Retail-Res-medium_dist        0.191415
# 18542011-Retail-Res-medium_dist       -0.000000
# 18542211-Retail-Res-medium_dist       -0.000000
# 18543911-Retail-Res-low_dist           0.000000
# 18544711-Manufacturing-low_dist        0.238238
# 18544811-Retail-Res-low_dist           0.071840
# 18545211-Retail-Res-medium_dist        0.000000
# 18545511-Retail-Res-medium_dist        0.000000
# 18545611-Retail-Res-medium_dist       -0.000000
# 18697111-Retail-Res-medium_dist        0.000000
# 18697211-Retail-Res-high_dist         -0.139325
# 18697311-Retail-Res-low_dist          -0.441789
# 18697911-Retail-Res-high_dist          0.156659
# 18698311-Manufacturing-medium_dist    -0.134306
# 18776511-Manufacturing-high_dist      -0.000000
# 18779811-Manufacturing-low_dist       -0.000000
# 192811-Manufacturing-medium_dist      -0.155235
# 193011-Manufacturing-medium_dist      -0.009890
# 194911-Retail-Res-low_dist             0.092880
# 195711-AutoRepair-high_dist           -0.000576
# 196511-Retail-Res-medium_dist         -0.000000
# 200311-AsphaltPlant-medium_dist        0.231218
# 200611-Retail-Res-high_dist           -0.029377
# 203811-WWTP-high_dist                 -0.000000
# 309711-Misc-medium_dist               -0.000000
# 310211-Retail-Res-high_dist            0.039203
# 310411-Retail-Res-high_dist           -0.000000
# 338911-Retail-Res-high_dist           -0.000000
# 340611-FoodPlant-high_dist             0.000000
# 343011-FoodPlant-medium_dist          -0.048100
# 375111-Eateries-high_dist             -0.000000
# 375611-AutoRepair-medium_dist         -0.000343
# 379511-WWTP-high_dist                 -0.013635
# 380611-Manufacturing-high_dist        -0.000000
# 382111-Foundaries-high_dist            0.000000
# 382911-Misc-high_dist                  0.079163
# 383511-AutoRepair-medium_dist         -0.013916
# 3963311-Foundaries-high_dist           0.000000
# 3963411-Manufacturing-high_dist       -0.000000
# 400211-Retail-Res-high_dist            0.000000
# 400311-Retail-Res-high_dist            0.161087
# 403111-Retail-Res-medium_dist         -0.000000
# 405311-Foundaries-high_dist           -0.000000
# 444911-Transportation-high_dist        0.000000
# 445511-Manufacturing-high_dist        -0.043006
# 446611-Manufacturing-low_dist          0.000000
# 448011-Retail-Res-high_dist           -0.000000
# 450311-Retail-Res-high_dist           -0.000000
# 479511-FoodPlant-low_dist             -0.000000
# 4955911-Manufacturing-high_dist       -0.000000
# 512911-FoodPlant-high_dist             0.000000
# 571611-Manufacturing-medium_dist      -0.000000
# 608411-Retail-Res-low_dist            -0.032550
# 771711-Eateries-high_dist             -0.135387
# 772011-EGen-high_dist                  0.193482
# 772611-Manufacturing-medium_dist      -0.000471
# 773811-Manufacturing-high_dist        -0.000000
# 7845611-Retail-Res-high_dist          -0.000000
# 7845711-Misc-medium_dist              -0.000000
# 804911-FoodPlant-high_dist            -0.000000
# 808611-AsphaltPlant-high_dist         -0.001771
# 808811-FoodPlant-high_dist            -0.000000
# Precip                                 0.000000
# Radiation                              0.000000
# Maxtemp                                0.000000
# Mintemp                                0.124231
# Pressure                              -0.121442
# Dist                                  -0.754162
# number_intersections                   0.060331
# dtype: float64

# %%
#Display feature importance using Lasso model

#Sort the features
imp_coef = coef_NO2[coef_NO2 !=0].sort_values()

# Plot feature importance in  bar graph
plt.figure(figsize = (10,30))
imp_coef.plot(kind = "barh", color='darkgreen')
plt.title("Feature importance using Lasso Model for NO2 Dataset")
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# #### <b> <font size = 3> Calculate VIF scores for the features selected by Lasso </b> </font>

# %%
coef_NO2[coef_NO2 !=0].index
# Out:
# Index(['10453011-WWTP-medium_dist', '10457011-Manufacturing-medium_dist',
#        '10457511-Manufacturing-high_dist', '10460411-Retail-Res-medium_dist',
#        '10460511-Retail-Res-high_dist', '10461911-Waste-low_dist',
#        '10469511-Retail-Res-medium_dist', '10470711-Retail-Res-medium_dist',
#        '10471211-Retail-Res-low_dist', '10472111-Retail-Res-low_dist',
#        ...
#        '445511-Manufacturing-high_dist', '608411-Retail-Res-low_dist',
#        '771711-Eateries-high_dist', '772011-EGen-high_dist',
#        '772611-Manufacturing-medium_dist', '808611-AsphaltPlant-high_dist',
#        'Mintemp', 'Pressure', 'Dist', 'number_intersections'],
#       dtype='object', length=137)

# %%
output_featurelist = []
i=0
for feature_name in coef_NO2.index:
    score = coef_NO2[i]
    if score!=0:
        output_featurelist.append("Q('" + feature_name + "')")
    i += 1
output_features_NO2_Lasso = ' + '.join(output_featurelist)

# %%
vif_NO2_score_Lasso = []
#  get y and X dataframes based on this regression:
y_NO2_vif_lasso, X_NO2_vif_lasso = dmatrices('NO2_Value ~' + output_features_NO2_Lasso, NO2_df_transformed_scaled, return_type='dataframe')

# For each X, calculate VIF and save in dataframe
vif_NO2_Lasso = pd.DataFrame()
vif_NO2_Lasso["VIF Factor"] = [variance_inflation_factor(X_NO2_vif_lasso.values, i) for i in range(X_NO2_vif_lasso.shape[1])]
vif_NO2_Lasso["features"] = X_NO2_vif_lasso.columns
vif_NO2_score_Lasso.append(vif_NO2_Lasso.round(1))

# %%
vif_NO2_score_Lasso
# Out:
# [       VIF Factor                                  features
#  0    1.000000e+00                                 Intercept
#  1    6.563300e+03            Q('10453011-WWTP-medium_dist')
#  2    2.634200e+03   Q('10457011-Manufacturing-medium_dist')
#  3    1.545610e+04     Q('10457511-Manufacturing-high_dist')
#  4    8.034251e+11      Q('10460411-Retail-Res-medium_dist')
#  5    2.509113e+08        Q('10460511-Retail-Res-high_dist')
#  6    1.052960e+04              Q('10461911-Waste-low_dist')
#  7    6.097000e+02      Q('10469511-Retail-Res-medium_dist')
#  8    8.540700e+03      Q('10470711-Retail-Res-medium_dist')
#  9    1.571708e+06         Q('10471211-Retail-Res-low_dist')
#  10   2.335855e+05         Q('10472111-Retail-Res-low_dist')
#  11   1.803800e+03      Q('10472311-Retail-Res-medium_dist')
#  12   2.827200e+03         Q('10473411-Retail-Res-low_dist')
#  13   8.456800e+03  Q('10476911-Transportation-medium_dist')
#  14   3.860600e+03     Q('10477111-Transportation-low_dist')
#  15   1.936886e+10      Q('10478111-Retail-Res-medium_dist')
#  16   1.041766e+06         Q('10478611-Retail-Res-low_dist')
#  17   2.650600e+03  Q('10481011-Transportation-medium_dist')
#  18   1.702900e+03      Q('10496711-Retail-Res-medium_dist')
#  19   1.547700e+03        Q('10497111-Retail-Res-high_dist')
#  20   1.847590e+04         Q('10500811-Retail-Res-low_dist')
#  21   3.409672e+06      Q('10502011-Retail-Res-medium_dist')
#  22   4.784400e+03         Q('10504811-Retail-Res-low_dist')
#  23   3.527730e+04      Q('10510811-AsphaltPlant-high_dist')
#  24   1.095224e+09       Q('10518411-FoodPlant-medium_dist')
#  25   1.290226e+06   Q('10708111-Manufacturing-medium_dist')
#  26   2.172193e+05       Q('1088911-Retail-Res-medium_dist')
#  27   2.374700e+03       Q('1106211-Retail-Res-medium_dist')
#  28   4.485600e+03       Q('1106311-Retail-Res-medium_dist')
#  29   6.023211e+08  Q('11650611-Transportation-medium_dist')
#  30   8.878800e+03        Q('127611-Retail-Res-medium_dist')
#  31   5.595036e+06        Q('127711-Retail-Res-medium_dist')
#  32   6.068400e+03        Q('127811-Retail-Res-medium_dist')
#  33   2.857900e+03  Q('13747011-Transportation-medium_dist')
#  34   3.974445e+08        Q('13750711-Retail-Res-high_dist')
#  35   1.256900e+03        Q('13761011-Retail-Res-high_dist')
#  36   2.570500e+03  Q('13777411-Transportation-medium_dist')
#  37   6.150000e+02         Q('13777911-Retail-Res-low_dist')
#  38   1.575650e+04         Q('13779311-Retail-Res-low_dist')
#  39   9.847281e+07      Q('13782611-Retail-Res-medium_dist')
#  40   1.621100e+03  Q('13815311-Transportation-medium_dist')
#  41   5.368000e+02  Q('13818011-Transportation-medium_dist')
#  42   5.857128e+06         Q('13818411-Retail-Res-low_dist')
#  43   2.902313e+08      Q('13818911-Retail-Res-medium_dist')
#  44   3.661800e+03      Q('13833111-Retail-Res-medium_dist')
#  45   1.318400e+03         Q('13833411-Retail-Res-low_dist')
#  46   5.149200e+03     Q('13837411-Transportation-low_dist')
#  47   2.020400e+03     Q('13983311-Manufacturing-high_dist')
#  48   3.826171e+05      Q('14059511-Retail-Res-medium_dist')
#  49   2.733000e+02        Q('14122011-Retail-Res-high_dist')
#  50   2.376236e+06      Q('14191911-Retail-Res-medium_dist')
#  51   2.670600e+03      Q('14249611-Retail-Res-medium_dist')
#  52   4.672000e+02         Q('14251611-Retail-Res-low_dist')
#  53   3.435630e+04  Q('14270911-Transportation-medium_dist')
#  54   4.122700e+03      Q('14271411-Retail-Res-medium_dist')
#  55   1.640700e+03        Q('14292411-Retail-Res-high_dist')
#  56   7.853400e+03      Q('14309511-Retail-Res-medium_dist')
#  57   2.278200e+03      Q('14314511-Retail-Res-medium_dist')
#  58   2.413000e+03      Q('14314611-Retail-Res-medium_dist')
#  59   2.634920e+04  Q('14314811-Transportation-medium_dist')
#  60   3.304635e+09         Q('14318611-FoodPlant-high_dist')
#  61   4.973700e+03         Q('15713511-Retail-Res-low_dist')
#  62   8.218400e+03          Q('15713811-FoodPlant-low_dist')
#  63   1.416429e+05     Q('15714811-Transportation-low_dist')
#  64   4.710000e+02         Q('15714911-Retail-Res-low_dist')
#  65   4.489260e+04        Q('15721111-Retail-Res-high_dist')
#  66   4.349577e+06         Q('15723511-Retail-Res-low_dist')
#  67   5.878000e+02        Q('15734511-Retail-Res-high_dist')
#  68   1.919000e+03         Q('15734911-Retail-Res-low_dist')
#  69   1.075580e+04        Q('15745711-Retail-Res-high_dist')
#  70   9.800000e+02         Q('15746511-Retail-Res-low_dist')
#  71   6.214000e+03         Q('15755311-Retail-Res-low_dist')
#  72   8.753365e+06     Q('15755511-Manufacturing-high_dist')
#  73   1.146428e+07         Q('15756011-FoodPlant-high_dist')
#  74   2.068000e+03      Q('15940511-Retail-Res-medium_dist')
#  75   3.010980e+04         Q('15943911-Retail-Res-low_dist')
#  76   3.144392e+06      Q('16021911-Retail-Res-medium_dist')
#  77   5.845841e+06      Q('16022011-Retail-Res-medium_dist')
#  78   3.563000e+02             Q('168411-Waste-medium_dist')
#  79   4.845000e+02        Q('172211-Retail-Res-medium_dist')
#  80   3.672590e+04  Q('17243011-Transportation-medium_dist')
#  81   9.463400e+03         Q('17243711-Retail-Res-low_dist')
#  82   9.828000e+02      Q('17245011-Retail-Res-medium_dist')
#  83   1.887400e+03      Q('17245411-Retail-Res-medium_dist')
#  84   4.858400e+03         Q('17246811-Retail-Res-low_dist')
#  85   3.605568e+06      Q('17247811-Retail-Res-medium_dist')
#  86   1.245400e+04         Q('17247911-Retail-Res-low_dist')
#  87   8.561000e+02      Q('17248111-Retail-Res-medium_dist')
#  88   3.693435e+09      Q('17248611-Retail-Res-medium_dist')
#  89   4.049121e+05         Q('17249711-Retail-Res-low_dist')
#  90   5.068767e+12      Q('17249911-Retail-Res-medium_dist')
#  91   3.790040e+04     Q('17250011-Transportation-low_dist')
#  92   3.526290e+04      Q('17251211-Retail-Res-medium_dist')
#  93   9.985400e+03         Q('17252511-Retail-Res-low_dist')
#  94   1.305810e+04      Q('17252711-Retail-Res-medium_dist')
#  95   1.456800e+03         Q('18127811-Retail-Res-low_dist')
#  96   6.004800e+13      Q('18128911-Retail-Res-medium_dist')
#  97   1.847760e+09      Q('18129911-Retail-Res-medium_dist')
#  98   5.811096e+13         Q('18130011-Retail-Res-low_dist')
#  99   6.688870e+04         Q('18130611-Retail-Res-low_dist')
#  100  4.939300e+03         Q('18131011-Retail-Res-low_dist')
#  101  3.715990e+04      Q('18132011-Retail-Res-medium_dist')
#  102  1.350194e+08        Q('18135811-Retail-Res-high_dist')
#  103  2.018900e+03      Q('18490411-Retail-Res-medium_dist')
#  104  5.363000e+02            Q('18491811-WWTP-medium_dist')
#  105  4.725000e+03   Q('18495311-Manufacturing-medium_dist')
#  106  2.916880e+04            Q('18496311-Misc-medium_dist')
#  107  1.971600e+03        Q('18496511-Retail-Res-high_dist')
#  108  1.080691e+06      Q('18541311-Retail-Res-medium_dist')
#  109  1.542212e+09      Q('18544711-Manufacturing-low_dist')
#  110  3.699151e+06         Q('18544811-Retail-Res-low_dist')
#  111  2.456700e+03        Q('18697211-Retail-Res-high_dist')
#  112  2.686366e+06         Q('18697311-Retail-Res-low_dist')
#  113  2.927200e+03        Q('18697911-Retail-Res-high_dist')
#  114  3.204632e+08   Q('18698311-Manufacturing-medium_dist')
#  115  2.321870e+04     Q('192811-Manufacturing-medium_dist')
#  116  9.731201e+11     Q('193011-Manufacturing-medium_dist')
#  117  2.053750e+04           Q('194911-Retail-Res-low_dist')
#  118  3.887440e+12          Q('195711-AutoRepair-high_dist')
#  119  1.301447e+05      Q('200311-AsphaltPlant-medium_dist')
#  120  7.534000e+02          Q('200611-Retail-Res-high_dist')
#  121  3.495000e+02          Q('310211-Retail-Res-high_dist')
#  122  2.427500e+03         Q('343011-FoodPlant-medium_dist')
#  123  7.169600e+03        Q('375611-AutoRepair-medium_dist')
#  124  8.049200e+03                Q('379511-WWTP-high_dist')
#  125  8.151900e+03                Q('382911-Misc-high_dist')
#  126  6.757656e+05        Q('383511-AutoRepair-medium_dist')
#  127  1.678600e+03          Q('400311-Retail-Res-high_dist')
#  128  2.110406e+09       Q('445511-Manufacturing-high_dist')
#  129  3.235706e+07           Q('608411-Retail-Res-low_dist')
#  130  8.621900e+03            Q('771711-Eateries-high_dist')
#  131  5.570700e+03                Q('772011-EGen-high_dist')
#  132  1.303819e+07     Q('772611-Manufacturing-medium_dist')
#  133  1.732487e+12        Q('808611-AsphaltPlant-high_dist')
#  134  2.570000e+01                              Q('Mintemp')
#  135  2.100000e+01                             Q('Pressure')
#  136  2.999000e+02                                 Q('Dist')
#  137  3.400000e+00                 Q('number_intersections')]

# %% [markdown]
# #### <b> <font size = 3> Apply the R2_VIF function to training and test data based on features selected by Lasso </b> </font>

# %%
cols_in_NO2_lasso = list(coef_NO2[coef_NO2 !=0].index)

# %%
#Drop the intercept column from X_BC_vif_lasso
X_NO2_vif_lasso.drop(columns = ['Intercept'], inplace = True)

# %%
# Create a dataframe with the feature subset
NO2_lasso_subset_vif  = pd.concat([NO2_All['NO2_Value'], NO2_All[cols_in_NO2_lasso]], axis = 1)

# %%
# Split dataframe into test and train data for R2/vif estimation
X_train_lasso_NO2_vif, X_test_lasso_NO2_vif, y_train_lasso_NO2_vif, y_test_lasso_NO2_vif = train_test_split(NO2_lasso_subset_vif[cols_in_NO2_lasso], NO2_lasso_subset_vif['NO2_Value'], test_size  = 0.30, random_state=0)

# %% [markdown]
# **Training data**

# %%
X_NO2_vif_lasso_train, train_df = create_inputs_R2_vif_func_NO2(X_train_lasso_NO2_vif, y_train_lasso_NO2_vif)

# %%
#R2 and VIF scores for Training data
calculate_R2_vif(X_NO2_vif_lasso_train, 'NO2_Value', train_df)
# Out:
# ["Q('Mintemp')"]
# (     VIF Factor      features
#  0  13263.146002     Intercept
#  1      1.000000  Q('Mintemp'), <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:              NO2_Value   R-squared (uncentered):                   0.759
#  Model:                            OLS   Adj. R-squared (uncentered):              0.759
#  Method:                 Least Squares   F-statistic:                          4.726e+04
#  Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
#  Time:                        12:15:20   Log-Likelihood:                         -55464.
#  No. Observations:               15041   AIC:                                  1.109e+05
#  Df Residuals:                   15040   BIC:                                  1.109e+05
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
#  --------------------------------------------------------------------------------
#  Q('Mintemp')     1.4864      0.007    217.395      0.000       1.473       1.500
#  ==============================================================================
#  Omnibus:                     1712.778   Durbin-Watson:                   2.017
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2353.009
#  Skew:                           0.952   Prob(JB):                         0.00
#  Kurtosis:                       3.362   Cond. No.                         1.00
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """)

# %% [markdown]
# **Test data**

# %%
X_NO2_vif_lasso_test, test_df = create_inputs_R2_vif_func_NO2(X_test_lasso_NO2_vif, y_test_lasso_NO2_vif)

# %%
#R2 and VIF scores for Training data
calculate_R2_vif(X_NO2_vif_lasso_test, 'NO2_Value', test_df)
# Out:
# ["Q('Mintemp')"]
# (     VIF Factor      features
#  0  13191.377213     Intercept
#  1      1.000000  Q('Mintemp'), <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:              NO2_Value   R-squared (uncentered):                   0.756
#  Model:                            OLS   Adj. R-squared (uncentered):              0.756
#  Method:                 Least Squares   F-statistic:                          1.994e+04
#  Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
#  Time:                        12:15:26   Log-Likelihood:                         -23884.
#  No. Observations:                6447   AIC:                                  4.777e+04
#  Df Residuals:                    6446   BIC:                                  4.778e+04
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
#  --------------------------------------------------------------------------------
#  Q('Mintemp')     1.5003      0.011    141.207      0.000       1.480       1.521
#  ==============================================================================
#  Omnibus:                      707.069   Durbin-Watson:                   1.993
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              959.616
#  Skew:                           0.934   Prob(JB):                    4.19e-209
#  Kurtosis:                       3.288   Cond. No.                         1.00
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """)

# %% [markdown]
# <div class="alert alert-block alert-success"> <b> Based on Lasso regularization and feature selection using stepfoward VIF approach and R2 estimation, minimum temperature seems to be the feature having the highest impact of NO2 concentration </b> </div>

# %% [markdown]
# #### <b> <font size = 3> Fit an OLS on the features that were selected from Lasso </b> </font>

# %%
## Fit an OLS on the remaining features
NO2_OLS_Lasso = sm.OLS(NO2_All['NO2_Value'], NO2_features[coef_NO2[coef_NO2 !=0].index])
NO2_OLS_Lasso_results = NO2_OLS_Lasso.fit() 
NO2_OLS_Lasso_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              NO2_Value   R-squared (uncentered):                   0.938
# Model:                            OLS   Adj. R-squared (uncentered):              0.938
# Method:                 Least Squares   F-statistic:                              2376.
# Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        12:15:35   Log-Likelihood:                         -64626.
# No. Observations:               21488   AIC:                                  1.295e+05
# Df Residuals:                   21351   BIC:                                  1.306e+05
# Df Model:                         137
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# 10453011-WWTP-medium_dist             -26.9334     14.806     -1.819      0.069     -55.953       2.087
# 10457011-Manufacturing-medium_dist     27.6507      2.584     10.701      0.000      22.586      32.715
# 10457511-Manufacturing-high_dist      101.8157     25.948      3.924      0.000      50.956     152.675
# 10460411-Retail-Res-medium_dist       9.06e+04   1.76e+04      5.159      0.000    5.62e+04    1.25e+05
# 10460511-Retail-Res-high_dist       -3532.8459   1061.454     -3.328      0.001   -5613.376   -1452.316
# 10461911-Waste-low_dist                19.4827      6.163      3.161      0.002       7.403      31.563
# 10469511-Retail-Res-medium_dist         0.7552      2.943      0.257      0.798      -5.014       6.525
# 10470711-Retail-Res-medium_dist       -59.4846     22.953     -2.592      0.010    -104.474     -14.496
# 10471211-Retail-Res-low_dist         1026.9992    130.637      7.861      0.000     770.942    1283.057
# 10472111-Retail-Res-low_dist          480.9915     64.384      7.471      0.000     354.793     607.190
# 10472311-Retail-Res-medium_dist        25.9168     18.064      1.435      0.151      -9.490      61.324
# 10473411-Retail-Res-low_dist            4.0331      0.760      5.303      0.000       2.542       5.524
# 10476911-Transportation-medium_dist   262.1406     21.180     12.377      0.000     220.626     303.655
# 10477111-Transportation-low_dist       16.8606     16.183      1.042      0.297     -14.858      48.580
# 10478111-Retail-Res-medium_dist     -2.802e+04   3737.426     -7.497      0.000   -3.53e+04   -2.07e+04
# 10478611-Retail-Res-low_dist           48.0705     31.409      1.530      0.126     -13.494     109.635
# 10481011-Transportation-medium_dist    12.9081      4.788      2.696      0.007       3.522      22.294
# 10496711-Retail-Res-medium_dist        71.8912      8.143      8.829      0.000      55.931      87.852
# 10497111-Retail-Res-high_dist         -17.4256      9.706     -1.795      0.073     -36.450       1.599
# 10500811-Retail-Res-low_dist            3.7354      3.248      1.150      0.250      -2.631      10.102
# 10502011-Retail-Res-medium_dist      1984.8285    648.903      3.059      0.002     712.930    3256.726
# 10504811-Retail-Res-low_dist          -36.3072      3.799     -9.558      0.000     -43.753     -28.862
# 10510811-AsphaltPlant-high_dist       -62.3989     52.569     -1.187      0.235    -165.438      40.641
# 10518411-FoodPlant-medium_dist       -236.2438   1024.974     -0.230      0.818   -2245.270    1772.783
# 10708111-Manufacturing-medium_dist    -53.4874     37.776     -1.416      0.157    -127.532      20.557
# 1088911-Retail-Res-medium_dist       -295.9974     58.704     -5.042      0.000    -411.062    -180.932
# 1106211-Retail-Res-medium_dist       -150.2977     11.431    -13.148      0.000    -172.703    -127.892
# 1106311-Retail-Res-medium_dist        152.1451     15.272      9.962      0.000     122.210     182.080
# 11650611-Transportation-medium_dist  5368.1864   1778.191      3.019      0.003    1882.798    8853.575
# 127611-Retail-Res-medium_dist          -5.6735     20.408     -0.278      0.781     -45.674      34.327
# 127711-Retail-Res-medium_dist        -343.7385    111.053     -3.095      0.002    -561.411    -126.067
# 127811-Retail-Res-medium_dist         111.3645     16.935      6.576      0.000      78.170     144.559
# 13747011-Transportation-medium_dist   -15.4882      8.406     -1.842      0.065     -31.965       0.989
# 13750711-Retail-Res-high_dist       -1.115e+04   9342.452     -1.193      0.233   -2.95e+04    7166.536
# 13761011-Retail-Res-high_dist           8.2532      3.003      2.748      0.006       2.367      14.139
# 13777411-Transportation-medium_dist     7.3320      2.675      2.741      0.006       2.089      12.575
# 13777911-Retail-Res-low_dist          -41.8455     10.596     -3.949      0.000     -62.615     -21.076
# 13779311-Retail-Res-low_dist          163.1793     16.295     10.014      0.000     131.240     195.119
# 13782611-Retail-Res-medium_dist      -671.0165    770.861     -0.870      0.384   -2181.962     839.929
# 13815311-Transportation-medium_dist   -57.8194      5.197    -11.126      0.000     -68.005     -47.634
# 13818011-Transportation-medium_dist    52.0446      2.216     23.489      0.000      47.702      56.388
# 13818411-Retail-Res-low_dist         -282.8470     56.080     -5.044      0.000    -392.769    -172.925
# 13818911-Retail-Res-medium_dist     -3267.8555    584.014     -5.596      0.000   -4412.566   -2123.145
# 13833111-Retail-Res-medium_dist       -11.6942     32.234     -0.363      0.717     -74.874      51.486
# 13833411-Retail-Res-low_dist            7.3881      8.004      0.923      0.356      -8.300      23.076
# 13837411-Transportation-low_dist     -105.2768      9.914    -10.619      0.000    -124.710     -85.844
# 13983311-Manufacturing-high_dist      -20.0038      2.554     -7.833      0.000     -25.010     -14.998
# 14059511-Retail-Res-medium_dist        -4.8928     29.383     -0.167      0.868     -62.486      52.700
# 14122011-Retail-Res-high_dist          -2.2800      1.871     -1.219      0.223      -5.947       1.387
# 14191911-Retail-Res-medium_dist       615.6068    196.050      3.140      0.002     231.334     999.880
# 14249611-Retail-Res-medium_dist        21.1268     12.210      1.730      0.084      -2.806      45.060
# 14251611-Retail-Res-low_dist           -5.6601      3.218     -1.759      0.079     -11.968       0.648
# 14270911-Transportation-medium_dist    13.6311      3.290      4.144      0.000       7.183      20.079
# 14271411-Retail-Res-medium_dist       -93.0798     15.072     -6.176      0.000    -122.623     -63.537
# 14292411-Retail-Res-high_dist         -10.2211      6.862     -1.490      0.136     -23.671       3.229
# 14309511-Retail-Res-medium_dist      -293.6461     18.532    -15.845      0.000    -329.970    -257.322
# 14314511-Retail-Res-medium_dist       -62.0222      9.444     -6.568      0.000     -80.533     -43.512
# 14314611-Retail-Res-medium_dist         8.0547      9.779      0.824      0.410     -11.114      27.223
# 14314811-Transportation-medium_dist   -20.1139     24.634     -0.816      0.414     -68.399      28.172
# 14318611-FoodPlant-high_dist         2.957e+04   3.44e+04      0.859      0.390   -3.79e+04     9.7e+04
# 15713511-Retail-Res-low_dist          -16.4061      2.903     -5.652      0.000     -22.096     -10.716
# 15713811-FoodPlant-low_dist            44.3474      6.649      6.670      0.000      31.315      57.380
# 15714811-Transportation-low_dist     -359.3335     26.432    -13.595      0.000    -411.141    -307.526
# 15714911-Retail-Res-low_dist           -8.0430      6.908     -1.164      0.244     -21.583       5.497
# 15721111-Retail-Res-high_dist          10.9164      9.129      1.196      0.232      -6.977      28.810
# 15723511-Retail-Res-low_dist        -2165.8267    750.787     -2.885      0.004   -3637.426    -694.227
# 15734511-Retail-Res-high_dist          24.7695      4.289      5.775      0.000      16.363      33.176
# 15734911-Retail-Res-low_dist           10.6672      2.607      4.092      0.000       5.557      15.777
# 15745711-Retail-Res-high_dist        -108.3442     11.413     -9.493      0.000    -130.715     -85.973
# 15746511-Retail-Res-low_dist           -5.1121      6.486     -0.788      0.431     -17.825       7.601
# 15755311-Retail-Res-low_dist          -62.1205     17.034     -3.647      0.000     -95.508     -28.733
# 15755511-Manufacturing-high_dist      551.0867     97.889      5.630      0.000     359.218     742.956
# 15756011-FoodPlant-high_dist          182.1370     92.842      1.962      0.050       0.160     364.114
# 15940511-Retail-Res-medium_dist        -2.5962     10.932     -0.237      0.812     -24.024      18.832
# 15943911-Retail-Res-low_dist           37.3264     45.663      0.817      0.414     -52.177     126.830
# 16021911-Retail-Res-medium_dist      2150.5027    806.921      2.665      0.008     568.877    3732.128
# 16022011-Retail-Res-medium_dist     -2599.4608   1168.504     -2.225      0.026   -4889.816    -309.106
# 168411-Waste-medium_dist               -6.3391      1.772     -3.577      0.000      -9.812      -2.866
# 172211-Retail-Res-medium_dist         -12.1872      0.945    -12.894      0.000     -14.040     -10.335
# 17243011-Transportation-medium_dist   -73.0756     11.998     -6.091      0.000     -96.592     -49.560
# 17243711-Retail-Res-low_dist          -13.1006     21.796     -0.601      0.548     -55.822      29.621
# 17245011-Retail-Res-medium_dist        40.1271      4.007     10.014      0.000      32.273      47.981
# 17245411-Retail-Res-medium_dist       -23.1892     13.564     -1.710      0.087     -49.777       3.398
# 17246811-Retail-Res-low_dist           22.1821      2.277      9.742      0.000      17.719      26.645
# 194911-Retail-Res-low_dist            -76.0832     22.690     -3.353      0.001    -120.558     -31.609
# 195711-AutoRepair-high_dist          4.345e+05   6.27e+04      6.932      0.000    3.12e+05    5.57e+05
# 200311-AsphaltPlant-medium_dist      -327.0385     49.822     -6.564      0.000    -424.694    -229.383
# 200611-Retail-Res-high_dist           -36.1225      3.735     -9.670      0.000     -43.444     -28.801
# 310211-Retail-Res-high_dist             3.9205      4.116      0.952      0.341      -4.147      11.988
# 343011-FoodPlant-medium_dist           63.2774      8.553      7.398      0.000      46.513      80.042
# 375611-AutoRepair-medium_dist          48.8234     19.888      2.455      0.014       9.841      87.805
# 379511-WWTP-high_dist                 -48.0535      7.042     -6.824      0.000     -61.856     -34.251
# 382911-Misc-high_dist                  47.0295      4.788      9.822      0.000      37.644      56.415
# 383511-AutoRepair-medium_dist         113.1270     32.415      3.490      0.000      49.590     176.664
# 400311-Retail-Res-high_dist            23.3807      6.804      3.436      0.001      10.045      36.717
# 445511-Manufacturing-high_dist        498.7167   1433.370      0.348      0.728   -2310.797    3308.230
# 608411-Retail-Res-low_dist             77.3407    168.135      0.460      0.646    -252.216     406.897
# 771711-Eateries-high_dist               2.8502     18.708      0.152      0.879     -33.818      39.519
# 772011-EGen-high_dist                 -13.7920      8.260     -1.670      0.095     -29.982       2.398
# 772611-Manufacturing-medium_dist      235.2915    128.476      1.831      0.067     -16.532     487.115
# 808611-AsphaltPlant-high_dist        -1.08e+04   1.93e+04     -0.559      0.576   -4.87e+04    2.71e+04
# Mintemp                                18.2585      1.837      9.937      0.000      14.657      21.860
# Pressure                               -0.1485      0.034     -4.375      0.000      -0.215      -0.082
# Dist                                   -5.4560      0.521    -10.475      0.000      -6.477      -4.435
# number_intersections                    0.1042      0.013      7.755      0.000       0.078       0.131
# ==============================================================================
# Omnibus:                     3649.525   Durbin-Watson:                   1.525
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12949.840
# Skew:                           0.839   Prob(JB):                         0.00
# Kurtosis:                       6.413   Cond. No.                     2.76e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.76e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Creating a plot of NO2 concentration vs predicted concentration using OLS
sns.set_style("darkgrid")
sns.set(font_scale = 1.2)
plt.figure(figsize = (8,6))
ax = sns.regplot(x = NO2_All.NO2_Value, y = NO2_OLS_Lasso_results.fittedvalues, fit_reg=True)
ax.set(xlabel = 'Actual NO2 Concentrations (ppb)', ylabel = 'Predicted NO2 Concetrations (ppb)')
plt.title('Actual vs. Predicted NO2 Concentration')
plt.text(48 , 5 ,"R2 = 0.938", fontsize = 18)
# Out:
# Text(48, 5, 'R2 = 0.938')

# %% [markdown]
# <div class="alert alert-block alert-success"> <b> This model does much better than the model that was developed just based on features that were not highly correlated. Predicted values for high concentration measurements are still pretty poor. The features selected by the Lasso model also have very high VIF scores.</b></div>

# %% [markdown]
# ##  <b> <font size = 4>  Step Forward Approach with VIF Scores estimation </b> </font>

# %% [markdown]
# The approach here is to keep adding features sequentially, each time calculate the R2 value and see that's better than the previous R2. If the R2 is higher, then we calculate the VIF score with addition of each feature. If the VIF score of any of the features increases above threshold of 10, then we drop the newly added feature.

# %% [markdown]
# ### <b> <font size = 3>  BC Dataset </b> </font>

# %% [markdown]
# <b> <font size = 3> <span style="color:blue"> First, create a dataframe with y and standardized x values. Then create a dataframe in VIF format i.e. each column header should be Q('column name'), except the target variable.   </b> </font> </span>

# %%
y_BC_vif_df = BC_All[['BC_Value']]
X_BC_vif_df = BC_All.drop(columns = ['BC_Value'])
X_BC_scaled_vif_df = pd.DataFrame(StandardScaler().fit_transform(X_BC_vif_df), index = X_BC_vif_df.index, columns = X_BC_vif_df.columns)

# %% [markdown]
# <b> <font size = 3> <span style="color:blue">  Dataframe for VIF and Regressions </b> </font> </span>

# %%
# Split dataframe into test and train data for R2/vif estimation
X_train_BC_vif, X_test_BC_vif, y_train_BC_vif, y_test_BC_vif = train_test_split(X_BC_vif_df , y_BC_vif_df, test_size  = 0.30, random_state=0)

# %% [markdown]
# **Training Data**

# %%
X_BC_vif_train, BC_vif_df_train = create_inputs_R2_vif_func_BC(X_train_BC_vif, y_train_BC_vif)

# %%
calculate_R2_vif(X_BC_vif_train, 'BC_Value', BC_vif_df_train)
# Out:
# ["Q('Radiation')"]
# (     VIF Factor        features
#  0  46676.348204       Intercept
#  1      1.000000  Q('Radiation'), <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:               BC_Value   R-squared (uncentered):                   0.593
#  Model:                            OLS   Adj. R-squared (uncentered):              0.593
#  Method:                 Least Squares   F-statistic:                          2.190e+04
#  Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
#  Time:                        12:16:25   Log-Likelihood:                         -13655.
#  No. Observations:               15041   AIC:                                  2.731e+04
#  Df Residuals:                   15040   BIC:                                  2.732e+04
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
#  ----------------------------------------------------------------------------------
#  Q('Radiation')     0.0021   1.42e-05    147.979      0.000       0.002       0.002
#  ==============================================================================
#  Omnibus:                     3927.252   Durbin-Watson:                   2.017
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8782.050
#  Skew:                           1.502   Prob(JB):                         0.00
#  Kurtosis:                       5.234   Cond. No.                         1.00
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """)

# %% [markdown]
# **Test Data**

# %%
X_BC_vif_test, BC_vif_df_test = create_inputs_R2_vif_func_BC(X_test_BC_vif, y_test_BC_vif)

# %%
calculate_R2_vif(X_BC_vif_test, 'BC_Value', BC_vif_df_test)
# Out:
# ["Q('Radiation')"]
# (     VIF Factor        features
#  0  46894.386704       Intercept
#  1      1.000000  Q('Radiation'), <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:               BC_Value   R-squared (uncentered):                   0.584
#  Model:                            OLS   Adj. R-squared (uncentered):              0.584
#  Method:                 Least Squares   F-statistic:                              9059.
#  Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
#  Time:                        12:16:30   Log-Likelihood:                         -6045.7
#  No. Observations:                6447   AIC:                                  1.209e+04
#  Df Residuals:                    6446   BIC:                                  1.210e+04
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
#  ----------------------------------------------------------------------------------
#  Q('Radiation')     0.0021   2.24e-05     95.176      0.000       0.002       0.002
#  ==============================================================================
#  Omnibus:                     2496.187   Durbin-Watson:                   1.995
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12776.889
#  Skew:                           1.804   Prob(JB):                         0.00
#  Kurtosis:                       8.877   Cond. No.                         1.00
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """)

# %% [markdown]
# <div class="alert alert-block alert-success"> <b> Based on the step forward VIF approach with R2, 'Radiation' was the only feature that was selected. This indicates Radiation is highly correlated with BC concentration.</b></div>

# %% [markdown]
# ### <b> <font size = 3>  NO2 Dataset </b> </font>

# %% [markdown]
# <b> <font size = 3> <span style="color:blue"> First, create a dataframe with y and standardized x values. Then create a dataframe in VIF format i.e. each column header should be Q('column name'), except the target variable.   </b> </font> </span>

# %%
y_NO2_vif_df = NO2_All[['NO2_Value']]
X_NO2_vif_df = NO2_All.drop(columns = ['NO2_Value'])
X_NO2_scaled_vif_df = pd.DataFrame(StandardScaler().fit_transform(X_NO2_vif_df), index = X_NO2_vif_df.index, columns = X_NO2_vif_df.columns)

# %% [markdown]
# <b> <font size = 3> <span style="color:blue">  Dataframe for VIF and Regressions </b> </font> </span>

# %%
# Split dataframe into test and train data for R2/vif estimation
X_train_NO2_vif, X_test_NO2_vif, y_train_NO2_vif, y_test_NO2_vif = train_test_split(X_NO2_vif_df , y_NO2_vif_df, test_size  = 0.30, random_state=0)

# %% [markdown]
# **Training Data**

# %%
X_NO2_vif_train, NO2_vif_df_train = create_inputs_R2_vif_func_NO2(X_train_NO2_vif, y_train_NO2_vif)

# %%
calculate_R2_vif(X_NO2_vif_train, 'NO2_Value', NO2_vif_df_train)
# Out:
# ["Q('Radiation')"]
# (     VIF Factor        features
#  0  46676.348204       Intercept
#  1      1.000000  Q('Radiation'), <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:              NO2_Value   R-squared (uncentered):                   0.759
#  Model:                            OLS   Adj. R-squared (uncentered):              0.759
#  Method:                 Least Squares   F-statistic:                          4.748e+04
#  Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
#  Time:                        12:16:41   Log-Likelihood:                         -55437.
#  No. Observations:               15041   AIC:                                  1.109e+05
#  Df Residuals:                   15040   BIC:                                  1.109e+05
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
#  ----------------------------------------------------------------------------------
#  Q('Radiation')     0.0499      0.000    217.896      0.000       0.049       0.050
#  ==============================================================================
#  Omnibus:                     1777.290   Durbin-Watson:                   2.016
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2467.291
#  Skew:                           0.969   Prob(JB):                         0.00
#  Kurtosis:                       3.425   Cond. No.                         1.00
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """)

# %% [markdown]
# **Test Data**

# %%
X_NO2_vif_test, NO2_vif_df_test = create_inputs_R2_vif_func_NO2(X_test_NO2_vif, y_test_NO2_vif)

# %%
calculate_R2_vif(X_NO2_vif_test, 'NO2_Value', NO2_vif_df_test)
# Out:
# ["Q('Radiation')"]
# (     VIF Factor        features
#  0  46894.386704       Intercept
#  1      1.000000  Q('Radiation'), <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                   OLS Regression Results
#  =======================================================================================
#  Dep. Variable:              NO2_Value   R-squared (uncentered):                   0.757
#  Model:                            OLS   Adj. R-squared (uncentered):              0.757
#  Method:                 Least Squares   F-statistic:                          2.004e+04
#  Date:                Sun, 28 Jun 2020   Prob (F-statistic):                        0.00
#  Time:                        12:16:46   Log-Likelihood:                         -23872.
#  No. Observations:                6447   AIC:                                  4.775e+04
#  Df Residuals:                    6446   BIC:                                  4.775e+04
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
#  ----------------------------------------------------------------------------------
#  Q('Radiation')     0.0504      0.000    141.555      0.000       0.050       0.051
#  ==============================================================================
#  Omnibus:                      732.467   Durbin-Watson:                   1.995
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1003.036
#  Skew:                           0.950   Prob(JB):                    1.56e-218
#  Kurtosis:                       3.348   Cond. No.                         1.00
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """)

# %% [markdown]
# <div class="alert alert-block alert-success"> <b> Similar to BC dataset, based on the step forward VIF approach with R2, 'Radiation' was the only feature that was selected. This indicates Radiation is highly correlated with NO2 concentration.</b></div>

# %% [markdown]
# ##  <b> <font size = 4>  Principal Component Analysis  - Input Dataset</b> </font>

# %% [markdown]
# ### <b> <font size = 3>  BC Dataset</b> </font>

# %%
y_BC_original = BC_All[['BC_Value']]
X_BC_original = BC_All.drop(columns = 'BC_Value')

# %%
# Create the test train split again from the original data, without scaling
X_train_BC_PCA, X_test_BC_PCA, y_train_BC_PCA, y_test_BC_PCA = train_test_split(X_BC_original, y_BC_original, test_size=0.30, random_state=0)

# %% [markdown]
# ### <b> <font size = 3> NO2 Dataset</b> </font>

# %%
y_NO2_original = NO2_All[['NO2_Value']]
X_NO2_original = NO2_All.drop(columns = 'NO2_Value')

# %%
# Create the test train split again from the original data, without scaling
X_train_NO2_PCA, X_test_NO2_PCA, y_train_NO2_PCA, y_test_NO2_PCA = train_test_split(X_NO2_original, y_NO2_original, test_size=0.30, random_state=0)

# %% [markdown]
# The PCA + DecisionTree Regressor resulted in the selection of 50 components, and the mean cross validation score for the test dataset is 0.78. Predicting the 'y' value based on the model results in an R2 value of 0.88. 99% of the variance in the model is explained with these 50 selected components.

# %% [markdown]
# ## <b> <font size = 4>   Random Forest and Cross Validation for Feature Selection  </font></b>

# %% [markdown]
# ### <b> <font size = 3> BC Dataset</b> </font>

# %%
y_BC_original = BC_All[['BC_Value']]
X_BC_original = BC_All.drop(columns = 'BC_Value')

# %%
## Test Train split 
X_BC_original_train, X_BC_original_test, y_BC_original_train, y_BC_original_test = train_test_split(X_BC_original, y_BC_original, test_size = 0.3, random_state = 0)

# %% [markdown]
# **Feature selection using cross validation**

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits = 4)
RFRegressor = RandomForestRegressor(random_state = 0, n_estimators = 100, n_jobs = -1, max_features = 'auto')
count = 1


feature_names = ['{}'.format(name) for name in X_BC_original.columns]

BC_feature_importance_df = pd.DataFrame({'feature': [], 'importance': [], 'fold': []})

for train, _ in kf.split(X_BC_original, y_BC_original):
    RFRegressor.fit(X_BC_original.iloc[train,:], y_BC_original.iloc[train])
    BC_featureimp_index = np.argsort(RFRegressor.feature_importances_)[::-1]
    BC_labels = [feature_names[-i] for i in BC_featureimp_index]
    
    d = {'feature': BC_labels, 'importance': RFRegressor.feature_importances_[BC_featureimp_index], 'fold': count}
    BC_feature_importance_df = BC_feature_importance_df.append(pd.DataFrame(d))
    count = count + 1
    
#     # plot
#     plt.figure(figsize = (15,15))
#     plt.bar(BC_labels, RFRegressor.feature_importances_[BC_featureimp_index])
#     plt.xticks(BC_labels, rotation='vertical')
#     plt.ylabel('Importance')
#     plt.xlabel('Features')
#     plt.title('Fold {}'.format(count))
#     count = count + 1
# plt.show()

# %%
#Reset index and drop the column containin repeating indices
BC_feature_importance_df.reset_index(inplace=True)
BC_feature_importance_df.drop(columns = ['index'], inplace=True)

# %%
#Calculate the mean score of all features from cross validation and reset index
BC_feature_importance_df = BC_feature_importance_df.groupby('feature').describe()['importance']
BC_feature_importance_df.reset_index(inplace=True)

# %%
BC_feature_importance_df.head(370)
# Out:
#                                  feature  count      mean       std       min  \
# 96   13761511-Transportation-medium_dist    4.0  0.084706  0.133708  0.003013
# 273      18541311-Retail-Res-medium_dist    4.0  0.068587  0.109462  0.008055
# 7          10457711-Foundaries-high_dist    4.0  0.060878  0.117725  0.000088
# 124       140211-Manufacturing-high_dist    4.0  0.001698  0.001116  0.000761
# 229  18130311-Transportation-medium_dist    4.0  0.001661  0.000306  0.001221
# 33       10478711-Retail-Res-medium_dist    4.0  0.001638  0.001475  0.000430
# 122   13983311-Manufacturing-medium_dist    4.0  0.001588  0.000951  0.000542
# 302          203711-Retail-Res-high_dist    4.0  0.001577  0.000511  0.000896
# 126         14059511-Retail-Res-low_dist    4.0  0.001573  0.001148  0.000337
# 200      17245011-Retail-Res-medium_dist    4.0  0.001552  0.001858  0.000332
# 260        18492711-Retail-Res-high_dist    4.0  0.001548  0.001806  0.000312
# 15          10466511-FoodPlant-high_dist    4.0  0.001547  0.001189  0.000671
# 325          405311-Foundaries-high_dist    4.0  0.001523  0.000835  0.000287
# 192      16022011-Retail-Res-medium_dist    4.0  0.001520  0.001294  0.000443
# 240         18133411-Retail-Res-low_dist    4.0  0.001518  0.000719  0.000683
# 215        17250611-Retail-Res-high_dist    4.0  0.001503  0.000512  0.000846
# 146      14271111-Retail-Res-medium_dist    4.0  0.001492  0.001107  0.000420
# 42       10493211-Retail-Res-medium_dist    4.0  0.001491  0.001062  0.000477
# 307        337111-Manufacturing-low_dist    4.0  0.001422  0.001017  0.000637
# 272         18539711-Retail-Res-low_dist    4.0  0.001422  0.001043  0.000713
# 353                            Radiation    4.0  0.001382  0.000907  0.000335
# 309          338911-Retail-Res-high_dist    4.0  0.001374  0.000903  0.000452
# 11          10461011-Retail-Res-low_dist    4.0  0.001363  0.000624  0.000512
# 72        1088911-Retail-Res-medium_dist    4.0  0.001346  0.001595  0.000370
# 0        10452611-Manufacturing-low_dist    4.0  0.001338  0.001384  0.000417
# 194        168111-Retail-Res-medium_dist    4.0  0.001319  0.000474  0.000912
# 70              10708011-Waste-high_dist    4.0  0.001315  0.000534  0.000574
# 20       10472311-Retail-Res-medium_dist    4.0  0.001315  0.000715  0.000491
# 282        18697111-Retail-Res-high_dist    4.0  0.001310  0.000919  0.000477
# 27   10476911-Transportation-medium_dist    4.0  0.001285  0.001146  0.000349
# 209      17248111-Retail-Res-medium_dist    4.0  0.001283  0.000855  0.000376
# 51          10500811-Retail-Res-low_dist    4.0  0.001283  0.000635  0.000549
# 326      444911-Transportation-high_dist    4.0  0.001281  0.001010  0.000578
# 154         14309511-Retail-Res-low_dist    4.0  0.001280  0.001174  0.000450
# 334    4955911-Manufacturing-medium_dist    4.0  0.001280  0.001001  0.000338
# 261      18492911-Manufacturing-low_dist    4.0  0.001276  0.000400  0.000788
# 107         13799411-Retail-Res-low_dist    4.0  0.001262  0.000747  0.000456
# 258      18491311-Retail-Res-medium_dist    4.0  0.001257  0.000303  0.000812
# 118     13837411-Transportation-low_dist    4.0  0.001255  0.000621  0.000476
# 74          1106211-Retail-Res-high_dist    4.0  0.001253  0.000511  0.000694
# 288     18776211-Manufacturing-high_dist    4.0  0.001250  0.001012  0.000346
# 349                              Maxtemp    4.0  0.001234  0.000897  0.000378
# 143      14258711-Retail-Res-medium_dist    4.0  0.001208  0.000427  0.000585
# 136     14182811-Manufacturing-high_dist    4.0  0.001206  0.000987  0.000416
# 304              309711-Misc-medium_dist    4.0  0.001205  0.000493  0.000472
# 61    10505411-Manufacturing-medium_dist    4.0  0.001203  0.000981  0.000358
# 196        172211-Retail-Res-medium_dist    4.0  0.001202  0.000559  0.000592
# 112         13818411-Retail-Res-low_dist    4.0  0.001199  0.000481  0.000813
# 312            375111-Eateries-high_dist    4.0  0.001186  0.000398  0.000708
# 89   13747011-Transportation-medium_dist    4.0  0.001184  0.000394  0.000718
# 44    10495311-Manufacturing-medium_dist    4.0  0.001171  0.000493  0.000530
# 139        14241511-Retail-Res-high_dist    4.0  0.001124  0.000719  0.000358
# 119          138911-AutoRepair-high_dist    4.0  0.001111  0.000988  0.000474
# 193      16080611-Retail-Res-medium_dist    4.0  0.001101  0.001121  0.000388
# 92         13750711-Retail-Res-high_dist    4.0  0.001092  0.000191  0.000928
# 339            771711-Eateries-high_dist    4.0  0.001082  0.000791  0.000532
# 255      18490711-Retail-Res-medium_dist    4.0  0.001079  0.000224  0.000833
# 254         18490411-Retail-Res-low_dist    4.0  0.001076  0.000665  0.000481
# 315       380611-Manufacturing-high_dist    4.0  0.001076  0.000855  0.000400
# 26      10476711-Manufacturing-high_dist    4.0  0.001073  0.001335  0.000290
# 155         14314511-Retail-Res-low_dist    4.0  0.001058  0.000414  0.000728
# 25       10476211-Retail-Res-medium_dist    4.0  0.001055  0.000467  0.000510
# 29       10477311-Retail-Res-medium_dist    4.0  0.001053  0.000231  0.000746
# 328        446611-Manufacturing-low_dist    4.0  0.001044  0.000662  0.000288
# 183      15940511-Retail-Res-medium_dist    4.0  0.001023  0.000391  0.000485
# 24    10473611-Manufacturing-medium_dist    4.0  0.001020  0.000345  0.000575
# 251         18344711-Retail-Res-low_dist    4.0  0.001012  0.000809  0.000419
# 46       10496511-Retail-Res-medium_dist    4.0  0.001010  0.000594  0.000524
# 279      18545211-Retail-Res-medium_dist    4.0  0.001008  0.000202  0.000723
# 321      3963411-Manufacturing-high_dist    4.0  0.001006  0.000406  0.000408
# 203         17245711-Retail-Res-low_dist    4.0  0.001004  0.000164  0.000835
# 249        18135811-Retail-Res-high_dist    4.0  0.000997  0.000505  0.000357
# 184      15941011-Retail-Res-medium_dist    4.0  0.000995  0.000266  0.000602
# 91       13748111-Retail-Res-medium_dist    4.0  0.000988  0.000452  0.000537
# 13            10461911-Waste-medium_dist    4.0  0.000983  0.000134  0.000863
# 345         804911-FoodPlant-medium_dist    4.0  0.000979  0.000463  0.000509
# 39          10490611-Retail-Res-low_dist    4.0  0.000973  0.000307  0.000521
# 320         3963311-Foundaries-high_dist    4.0  0.000959  0.000755  0.000247
# 277      18544711-Manufacturing-low_dist    4.0  0.000955  0.000458  0.000470
# 201  17245111-Transportation-medium_dist    4.0  0.000951  0.000474  0.000284
# 182         15925211-Retail-Res-low_dist    4.0  0.000932  0.000723  0.000312
# 354                 number_intersections    4.0  0.000925  0.000130  0.000821
# 134      14179311-Retail-Res-medium_dist    4.0  0.000581  0.000219  0.000292
# 297           194911-Retail-Res-low_dist    4.0  0.000574  0.000132  0.000398
# 99          13777911-Retail-Res-low_dist    4.0  0.000571  0.000390  0.000277
# 316          382111-Foundaries-high_dist    4.0  0.000568  0.000151  0.000352
# 133         14167411-Retail-Res-low_dist    4.0  0.000566  0.000313  0.000281
# 308           338411-AutoRepair-low_dist    4.0  0.000561  0.000157  0.000396
# 97   13777411-Transportation-medium_dist    4.0  0.000559  0.000377  0.000233
# 109         13812811-Retail-Res-low_dist    4.0  0.000557  0.000359  0.000257
# 64       10510811-AsphaltPlant-high_dist    4.0  0.000555  0.000126  0.000369
# 87                 136511-EGen-high_dist    4.0  0.000544  0.000231  0.000294
# 270         18539311-Retail-Res-low_dist    4.0  0.000542  0.000070  0.000461
# 163  15714811-Transportation-medium_dist    4.0  0.000542  0.000242  0.000317
# 81         127511-Retail-Res-medium_dist    4.0  0.000538  0.000323  0.000302
# 214     17250011-Transportation-low_dist    4.0  0.000529  0.000154  0.000411
# 28      10477111-Transportation-low_dist    4.0  0.000527  0.000048  0.000473
# 228         18130211-Retail-Res-low_dist    4.0  0.000522  0.000062  0.000433
# 82         127611-Retail-Res-medium_dist    4.0  0.000521  0.000075  0.000439
# 278         18544811-Retail-Res-low_dist    4.0  0.000509  0.000103  0.000362
# 152      14295811-Retail-Res-medium_dist    4.0  0.000508  0.000183  0.000350
# 138      14235311-Retail-Res-medium_dist    4.0  0.000506  0.000111  0.000361
# 284         18697311-Retail-Res-low_dist    4.0  0.000504  0.000085  0.000417
# 204      17246611-Retail-Res-medium_dist    4.0  0.000502  0.000360  0.000261
# 169      15732311-Retail-Res-medium_dist    4.0  0.000492  0.000293  0.000268
# 331          450311-Retail-Res-high_dist    4.0  0.000490  0.000174  0.000303
# 100         13779311-Retail-Res-low_dist    4.0  0.000490  0.000164  0.000358
# 151        14292411-Retail-Res-high_dist    4.0  0.000490  0.000279  0.000291
# 69               10707511-EGen-high_dist    4.0  0.000482  0.000109  0.000329
# 212         17249711-Retail-Res-low_dist    4.0  0.000481  0.000163  0.000371
# 45       10496311-Retail-Res-medium_dist    4.0  0.000481  0.000038  0.000434
# 313        375611-AutoRepair-medium_dist    4.0  0.000480  0.000189  0.000265
# 242      18134111-Manufacturing-low_dist    4.0  0.000474  0.000064  0.000385
# 106      13799311-Retail-Res-medium_dist    4.0  0.000474  0.000116  0.000315
# 281      18545611-Retail-Res-medium_dist    4.0  0.000472  0.000160  0.000284
# 47       10496711-Retail-Res-medium_dist    4.0  0.000466  0.000263  0.000285
# 330          448011-Retail-Res-high_dist    4.0  0.000461  0.000231  0.000253
# 85         128211-Retail-Res-medium_dist    4.0  0.000460  0.000165  0.000267
# 113         13818811-Retail-Res-low_dist    4.0  0.000458  0.000154  0.000326
# 176        15750711-Retail-Res-high_dist    4.0  0.000456  0.000296  0.000264
# 115      13825511-Retail-Res-medium_dist    4.0  0.000452  0.000166  0.000313
# 239         18132911-Retail-Res-low_dist    4.0  0.000452  0.000060  0.000373
# 95         13761011-Retail-Res-high_dist    4.0  0.000354  0.000106  0.000240
# 60          10504811-Retail-Res-low_dist    4.0  0.000353  0.000194  0.000217
# 14          10462111-Retail-Res-low_dist    4.0  0.000352  0.000059  0.000284
# 58       10502711-Retail-Res-medium_dist    4.0  0.000352  0.000086  0.000269
# 236   18132311-Manufacturing-medium_dist    4.0  0.000348  0.000230  0.000203
# 226      18129911-Retail-Res-medium_dist    4.0  0.000344  0.000140  0.000198
# 262         18493611-Retail-Res-low_dist    4.0  0.000344  0.000264  0.000156
# 90          13747911-Retail-Res-low_dist    4.0  0.000344  0.000075  0.000279
# 43    10494711-Manufacturing-medium_dist    4.0  0.000343  0.000209  0.000184
# 9        10460411-Retail-Res-medium_dist    4.0  0.000341  0.000227  0.000195
# 305          310211-Retail-Res-high_dist    4.0  0.000340  0.000153  0.000215
# 63    10507111-Manufacturing-medium_dist    4.0  0.000325  0.000068  0.000236
# 56          10502511-Retail-Res-low_dist    4.0  0.000325  0.000080  0.000239
# 57          10502611-Retail-Res-low_dist    4.0  0.000320  0.000113  0.000184
# 80         127111-Retail-Res-medium_dist    4.0  0.000318  0.000172  0.000194
# 94         13760911-Retail-Res-high_dist    4.0  0.000309  0.000166  0.000185
# 93       13760711-Retail-Res-medium_dist    4.0  0.000308  0.000171  0.000189
# 111  13818011-Transportation-medium_dist    4.0  0.000307  0.000183  0.000177
# 311           343011-FoodPlant-high_dist    4.0  0.000304  0.000145  0.000196
# 202      17245411-Retail-Res-medium_dist    4.0  0.000299  0.000042  0.000252
# 318     383211-Manufacturing-medium_dist    4.0  0.000296  0.000111  0.000178
# 346        808611-AsphaltPlant-high_dist    4.0  0.000294  0.000102  0.000184
# 303              203811-WWTP-medium_dist    4.0  0.000291  0.000149  0.000177
# 350                              Mintemp    4.0  0.000290  0.000101  0.000188
# 157     14314811-Transportation-low_dist    4.0  0.000290  0.000013  0.000274
# 68      10523411-Manufacturing-high_dist    4.0  0.000281  0.000077  0.000199
# 291      18779811-Manufacturing-low_dist    4.0  0.000277  0.000036  0.000246
# 12       10461711-Retail-Res-medium_dist    4.0  0.000268  0.000121  0.000166
# 30              10477411-Waste-high_dist    4.0  0.000265  0.000115  0.000171
# 37       10488111-Retail-Res-medium_dist    4.0  0.000262  0.000032  0.000232
# 21          10472411-Retail-Res-low_dist    4.0  0.000261  0.000028  0.000220
# 217   17252111-Manufacturing-medium_dist    4.0  0.000235  0.000068  0.000176
# 347           808811-FoodPlant-high_dist    4.0  0.000234  0.000033  0.000206
# 335           512911-FoodPlant-high_dist    4.0  0.000233  0.000030  0.000210
#
#           25%       50%       75%       max              grouping
# 96   0.004505  0.026484  0.106685  0.282841        Transportation
# 273  0.009006  0.016950  0.076531  0.232393                Retail
# 7    0.001013  0.002991  0.062857  0.237442            Foundaries
# 224  0.002903  0.012158  0.050683  0.140870                Retail
# 188  0.001360  0.001519  0.034755  0.134186                Retail
# 218  0.015239  0.031528  0.050515  0.069248                Retail
# 49   0.001103  0.001374  0.027472  0.105364                Retail
# 262  0.000170  0.000248  0.000422  0.000725                Retail
# 90   0.000281  0.000336  0.000400  0.000425                Retail
# 43   0.000191  0.000278  0.000430  0.000631         Manufacturing
# 9    0.000203  0.000246  0.000385  0.000676                Retail
# 305  0.000267  0.000291  0.000364  0.000564                Retail
# 63   0.000297  0.000335  0.000363  0.000397         Manufacturing
# 56   0.000275  0.000318  0.000367  0.000425                Retail
# 57   0.000281  0.000317  0.000356  0.000461                Retail
# 80   0.000209  0.000254  0.000363  0.000568                Retail
# 94   0.000201  0.000252  0.000359  0.000546                Retail
# 93   0.000196  0.000243  0.000354  0.000555                Retail
# 111  0.000177  0.000242  0.000372  0.000566        Transportation
# 311  0.000209  0.000253  0.000347  0.000513             FoodPlant
# 202  0.000270  0.000301  0.000331  0.000342                Retail
# 318  0.000250  0.000281  0.000327  0.000445         Manufacturing
# 346  0.000219  0.000304  0.000379  0.000385          AsphaltPlant
# 303  0.000180  0.000247  0.000359  0.000493                  WWTP
# 350  0.000223  0.000279  0.000347  0.000416               Mintemp
# 157  0.000284  0.000293  0.000299  0.000302        Transportation
# 68   0.000229  0.000277  0.000329  0.000370         Manufacturing
# 291  0.000255  0.000267  0.000288  0.000328         Manufacturing
# 12   0.000184  0.000236  0.000320  0.000434                Retail
# 30   0.000210  0.000228  0.000282  0.000432                 Waste
# 37   0.000243  0.000255  0.000275  0.000306                Retail
# 21   0.000254  0.000270  0.000277  0.000285                Retail
# 217  0.000191  0.000219  0.000263  0.000328         Manufacturing
# 347  0.000206  0.000232  0.000260  0.000268             FoodPlant
# 335  0.000211  0.000224  0.000245  0.000274             FoodPlant

# %%
## Assign groupings to dataframe
BC_feature_importance_df['grouping'] = " "
for index, str in enumerate(BC_feature_importance_df['feature']):
    group = re.findall(r'-(.+?)-',str)
    if group:
        BC_feature_importance_df.loc[index, 'grouping'] = group
    else:
        BC_feature_importance_df.loc[index, 'grouping'] =  BC_feature_importance_df.loc[index, 'feature']

# %%
BC_feature_importance_df = BC_feature_importance_df.sort_values('mean', ascending = False)

# %%
#plot feature importance
plt.figure(figsize = (20,8))
ax = sns.barplot(y = 'mean', x = 'feature', hue = 'grouping',  data = BC_feature_importance_df[:30],
             dodge = False, palette = 'muted')
plt.xticks(rotation = 90)
plt.xlabel("Feature", size = 20)
plt.xticks(size = 20)
plt.yticks(size = 16)
plt.ylabel("Importance", size = 20)
plt.title("Feature selection for BC Dataset using Random Forest and Cross Validation", size = 20)
plt.show()
#order=BC_test_feature_importance.sort_values('importance',ascending = False).feature

# %%
# Write BC Feature importance to a separate csv file
BC_feature_importance_df.to_csv("Data/BC_feature_importance_All_Facilities.csv")

# %% [markdown]
# ### <b> <font size = 3>  NO2 Dataset</b> </font>

# %%
y_NO2_original = NO2_All[['NO2_Value']]
X_NO2_original = NO2_All.drop(columns = 'NO2_Value')

# %%
## Test Train split 
X_NO2_original_train, X_NO2_original_test, y_NO2_original_train, y_NO2_original_test = train_test_split(X_NO2_original, y_NO2_original, test_size = 0.3, random_state = 0)

# %% [markdown]
# **Feature selection using cross validation**

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits = 4)
RFRegressor = RandomForestRegressor(random_state = 0, n_estimators = 100, n_jobs = -1, max_features = 'auto')
count = 1


feature_names = ['{}'.format(name) for name in X_NO2_original.columns]

NO2_feature_importance_df = pd.DataFrame({'feature': [], 'importance': [], 'fold': []})

for train, _ in kf.split(X_NO2_original, y_NO2_original):
    RFRegressor.fit(X_NO2_original.iloc[train,:], y_NO2_original.iloc[train])
    NO2_featureimp_index = np.argsort(RFRegressor.feature_importances_)[::-1]
    NO2_labels = [feature_names[-i] for i in NO2_featureimp_index]
    
    d = {'feature': NO2_labels, 'importance': RFRegressor.feature_importances_[NO2_featureimp_index], 'fold': count}
    NO2_feature_importance_df = NO2_feature_importance_df.append(pd.DataFrame(d))
    count = count + 1

# %%
#Reset index and drop the column containin repeating indices
NO2_feature_importance_df.reset_index(inplace=True)
NO2_feature_importance_df.drop(columns = ['index'], inplace=True)

# %%
#Calculate the mean score of all features from cross validation and reset index
NO2_feature_importance_df = NO2_feature_importance_df.groupby('feature').describe()['importance']
NO2_feature_importance_df.reset_index(inplace=True)

# %%
## Assign groupings to dataframe
NO2_feature_importance_df['grouping'] = " "
for index, str in enumerate(NO2_feature_importance_df['feature']):
    group = re.findall(r'-(.+?)-',str)
    if group:
        NO2_feature_importance_df.loc[index, 'grouping'] = group
    else:
        NO2_feature_importance_df.loc[index, 'grouping'] =  NO2_feature_importance_df.loc[index, 'feature']

# %%
NO2_feature_importance_df.head(300)
# Out:
#                                  feature  count      mean       std       min  \
# 0          10452911-Retail-Res-high_dist    4.0  0.000984  0.000339  0.000624
# 1              10453011-WWTP-medium_dist    4.0  0.007301  0.005878  0.002510
# 2     10457011-Manufacturing-medium_dist    4.0  0.009112  0.008034  0.002199
# 3       10457511-Manufacturing-high_dist    4.0  0.000613  0.000532  0.000250
# 4        10460411-Retail-Res-medium_dist    4.0  0.005043  0.006484  0.000070
# 5          10460511-Retail-Res-high_dist    4.0  0.021758  0.042641  0.000220
# 6           10461011-Retail-Res-low_dist    4.0  0.000981  0.001264  0.000264
# 7        10461711-Retail-Res-medium_dist    4.0  0.053759  0.106811  0.000103
# 8                10461911-Waste-low_dist    4.0  0.000216  0.000077  0.000123
# 9           10462111-Retail-Res-low_dist    4.0  0.000237  0.000061  0.000165
# 10          10466511-FoodPlant-high_dist    4.0  0.002343  0.002596  0.000267
# 11       10469511-Retail-Res-medium_dist    4.0  0.001010  0.000803  0.000295
# 12       10470711-Retail-Res-medium_dist    4.0  0.000209  0.000118  0.000120
# 13          10471211-Retail-Res-low_dist    4.0  0.001029  0.000553  0.000549
# 14          10472111-Retail-Res-low_dist    4.0  0.000230  0.000064  0.000184
# 15       10472311-Retail-Res-medium_dist    4.0  0.002459  0.002522  0.000265
# 16       10472411-Retail-Res-medium_dist    4.0  0.000784  0.000597  0.000328
# 17             10472611-EGen-medium_dist    4.0  0.000332  0.000072  0.000255
# 18          10473411-Retail-Res-low_dist    4.0  0.003581  0.003038  0.000411
# 19    10473611-Manufacturing-medium_dist    4.0  0.000575  0.000292  0.000276
# 20          10476211-Retail-Res-low_dist    4.0  0.000140  0.000044  0.000102
# 21   10476911-Transportation-medium_dist    4.0  0.000761  0.001027  0.000208
# 22      10477111-Transportation-low_dist    4.0  0.000999  0.000498  0.000306
# 23       10478111-Retail-Res-medium_dist    4.0  0.001930  0.001760  0.000695
# 24          10478611-Retail-Res-low_dist    4.0  0.004496  0.007825  0.000215
# 25       10478711-Retail-Res-medium_dist    4.0  0.000342  0.000061  0.000285
# 26          10478811-Retail-Res-low_dist    4.0  0.000722  0.000538  0.000372
# 27   10481011-Transportation-medium_dist    4.0  0.000161  0.000070  0.000096
# 28       10487211-Retail-Res-medium_dist    4.0  0.002339  0.002296  0.000208
# 29       10488111-Retail-Res-medium_dist    4.0  0.001217  0.000709  0.000272
# 30   10490111-Transportation-medium_dist    4.0  0.000978  0.000631  0.000351
# 31       10490611-Retail-Res-medium_dist    4.0  0.000323  0.000146  0.000205
# 32          10492211-Retail-Res-low_dist    4.0  0.000202  0.000091  0.000077
# 33    10492711-Manufacturing-medium_dist    4.0  0.000399  0.000092  0.000300
# 34       10493211-Retail-Res-medium_dist    4.0  0.001289  0.000450  0.000779
# 35       10496311-Retail-Res-medium_dist    4.0  0.001367  0.001059  0.000246
# 36       10496511-Retail-Res-medium_dist    4.0  0.000540  0.000130  0.000445
# 37       10496711-Retail-Res-medium_dist    4.0  0.006123  0.003948  0.000700
# 38         10497111-Retail-Res-high_dist    4.0  0.001076  0.000699  0.000498
# 39       10497711-Retail-Res-medium_dist    4.0  0.000189  0.000087  0.000113
# 40   10498611-Transportation-medium_dist    4.0  0.001081  0.000486  0.000680
# 41          10500811-Retail-Res-low_dist    4.0  0.000872  0.000522  0.000306
# 42       10501811-Retail-Res-medium_dist    4.0  0.001070  0.000580  0.000268
# 43          10501911-Retail-Res-low_dist    4.0  0.001466  0.000880  0.000194
# 44       10502011-Retail-Res-medium_dist    4.0  0.001356  0.001209  0.000346
# 45       10502111-Retail-Res-medium_dist    4.0  0.000858  0.000557  0.000376
# 46       10502511-Retail-Res-medium_dist    4.0  0.000598  0.000501  0.000233
# 47          10502611-Retail-Res-low_dist    4.0  0.001305  0.000983  0.000455
# 48       10502711-Retail-Res-medium_dist    4.0  0.000670  0.000296  0.000420
# 49       10503011-Retail-Res-medium_dist    4.0  0.003697  0.005325  0.000108
# 50          10504811-Retail-Res-low_dist    4.0  0.000207  0.000077  0.000119
# 51    10505411-Manufacturing-medium_dist    4.0  0.000223  0.000021  0.000203
# 52       10506911-Retail-Res-medium_dist    4.0  0.000275  0.000137  0.000149
# 53       10510811-AsphaltPlant-high_dist    4.0  0.001004  0.000604  0.000206
# 54         10517111-Retail-Res-high_dist    4.0  0.000210  0.000069  0.000160
# 55        10518411-FoodPlant-medium_dist    4.0  0.000364  0.000312  0.000130
# 56      10523411-Manufacturing-high_dist    4.0  0.000488  0.000364  0.000215
# 57               10707511-EGen-high_dist    4.0  0.001048  0.000597  0.000558
# 58              10708011-Waste-high_dist    4.0  0.000376  0.000207  0.000199
# 138      14314511-Retail-Res-medium_dist    4.0  0.000335  0.000129  0.000192
# 139      14314611-Retail-Res-medium_dist    4.0  0.000507  0.000407  0.000159
# 140  14314811-Transportation-medium_dist    4.0  0.000772  0.000824  0.000120
# 141         14318611-FoodPlant-high_dist    4.0  0.000716  0.000578  0.000202
# 142         15713511-Retail-Res-low_dist    4.0  0.001420  0.000598  0.000933
# 143          15713811-FoodPlant-low_dist    4.0  0.000878  0.001108  0.000210
# 144     15714811-Transportation-low_dist    4.0  0.000358  0.000212  0.000176
# 145         15714911-Retail-Res-low_dist    4.0  0.000155  0.000066  0.000101
# 146         15715211-Retail-Res-low_dist    4.0  0.003072  0.002566  0.000967
# 147        15721111-Retail-Res-high_dist    4.0  0.080170  0.155406  0.001091
# 148         15723511-Retail-Res-low_dist    4.0  0.038678  0.070137  0.000882
# 149     15723611-Transportation-low_dist    4.0  0.000234  0.000027  0.000200
# 150      15732311-Retail-Res-medium_dist    4.0  0.002032  0.002192  0.000196
# 151        15734511-Retail-Res-high_dist    4.0  0.000192  0.000076  0.000125
# 152         15734911-Retail-Res-low_dist    4.0  0.000352  0.000314  0.000116
# 153         15737911-Retail-Res-low_dist    4.0  0.000356  0.000312  0.000134
# 154         15742311-Retail-Res-low_dist    4.0  0.000356  0.000277  0.000091
# 155        15745711-Retail-Res-high_dist    4.0  0.000706  0.000494  0.000238
# 156         15746511-Retail-Res-low_dist    4.0  0.022068  0.043262  0.000253
# 157        15750711-Retail-Res-high_dist    4.0  0.000425  0.000224  0.000128
# 158         15754311-Retail-Res-low_dist    4.0  0.000582  0.000577  0.000153
# 159         15755311-Retail-Res-low_dist    4.0  0.000355  0.000174  0.000197
# 160         15755411-Retail-Res-low_dist    4.0  0.000995  0.001122  0.000350
# 161     15755511-Manufacturing-high_dist    4.0  0.001904  0.002748  0.000192
# 162         15756011-FoodPlant-high_dist    4.0  0.000365  0.000214  0.000172
# 163         15925211-Retail-Res-low_dist    4.0  0.000247  0.000120  0.000178
# 164      15940511-Retail-Res-medium_dist    4.0  0.000365  0.000293  0.000168
# 165      15941011-Retail-Res-medium_dist    4.0  0.001740  0.002151  0.000565
# 166        15941111-Retail-Res-high_dist    4.0  0.000347  0.000161  0.000193
# 167        15941211-Retail-Res-high_dist    4.0  0.000394  0.000275  0.000178
# 168        15942711-Retail-Res-high_dist    4.0  0.000459  0.000239  0.000249
# 169         15943911-Retail-Res-low_dist    4.0  0.000289  0.000077  0.000181
# 170         15950611-Retail-Res-low_dist    4.0  0.000278  0.000121  0.000139
# 171              15974511-Misc-high_dist    4.0  0.000718  0.000208  0.000560
# 172      16021911-Retail-Res-medium_dist    4.0  0.001082  0.000769  0.000346
# 173      16022011-Retail-Res-medium_dist    4.0  0.000381  0.000255  0.000166
# 174      16080611-Retail-Res-medium_dist    4.0  0.000615  0.000246  0.000321
# 175        168111-Retail-Res-medium_dist    4.0  0.000230  0.000117  0.000105
# 176             168411-Waste-medium_dist    4.0  0.015484  0.023936  0.000425
# 264  0.000521  0.000736  0.000994  0.001199          Retail
# 265  0.000335  0.000355  0.000430  0.000616          Retail
# 266  0.000214  0.000264  0.000384  0.000618          Retail
# 267  0.000499  0.001024  0.002158  0.004184          Retail
# 268  0.000140  0.000181  0.000299  0.000532   Manufacturing
# 269  0.000641  0.000806  0.015246  0.058528   Manufacturing
# 270  0.000222  0.000307  0.000467  0.000706   Manufacturing
# 271  0.000426  0.000653  0.001203  0.002495   Manufacturing
# 272  0.000124  0.000236  0.000395  0.000558   Manufacturing
# 273  0.002494  0.009382  0.030791  0.074956          Retail
# 274  0.001259  0.002348  0.003401  0.003728      AutoRepair
# 275  0.000144  0.000257  0.000442  0.000699          Retail
# 276  0.000237  0.000302  0.000361  0.000364    AsphaltPlant
# 277  0.000523  0.000542  0.000917  0.002017          Retail
# 278  0.000275  0.000333  0.000693  0.001657            WWTP
# 279  0.000146  0.000168  0.000199  0.000226            Misc
# 280  0.000907  0.001149  0.010983  0.039763          Retail
# 281  0.000738  0.001134  0.001500  0.001512          Retail
# 282  0.000150  0.000188  0.000262  0.000402          Retail
# 283  0.000518  0.000696  0.000827  0.000835       FoodPlant
# 284  0.000178  0.000246  0.000316  0.000409       FoodPlant
# 285  0.000298  0.000421  0.000738  0.001374        Eateries
# 286  0.000821  0.001722  0.002639  0.002980      AutoRepair
# 287  0.000274  0.000500  0.000718  0.000751            WWTP
# 288  0.000615  0.000817  0.001267  0.002032   Manufacturing
# 289  0.000239  0.000483  0.013354  0.051287      Foundaries
# 290  0.000195  0.000264  0.000432  0.000728            Misc
# 291  0.000324  0.000441  0.000575  0.000635      AutoRepair
# 292  0.000268  0.000476  0.000676  0.000719      Foundaries
# 293  0.000344  0.000362  0.000402  0.000506   Manufacturing
# 294  0.004037  0.027460  0.054369  0.067113          Retail
# 295  0.000160  0.000206  0.000311  0.000545          Retail
# 296  0.000294  0.000364  0.000517  0.000834          Retail
# 297  0.000949  0.001436  0.002118  0.003186      Foundaries
# 298  0.000348  0.000408  0.000464  0.000491  Transportation
# 299  0.000363  0.000528  0.000690  0.000733   Manufacturing

# %%
NO2_feature_importance_df = NO2_feature_importance_df.sort_values('mean', ascending = False)

# %%
#plot feature importance
plt.figure(figsize = (20,8))
ax = sns.barplot(y = 'mean', x = 'feature', hue = 'grouping',  data = NO2_feature_importance_df[:30],
             dodge = False, palette = 'muted')
plt.xticks(rotation = 90)
plt.xlabel("Feature", size = 20)
plt.xticks(size = 20)
plt.yticks(size = 16)
plt.ylabel("Importance", size = 20)
plt.title("Feature selection for NO2 Dataset using Random Forest and Cross Validation", size = 20)
plt.show()

# %%
# Write NO2 Feature importance to a separate csv file
NO2_feature_importance_df.to_csv("Data/NO2_feature_importance_All_Facilities.csv")

# %% [markdown]
# #  <font size = 5> <b> Machine Learning </font> </b>

# %% [markdown]
# ## <b> <font size = 4>  Apply PCA And Test Performance of Several Models </b> </font>

# %% [markdown]
# The idea here is to test model performances for different models with PCA and without PCA to see if there is any benefit of performing a PCA.

# %% [markdown]
# <b> <font size = 3> Function to apply PCA and test performance of several models </b> </font>

# %%
def diff_model_test(X,y):
    results={}
    def test_model(clf):
        
        cv = KFold(n_splits=5,shuffle=True,random_state=45)
        r2 = make_scorer(r2_score)
        r2_val_score = cross_val_score(clf, X,y, cv=cv,scoring=r2)
        scores=[r2_val_score.mean()]
        return scores

    clf = linear_model.LinearRegression()
    results["Linear"]=test_model(clf)
    
    clf = linear_model.Ridge()
    results["Ridge"]=test_model(clf)
    
    clf = linear_model.RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1])
    results["RidgeCV"] = test_model(clf)

    clf = BaggingRegressor()
    results["Bagging"]=test_model(clf)
    
    
    clf = RandomForestRegressor(n_estimators = 200)
    results["RandomForest"]=test_model(clf)
    
    #clf = linear_model.BayesianRidge()
    #results["Bayesian Ridge"]=test_model(clf)
    
    #clf = linear_model.HuberRegressor()
    #results["Hubber"]=test_model(clf)
    
    clf = XGBRegressor(n_estimators = 50)
    results['XG Boost'] = test_model(clf)
    
    


    
    results = pd.DataFrame.from_dict(results,orient='index')
    results.columns=["R Square Score"] 
    #results=results.sort(columns=["R Square Score"],ascending=False)
    results.plot(kind="bar",title="Model Scores")
    axes = plt.gca()
    axes.set_ylim([0.5,1])
    return results

# %% [markdown]
# ### <b> <font size = 4> BC Dataset </b> </font>

# %%
## USing PCA to test different models
#Create a Scaler object
scaler_BC = StandardScaler()

# Fit on training set only.
scaler_BC.fit(X_train_BC_PCA)

# Apply transform to both the training set and the test set.
X_train_BC_PCA = scaler_BC.transform(X_train_BC_PCA)
X_test_BC_PCA = scaler_BC.transform(X_test_BC_PCA)

# %%
#Instantiate PCA
pca_BC = PCA(0.99) #Set the variance to be 0.99

pca_BC.fit(X_train_BC_PCA)


X_train_BC_PCA_trans = pca_BC.transform(X_train_BC_PCA)
X_test_BC_PCA_trans = pca_BC.transform(X_test_BC_PCA)

# %% [markdown]
# **Model scores with PCA**

# %%
## Call the function on BC dataset
print("Model score on training set with PCA: \n ")
diff_model_test(X_train_BC_PCA, y_train_BC_PCA)
# Out:
# Model score on training set with PCA:
#               R Square Score
# Linear              0.658299
# Ridge               0.586892
# RidgeCV             0.645884
# Bagging             0.800443
# RandomForest        0.813935
# XG Boost            0.681130

# %%
print("Model score on test set with PCA: \n")
diff_model_test(X_test_BC_PCA, y_test_BC_PCA)
# Out:
# Model score on test set with PCA:
#               R Square Score
# Linear              0.645761
# Ridge               0.561087
# RidgeCV             0.635105
# Bagging             0.737963
# RandomForest        0.762675
# XG Boost            0.669166

# %% [markdown]
# **Model scores without PCA**

# %%
## BC dataset without PCA - use scaled and normalized dataset

## Call the function on BC dataset
print("Model score on test set without PCA:")
diff_model_test(X_test_BC, y_test_BC)
# Out:
# Model score on test set without PCA:
#               R Square Score
# Linear              0.605984
# Ridge               0.596270
# RidgeCV             0.598741
# Bagging             0.715232
# RandomForest        0.731579
# XG Boost            0.643827

# %% [markdown]
#  ### <b> <font size = 4> NO2 Dataset </b> </font>

# %%
## USing PCA to test different models
#Create a Scaler object
scaler_NO2 = StandardScaler()

# Fit on training set only.
scaler_NO2.fit(X_train_NO2_PCA)

# Apply transform to both the training set and the test set.
X_train_NO2_PCA = scaler_NO2.transform(X_train_NO2_PCA)
X_test_NO2_PCA = scaler_NO2.transform(X_test_NO2_PCA)

# %%
#Instantiate PCA
pca = PCA(0.99)

pca.fit(X_train_NO2_PCA)


X_train_NO2_PCA_trans = pca.transform(X_train_NO2_PCA)
X_test_NO2_PCA_trans = pca.transform(X_test_NO2_PCA)

# %% [markdown]
# **Model scores with PCA**

# %%
## Call the function on NO2 dataset
print("Model score on training set with PCA: \n ")
diff_model_test(X_train_NO2_PCA, y_train_NO2_PCA)
# Out:
# Model score on training set with PCA:
#               R Square Score
# Linear              0.760253
# Ridge               0.682373
# RidgeCV             0.742407
# Bagging             0.911945
# RandomForest        0.919548
# XG Boost            0.790013

# %%
print("Model score on test set with PCA: \n")
diff_model_test(X_test_NO2_PCA, y_test_NO2_PCA)
# Out:
# Model score on test set with PCA:
#               R Square Score
# Linear              0.749091
# Ridge               0.660212
# RidgeCV             0.736677
# Bagging             0.887279
# RandomForest        0.899310
# XG Boost            0.780927

# %% [markdown]
# **Model scores without PCA**

# %%
## NO2 dataset without PCA - use scaled and normalized dataset

## Call the function on BC dataset
print("Model score on test set without PCA:")
diff_model_test(X_test_NO2, y_test_NO2)
# Out:
# Model score on test set without PCA:
#               R Square Score
# Linear              0.748091
# Ridge               0.724831
# RidgeCV             0.739534
# Bagging             0.894574
# RandomForest        0.905719
# XG Boost            0.791325

# %% [markdown]
# ## <b> <font size = 5> Cross-validation and Gridsearch for Model Selection and Prediction </b> </font> </span>

# %%
def cv_gridsearch_models(model_type, X, y, pol ,pca_apply= False):
    """model_type: string. Inputs = ridge, randomforest, xgboost
    X = dataframe with all features (normalized and scaled)
    y = dataframe of target variable
    pca_apply = set apply_pca = True"""
    
    #Split X and y into 70/30 train and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

    #Scale the test and training X - data
    feature_scaler = StandardScaler()
    X_train = feature_scaler.fit_transform(X_train)
    X_test = feature_scaler.transform(X_test)
    
    
    ## Define grid parameters for different types of model and perform a gridsearch CV over each
    ## First model is a simple RandomforestRegressor. Grid parameters are number of estimators, max_features, and max_depth
    ## Second model is a Ridge Regression model. Grid parameters include Alpha and fit_intercept
    ## Third model is a linear regression model with grid parameters like 
    ## Fourth model is XGBoost, with grid parameters like max_depth, learning rate and number of estimators
    
    if model_type == 'RF':
        rf_regressor = RandomForestRegressor(random_state=0, n_jobs = -1, max_features = 'sqrt', n_estimators = 50)
        grid_param = {
            'n_estimators': [300, 400, 500, 600, 800],
            'max_depth': [5,10, 15, 50]
                      }
        model = GridSearchCV(estimator=rf_regressor,
                     param_grid=grid_param,
 #                    scoring='neg_mean_absolute_error',
                     cv=5,
                     n_jobs=-1)
        
    elif model_type == 'Ridge':
        ridge_reg = Ridge(normalize = True)
        grid_param = {
            'alpha': [1,0.1,0.01,0.001,0,10],
            'fit_intercept': [True, False], 
            }
        model = GridSearchCV(estimator = ridge_reg,
                            param_grid = grid_param,
                            scoring = 'r2',
                            cv = 5)
        
    elif model_type == "ElasticNet":
        elastic_net = ElasticNet(normalize = True, random_state = 0)
        grid_param = {'l1_ratio': [.1, .5, .7, .9, .95, .99, 1],
                     'alpha': [1,0.1,0.01,0, 10]}
        model = GridSearchCV(estimator = elastic_net,
                            param_grid = grid_param,
                            scoring = 'r2',
                            cv = 5)
        
    elif model_type == "Linear":
        linear_reg = LinearRegression(n_jobs = -1)
        grid_param = {'fit_intercept': [True, False]}
        model = GridSearchCV(estimator =linear_reg, param_grid = grid_param,
                            cv = 5)
        
        
    elif model_type == 'XGB':
        XGB_reg = XGBRegressor(objective = 'reg:linear', random_state = 0, n_estimators = 50)
        grid_param = {
            'max_depth' : [2,4,6,10],
            'n_estimators': [40,60,100],
            'learning_rate': [0.1, 0.001, 0.05, 0.01]
            }
        model = GridSearchCV(estimator = XGB_reg,
                            param_grid = grid_param,
 #                           scoring = 'neg_mean_squared_error', 
                             cv = 5)
   
    if (model_type == 'Ridge') & (pca_apply == 'True'):
            pca = PCA(n_components = np.argwhere(np.cumsum(pca.explained_variance_ratio_) > 0.999)[0][0])
            X_train_pca = pca.fit_transform(X_train)
            X_test_pca = pca.transform(X_test)
            model.fit(X_train_pca, y_train)
            train_score= model.score(X_train_pca, y_train)
            test_score = model.score(X_test_pca, y_test)
            print("Train R2 = {}, Test_R2 = {}".format(train_score, test_score))
            best_parameters = model.best_params_
            print("Best parameter for {} is {}".format(model_type, best_parameters))
            best_result = model.best_score_
            print("Best R2 achieved for {} is {}".format(model_type, best_result))
            
    else: 
        model.fit(X_train, y_train)
        y_pred = []
        y_pred = model.predict(X_test)
        # model.predict returns nparray of nparray objects
        if (model_type == "Ridge") or (model_type == "Linear"):
            y_pred = [y[0] for y in y_pred]            
        best_parameters = model.best_params_
        print("Best parameter for {} is {}".format(model_type, best_parameters))
        best_result = model.best_score_
        print("Best accuracy achieved for {} is {}".format(model_type, best_result))
        train_score= model.score(X_train, y_train)
        test_score = model.score(X_test, y_test)
        print("Train R2 = {}, Test_R2 = {}".format(train_score, test_score))
        best_parameters = model.best_params_
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        print("Root Mean Squared Error: {}".format(rmse))
        

        ##Plot a graph of predicted vs actual values
        #sns.set_style("darkgrid")
        #sns.set(font_scale = 1.2)
        plt.figure(figsize = (8,6))
        ax = sns.regplot(x = y_test, y = y_pred, fit_reg=True)
        if pol=='BC':
            ax.set(xlabel = 'Actual BC Concentrations (ug/m3)', ylabel = 'Predicted BC Concetrations (ug/m3)') 
        else:
            ax.set(xlabel = 'Actual NO2 Concentrations (ppb)', ylabel = 'Predicted NO2 Concetrations (ppb)')
   
        plt.title("Predicted vs. Actual concentration for "+model_type+ " Regression for "+pol)
        if pol=='BC':
            plt.text(6 , 0 ,"R2 = {}".format(round(test_score,3)), fontsize = 18)
        else:
            plt.text(45 , 10 ,"R2 = {}".format(round(test_score,3)), fontsize = 18)

# %% [markdown]
# ### <b> <font size = 4> BC Dataset </b> </font>

# %%
print("Linear Regression:")

cv_gridsearch_models('Linear', X_BC_original, y_BC_original, "BC", False)
# Out:
# Linear Regression:
# Best parameter for Linear is {'fit_intercept': True}
# Best accuracy achieved for Linear is 0.6718019585167653
# Train R2 = 0.692052543817544, Test_R2 = 0.6743052052769285
# Root Mean Squared Error: 0.35279554114119327

# %%
print("Ridge Regression without PCA:")


cv_gridsearch_models('Ridge', X_BC_original, y_BC_original, "BC" ,False)
# Out:
# Ridge Regression without PCA:
# Best parameter for Ridge is {'alpha': 0, 'fit_intercept': True}
# Best accuracy achieved for Ridge is 0.6718019585105729
# Train R2 = 0.6920525438149336, Test_R2 = 0.6743052052831604
# Root Mean Squared Error: 0.3527955411378181

# %%
print("ElasticNet Regression without PCA:")


cv_gridsearch_models('ElasticNet', X_BC_original, y_BC_original, "BC" ,False)
# Out:
# ElasticNet Regression without PCA:
# Best parameter for ElasticNet is {'alpha': 0, 'l1_ratio': 0.1}
# Best accuracy achieved for ElasticNet is 0.5499894866345686
# Train R2 = 0.5536546918772671, Test_R2 = 0.5414685366536256
# Root Mean Squared Error: 0.4186029160727685

# %%
print("Random Forest Regression:")

cv_gridsearch_models('RF', X_BC_original, y_BC_original, "BC", False)
# Out:
# Random Forest Regression:
# Best parameter for RF is {'max_depth': 15, 'n_estimators': 800}
# Best accuracy achieved for RF is 0.8091160723078702
# Train R2 = 0.9267348791137142, Test_R2 = 0.7951647827262689
# Root Mean Squared Error: 0.2797821429016857

# %%
rf_regressor = RandomForestRegressor(random_state=0, n_jobs = -1, max_features = 'sqrt', n_estimators = 800, max_depth = 15)

# %%
rf_regressor
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=15,
#                       max_features='sqrt', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=-1,
#                       oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %%
print("XGBoost Regression:")
cv_gridsearch_models('XGB', X_BC_original, y_BC_original, "BC", False)
# Out:
# XGBoost Regression:
# Best parameter for XGB is {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Best accuracy achieved for XGB is 0.8187487495684528
# Train R2 = 0.9309704773993756, Test_R2 = 0.8100745851262938
# Root Mean Squared Error: 0.2694072139053117

# %%
XGB_reg = XGBRegressor(objective = 'reg:linear', random_state = 0, learning_rate =  0.1, max_depth =  10, n_estimators =  100)

# %%
#Save the XGBoost Regression and Random Forest models as pickle file
XBG_BC_pkl = 'xgb_bc.pkl'
# Open the pickle instance, dump best estimators into pickle files
XBG_BC_pkl = open(XBG_BC_pkl, 'wb')
pickle.dump(XGB_reg, XBG_BC_pkl)
# Close the pickle instances
XBG_BC_pkl.close()

# %%
#Save the  Random Forest models as pickle file
RF_BC_pkl = 'rf_bc.pkl'
# Open the pickle instance, dump best estimators into pickle files
RF_BC_pkl = open(RF_BC_pkl, 'wb')
pickle.dump(rf_regressor, RF_BC_pkl)
# Close the pickle instances
RF_BC_pkl.close()

# %% [markdown]
# ### <b> <font size = 4>  NO2 Dataset </b> </font>

# %%
print("Linear Regression:")

cv_gridsearch_models('Linear', X_NO2_original, y_NO2_original, "NO2", False)
# Out:
# Linear Regression:
# Best parameter for Linear is {'fit_intercept': True}
# Best accuracy achieved for Linear is 0.7600700314708649
# Train R2 = 0.7713960863839737, Test_R2 = 0.767365156781551
# Root Mean Squared Error: 4.7335801830760635

# %%
print("Ridge Regression without PCA:")

cv_gridsearch_models('Ridge', X_NO2_original, y_NO2_original,"NO2",False)
# Out:
# Ridge Regression without PCA:
# Best parameter for Ridge is {'alpha': 0, 'fit_intercept': True}
# Best accuracy achieved for Ridge is 0.75885141239362
# Train R2 = 0.7713960863837959, Test_R2 = 0.7673651567865519
# Root Mean Squared Error: 4.733580183025185

# %%
print("ElasticNet Regression without PCA:")


cv_gridsearch_models('ElasticNet', X_NO2_original, y_NO2_original, "NO2" ,False)
# Out:
# ElasticNet Regression without PCA:
# Best parameter for ElasticNet is {'alpha': 0, 'l1_ratio': 0.1}
# Best accuracy achieved for ElasticNet is 0.6383595262028383
# Train R2 = 0.640545654487501, Test_R2 = 0.6353304671073837
# Root Mean Squared Error: 5.926551973218568

# %%
print("Random Forest Regression:")

cv_gridsearch_models('RF', X_NO2_original, y_NO2_original, "NO2")
# Out:
# Random Forest Regression:
# Best parameter for RF is {'max_depth': 50, 'n_estimators': 800}
# Best accuracy achieved for RF is 0.9102937750195628
# Train R2 = 0.9882865201476224, Test_R2 = 0.916926250380079
# Root Mean Squared Error: 2.828682890260696

# %%
rf_regressor = RandomForestRegressor(random_state=0, n_jobs = -1, max_features = 'sqrt', n_estimators = 800, max_depth = 50)

# %%
print("XGBoost Regression:")

cv_gridsearch_models('XGB', X_NO2_original, y_NO2_original, "NO2")
# Out:
# XGBoost Regression:
# Best parameter for XGB is {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Best accuracy achieved for XGB is 0.9203067677218862
# Train R2 = 0.9736901148019901, Test_R2 = 0.9248262918404302
# Root Mean Squared Error: 2.690824316965867

# %%
XGB_reg = XGBRegressor(objective = 'reg:linear', random_state = 0, learning_rate =  0.1, max_depth =  10, n_estimators =  100)

# %%
#Save the XGBoost Regression and Random Forest models as pickle file
XBG_NO2_pkl = 'xgb_no2.pkl'
# Open the pickle instance, dump best estimators into pickle files
XBG_NO2_pkl = open(XBG_NO2_pkl, 'wb')
pickle.dump(XGB_reg, XBG_NO2_pkl)
# Close the pickle instances
XBG_NO2_pkl.close()

# %%
#Save the  Random Forest models as pickle file
RF_NO2_pkl = 'rf_no2.pkl'
# Open the pickle instance, dump best estimators into pickle files
RF_NO2_pkl = open(RF_NO2_pkl, 'wb')
pickle.dump(rf_regressor, RF_NO2_pkl)
# Close the pickle instances
RF_NO2_pkl.close()

# %% [markdown]
# # <font size = 5> <b> Reference </b> </font>

# %% [markdown]
# 1. Feature Selection with Pandas: https://towardsdatascience.com/feature-selection-with-pandas-e3690ad8504b
#
# 2. Linear Regression Models: https://towardsdatascience.com/linear-regression-models-4a3d14b8d368
#
# 3. VIF score estimation: https://etav.github.io/python/vif_factor_python.html
#
# 4. Wrapper methods: https://stackabuse.com/applying-wrapper-methods-in-python-for-feature-selection/
#
# 5. Decision Tree Regressor: https://www.dezyre.com/recipes/create-and-optimize-baseline-decision-tree-model-for-regression
#
# 6. Application of PCA: https://www.dezyre.com/recipes/create-and-optimize-baseline-decision-tree-model-for-regression
#
# 7. XGBoost: https://www.mikulskibartosz.name/xgboost-hyperparameter-tuning-in-python-using-grid-search/
#
# 8. Crossvalidation and Gridsearch CV: https://stackabuse.com/cross-validation-and-grid-search-for-model-selection-in-python/
